# %% [markdown]
# # Peter Moss Acute Myeloid & Lymphoblastic Leukemia AI Research Project
# ## Acute Lymphoblastic Leukemia Detection System 2019
# ### Data Augmentation
#
# ![Peter Moss Acute Myeloid & Lymphoblastic Leukemia Research Project](Media/Images/ALL_IDB1-Augmentation.png)
#
#
# The Acute Lymphoblastic Leukemia Detection System 2019 Data Augmentation program applies augmentations/filters to datasets and increases the amount of training/test data available to use. The program is part of the computer vision research and development for the Peter Moss Acute Myeloid & Lymphoblastic Leukemia AI Research Project. This page will provide general information, as well as a guide for installing and setting up the augmentation script.
#
# Before you start the tutorial on below you should complete the steps in the [Augmentation README](README)

# %% [markdown]
# # Research papers followed
#
# The Acute Lymphoblastic Leukemia Detection System 2019 uses the data augmentation methods proposed in the [Leukemia Blood Cell Image Classification Using Convolutional Neural Network by T. T. P. Thanh, Caleb Vununu, Sukhrob Atoev, Suk-Hwan Lee, and Ki-Ryong Kwon](http://www.ijcte.org/vol10/1198-H0012.pdf "Leukemia Blood Cell Image Classification Using Convolutional Neural Network by T. T. P. Thanh, Caleb Vununu, Sukhrob Atoev, Suk-Hwan Lee, and Ki-Ryong Kwon").
#
# | Paper                                                                       | Description                                                                  | Link                                                       |
# | --------------------------------------------------------------------------- | ---------------------------------------------------------------------------- | ---------------------------------------------------------- |
# | Leukemia Blood Cell Image Classification Using Convolutional Neural Network | T. T. P. Thanh, Caleb Vununu, Sukhrob Atoev, Suk-Hwan Lee, and Ki-Ryong Kwon | [Paper](http://www.ijcte.org/vol10/1198-H0012.pdf "Paper") |

# %% [markdown]
# # Dataset Used
#
# The [Acute Lymphoblastic Leukemia Image Database for Image Processing](https://homes.di.unimi.it/scotti/all/) dataset is used for this project. The dataset was created by [Fabio Scotti, Associate Professor Dipartimento di Informatica, Università degli Studi di Milano](https://homes.di.unimi.it/scotti/). Big thanks to Fabio for his research and time put in to creating the dataset and documentation, it is one of his personal projects. You will need to follow the steps outlined [here](https://homes.di.unimi.it/scotti/all/#download) to gain access to the dataset.
#
# | Dataset                                                          | Description                                                                                                                                      | Link                                                                |
# | ---------------------------------------------------------------- | ------------------------------------------------------------------------------------------------------------------------------------------------ | ------------------------------------------------------------------- |
# | Acute Lymphoblastic Leukemia Image Database for Image Processing | Created by [Fabio Scotti, Associate Professor Dipartimento di Informatica, Università degli Studi di Milano](https://homes.di.unimi.it/scotti/). | [Dataset](https://homes.di.unimi.it/scotti/all/#download "Dataset") |
#
# # Data augmentation
#
# ![AML & ALL Data Augmentation](Media/Images/ALL_IDB1-Augmented-Slides.png)
#
# In this dataset there were 49 negative and 59 positive. To make this even I removed 10 images from the negative dataset. From here I removed a further 10 images per class for testing further on in the tutorial and for the purpose of demos etc.
#
# In my case I had 20 test images (10 pos/10 neg) and 39 images per class ready for augmentation. Place the original images that you wish to augment into the **Model/Data/0** & **Model/Data/1**. Using this program I was able to create a dataset of **1053** positive and **1053** negative augmented images.
#
# The full Python class that holds the functions mentioned below can be found in [Classes/Data.py](Classes/Data.py), The Data class is a wrapper class around releated functions provided in popular computer vision libraries including as OpenCV and Scipy.
#
# ## Resizing
#
# The first step is to resize the image this is done with the following function:
#
# ```
#     def resize(self, filePath, savePath, show = False):
#
#         """
#         Writes an image based on the filepath and the image provided.
#         """
#
#         image = cv2.resize(cv2.imread(filePath), self.fixed)
#         self.writeImage(savePath, image)
#         self.filesMade += 1
#         print("Resized image written to: " + savePath)
#
#         if show is True:
#             plt.imshow(image)
#             plt.show()
#
#         return image
# ```
#
# ## Grayscaling
#
# In general grayscaled images are not as complex as color images and result in a less complex model. In the paper the authors described using grayscaling to create more data easily. To create a greyscale copy of each image I wrapped the built in OpenCV function, [cv2.cvtColor()](https://opencv-python-tutroals.readthedocs.io/en/latest/py_tutorials/py_imgproc/py_colorspaces/py_colorspaces.html). The created images will be saved to the relevant directories in the default configuration.
#
# ```
#     def grayScale(self, image, grayPath, show = False):
#
#         """
#         Writes a grayscale copy of the image to the filepath provided.
#         """
#
#         gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
#         self.writeImage(grayPath, gray)
#         self.filesMade += 1
#         print("Grayscaled image written to: " + grayPath)
#
#         if show is True:
#             plt.imshow(gray)
#             plt.show()
#
#         return image, gray
# ```
# ## Histogram Equalization
#
# Histogram equalization is basically stretching the histogram horizontally on both sides, increasing the intensity/contrast. Histogram equalization is described in the paper to enhance the contrast.
#
# In the case of this dataset, it makes both the white and red blood cells more distinguishable. The created images will be saved to the relevant directories in the default configuration.
#
# ```
#     def equalizeHist(self, gray, histPath, show = False):
#
#         """
#         Writes histogram equalized copy of the image to the filepath provided.
#         """
#
#         hist = cv2.equalizeHist(gray)
#         self.writeImage(histPath, cv2.equalizeHist(gray))
#         self.filesMade += 1
#         print("Histogram equalized image written to: " + histPath)
#
#         if show is True:
#             plt.imshow(hist)
#             plt.show()
#
#         return hist
# ```
#
# ## Reflection
#
# Reflection is a way of increasing your dataset by creating a copy that is fliped on its X axis, and a copy that is flipped on its Y axis. The reflection function below uses the built in OpenCV function, cv2.flip, to flip the image on the mentioned axis. The created images will be saved to the relevant directories in the default configuration.
#
# ```
#     def reflection(self, image, horPath, verPath, show = False):
#
#         """
#         Writes reflected copies of the image to the filepath provided.
#         """
#
#         horImg = cv2.flip(image, 0)
#         self.writeImage(horPath, horImg)
#         self.filesMade += 1
#         print("Horizontally reflected image written to: " + horPath)
#
#         if show is True:
#             plt.imshow(horImg)
#             plt.show()
#
#         verImg = cv2.flip(image, 1)
#         self.writeImage(verPath, verImg)
#         self.filesMade += 1
#         print("Vertical reflected image written to: " + verPath)
#
#         if show is True:
#             plt.imshow(verImg)
#             plt.show()
#
#         return horImg, verImg
# ```
# ## Gaussian Blur
#
# Gaussian Blur is a popular technique used on images and is especially popular in the computer vision world. The function below uses the ndimage.gaussian_filter function. The created images will be saved to the relevant directories in the default configuration.
#
# ```
#     def gaussian(self, filePath, gaussianPath, show = False):
#
#         """
#         Writes gaussian blurred copy of the image to the filepath provided.
#         """
#
#         gaussianBlur = ndimage.gaussian_filter(plt.imread(filePath), sigma=5.11)
#         self.writeImage(gaussianPath, gaussianBlur)
#         self.filesMade += 1
#         print("Gaussian image written to: " + gaussianPath)
#
#         if show is True:
#             plt.imshow(gaussianBlur)
#             plt.show()
#
#         return gaussianBlur
# ```
#
# ## Translation
#
# Translation is a type of Affine Transformation and basically repositions the image within itself. The function below uses the cv2.warpAffine function. The created images will be saved to the relevant directories in the default configuration.
#
# ```
#     def translate(self, image, translatedPath, show = False):
#
#         """
#         Writes transformed copy of the image to the filepath provided.
#         """
#
#         cols, rows, chs = image.shape
#
#         translated = cv2.warpAffine(image, np.float32([[1, 0, 84], [0, 1, 56]]), (rows, cols),
#                                     borderMode=cv2.BORDER_CONSTANT, borderValue=(144, 159, 162))
#
#         self.writeImage(filePath, translated)
#         self.filesMade += 1
#         print("Translated image written to: " + filePath)
#
#         if show is True:
#             plt.imshow(translated)
#             plt.show()
#
#         return translated
# ```
#
# ## Rotation
#
# Gaussian Blur is a popular technique used on images and is especially popular in the computer vision world. The function below uses the ndimage.gaussian_filter function. The created images will be saved to the relevant directories in the default configuration.
#
# ```
#     def rotation(self, path, filePath, filename, show=False):
#             """
#             Writes rotated copies of the image to the filepath provided.
#             """
#
#             img = Image.open(filePath)
#
#             image = cv2.imread(filePath)
#             cols, rows, chs = image.shape
#
#             for i in range(0, 20):
#                 # Seed needs to be set each time randint is called
#                 random.seed(self.seed)
#                 randDeg = random.randint(-180, 180)
#                 matrix = cv2.getRotationMatrix2D((cols/2, rows/2), randDeg, 0.70)
#                 rotated = cv2.warpAffine(image, matrix, (rows, cols), borderMode=cv2.BORDER_CONSTANT,
#                                         borderValue=(144, 159, 162))
#                 fullPath = os.path.join(
#                     path, str(randDeg) + '-' + str(i) + '-' + filename)
#
#                 self.writeImage(fullPath, rotated)
#                 self.filesMade += 1
#                 print("Rotated image written to: " + fullPath)
#
#                 if show is True:
#                     plt.imshow(rotated)
#                     plt.show()
# ```
#
# # Augment your data
# You can use the code below to augment your data. The full Python class that holds the core data functions can be found in [Classes/Data.py](Classes/Data.py). The AMLDnnData class below is a wrapper class around the Data class that allows you to run the code in this Notebook. Follow the steps below and execute the code blocks using __SHIFT + ENTER__.
#
# ## Sort your dataset
# The **ALL_IDB_1** dataset is the one used in this tutorial. In this dataset there were 59 negative and 49 positive. To make this even I removed 10 images from the negative dataset. From here I removed a further 10 images per class for testing further on in the tutorial and for the purpose of demos etc. In my case I ended up with 20 test images (10 pos/10 neg) and 49 images per class ready for augmentation. Place the original images that you wish to augment into the **Model/Data/0** & **Model/Data/1**. Using this program I was able to create a dataset of **1053** positive and **1053** negative augmented images.
#
#
# ## Import required libraries
# We are going to run the above code in the browser, to do this you need to run the following code. Execute the code block by placing your cursor inside and clicking __shift__ & __enter__.

# %%
import matplotlib.pyplot as plt

# %matplotlib inline
plt.rcParams['figure.figsize'] = (5.0, 4.0) 
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

from Classes.Data import Data

# %% [markdown]
# ## Initiate the data wrapper
# The following Python class is a wrapper for the [Data (Classes/Data.py)](Classes/Data.py) class.

# %%
class ALLData():
    
    def __init__(self):
        
        ###############################################################
        #
        # Sets up all default requirements and placeholders 
        # needed for the Acute Myeloid Leukemia Classifier. 
        #
        ###############################################################

        self.Data = Data()
        
    def processDataset(self):
        
        ###############################################################
        #
        # Make sure you have your equal amounts of positive and negative
        # samples in the Model/Data directories.
        # 
        # Only run this function once! it will continually make copies 
        # of all images in the Settings->TrainDir directory specified 
        # in Required/confs.json        
        #
        ###############################################################
        
        self.Data.processDataset() 
        
ALLData = ALLData()

# %% [markdown]
# ## Augment the dataset
#
# Make sure you have your equal amounts of positive and negative samples in the Model/Data directories, in my program I use the directories 0 and 1, but you can name them what you like as long as they are integers.
#
# __Only run this function once! it will continually make copies of all images in the Settings->TrainDir directory specified in Required/confs.json__
#
# Execute the following code block to process the dataset by running all of the functions shown above. You may see slides that are a strange color or not square, you can ignore this as the actual saved image is correct.

# %%
# Only run once!
ALLData.processDataset()
# Out:
# Resized image written to: Model/Augmented/1/Im011_1.jpg
# Grayscaled image written to: Model/Augmented/1/Gray-Im011_1.jpg
# Histogram equalized image written to: Model/Augmented/1/Hist-Im011_1.jpg
# Horizontally reflected image written to: Model/Augmented/1/Hor-Im011_1.jpg
# Vertical reflected image written to: Model/Augmented/1/Ver-Im011_1.jpg
# Gaussian image written to: Model/Augmented/1/Gaus-Im011_1.jpg
# Translated image written to: Model/Augmented/1/Trans-Im011_1.jpg
# Rotated image written to: Model/Augmented/1/-152-0-Im011_1.jpg
# Rotated image written to: Model/Augmented/1/-152-1-Im011_1.jpg
# Rotated image written to: Model/Augmented/1/-152-2-Im011_1.jpg
# Rotated image written to: Model/Augmented/1/-152-3-Im011_1.jpg
# Rotated image written to: Model/Augmented/1/-152-4-Im011_1.jpg
# Rotated image written to: Model/Augmented/1/-152-5-Im011_1.jpg
# Rotated image written to: Model/Augmented/1/-152-6-Im011_1.jpg
# Rotated image written to: Model/Augmented/1/-152-7-Im011_1.jpg
# Rotated image written to: Model/Augmented/1/-152-8-Im011_1.jpg
# Rotated image written to: Model/Augmented/1/-152-9-Im011_1.jpg
# Rotated image written to: Model/Augmented/1/-152-10-Im011_1.jpg
# Rotated image written to: Model/Augmented/1/-152-11-Im011_1.jpg
# Rotated image written to: Model/Augmented/1/-152-12-Im011_1.jpg
# Rotated image written to: Model/Augmented/1/-152-13-Im011_1.jpg
# Rotated image written to: Model/Augmented/1/-152-14-Im011_1.jpg
# Rotated image written to: Model/Augmented/1/-152-15-Im011_1.jpg
# Rotated image written to: Model/Augmented/1/-152-16-Im011_1.jpg
# Rotated image written to: Model/Augmented/1/-152-17-Im011_1.jpg
# Rotated image written to: Model/Augmented/1/-152-18-Im011_1.jpg
# Rotated image written to: Model/Augmented/1/-152-19-Im011_1.jpg
# Total augmented files created so far 27
#
# Resized image written to: Model/Augmented/1/Im013_1.jpg
# Grayscaled image written to: Model/Augmented/1/Gray-Im013_1.jpg
# Histogram equalized image written to: Model/Augmented/1/Hist-Im013_1.jpg
# Horizontally reflected image written to: Model/Augmented/1/Hor-Im013_1.jpg
# Vertical reflected image written to: Model/Augmented/1/Ver-Im013_1.jpg
# Gaussian image written to: Model/Augmented/1/Gaus-Im013_1.jpg
# Translated image written to: Model/Augmented/1/Trans-Im013_1.jpg
# Rotated image written to: Model/Augmented/1/-152-0-Im013_1.jpg
# Rotated image written to: Model/Augmented/1/-152-1-Im013_1.jpg
# Rotated image written to: Model/Augmented/1/-152-2-Im013_1.jpg
# Rotated image written to: Model/Augmented/1/-152-3-Im013_1.jpg
# Rotated image written to: Model/Augmented/1/-152-4-Im013_1.jpg
# Rotated image written to: Model/Augmented/1/-152-5-Im013_1.jpg
# Rotated image written to: Model/Augmented/1/-152-6-Im013_1.jpg
# Rotated image written to: Model/Augmented/1/-152-7-Im013_1.jpg
# Rotated image written to: Model/Augmented/1/-152-8-Im013_1.jpg
# Rotated image written to: Model/Augmented/1/-152-9-Im013_1.jpg
# Rotated image written to: Model/Augmented/1/-152-10-Im013_1.jpg
# Rotated image written to: Model/Augmented/1/-152-11-Im013_1.jpg
# Rotated image written to: Model/Augmented/1/-152-12-Im013_1.jpg
# Rotated image written to: Model/Augmented/1/-152-13-Im013_1.jpg
# Rotated image written to: Model/Augmented/1/-152-14-Im013_1.jpg
# Rotated image written to: Model/Augmented/1/-152-15-Im013_1.jpg
# Rotated image written to: Model/Augmented/1/-152-16-Im013_1.jpg
# Rotated image written to: Model/Augmented/1/-152-17-Im013_1.jpg
# Rotated image written to: Model/Augmented/1/-152-18-Im013_1.jpg
# Rotated image written to: Model/Augmented/1/-152-19-Im013_1.jpg
# Total augmented files created so far 54
#
# Resized image written to: Model/Augmented/1/Im062_1.jpg
# Grayscaled image written to: Model/Augmented/1/Gray-Im062_1.jpg
# Histogram equalized image written to: Model/Augmented/1/Hist-Im062_1.jpg
# Horizontally reflected image written to: Model/Augmented/1/Hor-Im062_1.jpg
# Vertical reflected image written to: Model/Augmented/1/Ver-Im062_1.jpg
# Gaussian image written to: Model/Augmented/1/Gaus-Im062_1.jpg
# Translated image written to: Model/Augmented/1/Trans-Im062_1.jpg
# Rotated image written to: Model/Augmented/1/-152-0-Im062_1.jpg
# Rotated image written to: Model/Augmented/1/-152-1-Im062_1.jpg
# Rotated image written to: Model/Augmented/1/-152-2-Im062_1.jpg
# Rotated image written to: Model/Augmented/1/-152-3-Im062_1.jpg
# Rotated image written to: Model/Augmented/1/-152-4-Im062_1.jpg
# Rotated image written to: Model/Augmented/1/-152-5-Im062_1.jpg
# Rotated image written to: Model/Augmented/1/-152-6-Im062_1.jpg
# Rotated image written to: Model/Augmented/1/-152-7-Im062_1.jpg
# Rotated image written to: Model/Augmented/1/-152-8-Im062_1.jpg
# Rotated image written to: Model/Augmented/1/-152-9-Im062_1.jpg
# Rotated image written to: Model/Augmented/1/-152-10-Im062_1.jpg
# Rotated image written to: Model/Augmented/1/-152-11-Im062_1.jpg
# Rotated image written to: Model/Augmented/1/-152-12-Im062_1.jpg
# Rotated image written to: Model/Augmented/1/-152-13-Im062_1.jpg
# Rotated image written to: Model/Augmented/1/-152-14-Im062_1.jpg
# Rotated image written to: Model/Augmented/1/-152-15-Im062_1.jpg
# Rotated image written to: Model/Augmented/1/-152-16-Im062_1.jpg
# Rotated image written to: Model/Augmented/1/-152-17-Im062_1.jpg
# Rotated image written to: Model/Augmented/1/-152-18-Im062_1.jpg
# Rotated image written to: Model/Augmented/1/-152-19-Im062_1.jpg
# Total augmented files created so far 81
#
# Resized image written to: Model/Augmented/1/Im027_1.jpg
# Grayscaled image written to: Model/Augmented/1/Gray-Im027_1.jpg
# Histogram equalized image written to: Model/Augmented/1/Hist-Im027_1.jpg
# Horizontally reflected image written to: Model/Augmented/1/Hor-Im027_1.jpg
# Vertical reflected image written to: Model/Augmented/1/Ver-Im027_1.jpg
# Gaussian image written to: Model/Augmented/1/Gaus-Im027_1.jpg
# Translated image written to: Model/Augmented/1/Trans-Im027_1.jpg
# Rotated image written to: Model/Augmented/1/-152-0-Im027_1.jpg
# Rotated image written to: Model/Augmented/1/-152-1-Im027_1.jpg
# Rotated image written to: Model/Augmented/1/-152-2-Im027_1.jpg
# Rotated image written to: Model/Augmented/1/-152-3-Im027_1.jpg
# Rotated image written to: Model/Augmented/1/-152-4-Im027_1.jpg
# Rotated image written to: Model/Augmented/1/-152-5-Im027_1.jpg
# Rotated image written to: Model/Augmented/1/-152-6-Im027_1.jpg
# Rotated image written to: Model/Augmented/1/-152-7-Im027_1.jpg
# Rotated image written to: Model/Augmented/1/-152-8-Im027_1.jpg
# Rotated image written to: Model/Augmented/1/-152-9-Im027_1.jpg
# Rotated image written to: Model/Augmented/1/-152-10-Im027_1.jpg
# Rotated image written to: Model/Augmented/1/-152-11-Im027_1.jpg
# Rotated image written to: Model/Augmented/1/-152-12-Im027_1.jpg
# Rotated image written to: Model/Augmented/1/-152-13-Im027_1.jpg
# Rotated image written to: Model/Augmented/1/-152-14-Im027_1.jpg
# Rotated image written to: Model/Augmented/1/-152-15-Im027_1.jpg
# Rotated image written to: Model/Augmented/1/-152-16-Im027_1.jpg
# Rotated image written to: Model/Augmented/1/-152-17-Im027_1.jpg
# Rotated image written to: Model/Augmented/1/-152-18-Im027_1.jpg
# Rotated image written to: Model/Augmented/1/-152-19-Im027_1.jpg
# Total augmented files created so far 108
#
# Resized image written to: Model/Augmented/1/Im017_1.jpg
# Grayscaled image written to: Model/Augmented/1/Gray-Im017_1.jpg
# Histogram equalized image written to: Model/Augmented/1/Hist-Im017_1.jpg
# Horizontally reflected image written to: Model/Augmented/1/Hor-Im017_1.jpg
# Vertical reflected image written to: Model/Augmented/1/Ver-Im017_1.jpg
# Gaussian image written to: Model/Augmented/1/Gaus-Im017_1.jpg
# Translated image written to: Model/Augmented/1/Trans-Im017_1.jpg
# Rotated image written to: Model/Augmented/1/-152-0-Im017_1.jpg
# Rotated image written to: Model/Augmented/1/-152-1-Im017_1.jpg
# Rotated image written to: Model/Augmented/1/-152-2-Im017_1.jpg
# Rotated image written to: Model/Augmented/1/-152-3-Im017_1.jpg
# Rotated image written to: Model/Augmented/1/-152-4-Im017_1.jpg
# Rotated image written to: Model/Augmented/1/-152-5-Im017_1.jpg
# Rotated image written to: Model/Augmented/1/-152-6-Im017_1.jpg
# Rotated image written to: Model/Augmented/1/-152-7-Im017_1.jpg
# Rotated image written to: Model/Augmented/1/-152-8-Im017_1.jpg
# Rotated image written to: Model/Augmented/1/-152-9-Im017_1.jpg
# Rotated image written to: Model/Augmented/1/-152-10-Im017_1.jpg
# Rotated image written to: Model/Augmented/1/-152-11-Im017_1.jpg
# Rotated image written to: Model/Augmented/1/-152-12-Im017_1.jpg
# Rotated image written to: Model/Augmented/1/-152-13-Im017_1.jpg
# Rotated image written to: Model/Augmented/1/-152-14-Im017_1.jpg
# Rotated image written to: Model/Augmented/1/-152-15-Im017_1.jpg
# Rotated image written to: Model/Augmented/1/-152-16-Im017_1.jpg
# Rotated image written to: Model/Augmented/1/-152-17-Im017_1.jpg
# Rotated image written to: Model/Augmented/1/-152-18-Im017_1.jpg
# Rotated image written to: Model/Augmented/1/-152-19-Im017_1.jpg
# Total augmented files created so far 135
#
# Resized image written to: Model/Augmented/1/Im005_1.jpg
# Grayscaled image written to: Model/Augmented/1/Gray-Im005_1.jpg
# Histogram equalized image written to: Model/Augmented/1/Hist-Im005_1.jpg
# Horizontally reflected image written to: Model/Augmented/1/Hor-Im005_1.jpg
# Vertical reflected image written to: Model/Augmented/1/Ver-Im005_1.jpg
# Gaussian image written to: Model/Augmented/1/Gaus-Im005_1.jpg
# Translated image written to: Model/Augmented/1/Trans-Im005_1.jpg
# Rotated image written to: Model/Augmented/1/-152-0-Im005_1.jpg
# Rotated image written to: Model/Augmented/1/-152-1-Im005_1.jpg
# Rotated image written to: Model/Augmented/1/-152-2-Im005_1.jpg
# Rotated image written to: Model/Augmented/1/-152-3-Im005_1.jpg
# Rotated image written to: Model/Augmented/1/-152-4-Im005_1.jpg
# Rotated image written to: Model/Augmented/1/-152-5-Im005_1.jpg
# Rotated image written to: Model/Augmented/1/-152-6-Im005_1.jpg
# Rotated image written to: Model/Augmented/1/-152-7-Im005_1.jpg
# Rotated image written to: Model/Augmented/1/-152-8-Im005_1.jpg
# Rotated image written to: Model/Augmented/1/-152-9-Im005_1.jpg
# Rotated image written to: Model/Augmented/1/-152-10-Im005_1.jpg
# Rotated image written to: Model/Augmented/1/-152-11-Im005_1.jpg
# Rotated image written to: Model/Augmented/1/-152-12-Im005_1.jpg
# Rotated image written to: Model/Augmented/1/-152-13-Im005_1.jpg
# Rotated image written to: Model/Augmented/1/-152-14-Im005_1.jpg
# Rotated image written to: Model/Augmented/1/-152-15-Im005_1.jpg
# Rotated image written to: Model/Augmented/1/-152-16-Im005_1.jpg
# Rotated image written to: Model/Augmented/1/-152-17-Im005_1.jpg
# Rotated image written to: Model/Augmented/1/-152-18-Im005_1.jpg
# Rotated image written to: Model/Augmented/1/-152-19-Im005_1.jpg
# Total augmented files created so far 162
#
# Resized image written to: Model/Augmented/1/Im055_1.jpg
# Grayscaled image written to: Model/Augmented/1/Gray-Im055_1.jpg
# Histogram equalized image written to: Model/Augmented/1/Hist-Im055_1.jpg
# Horizontally reflected image written to: Model/Augmented/1/Hor-Im055_1.jpg
# Vertical reflected image written to: Model/Augmented/1/Ver-Im055_1.jpg
# Gaussian image written to: Model/Augmented/1/Gaus-Im055_1.jpg
# Translated image written to: Model/Augmented/1/Trans-Im055_1.jpg
# Rotated image written to: Model/Augmented/1/-152-0-Im055_1.jpg
# Rotated image written to: Model/Augmented/1/-152-1-Im055_1.jpg
# Rotated image written to: Model/Augmented/1/-152-2-Im055_1.jpg
# Rotated image written to: Model/Augmented/1/-152-3-Im055_1.jpg
# Rotated image written to: Model/Augmented/1/-152-4-Im055_1.jpg
# Rotated image written to: Model/Augmented/1/-152-5-Im055_1.jpg
# Rotated image written to: Model/Augmented/1/-152-6-Im055_1.jpg
# Rotated image written to: Model/Augmented/1/-152-7-Im055_1.jpg
# Rotated image written to: Model/Augmented/1/-152-8-Im055_1.jpg
# Rotated image written to: Model/Augmented/1/-152-9-Im055_1.jpg
# Rotated image written to: Model/Augmented/1/-152-10-Im055_1.jpg
# Rotated image written to: Model/Augmented/1/-152-11-Im055_1.jpg
# Rotated image written to: Model/Augmented/1/-152-12-Im055_1.jpg
# Rotated image written to: Model/Augmented/1/-152-13-Im055_1.jpg
# Rotated image written to: Model/Augmented/1/-152-14-Im055_1.jpg
# Rotated image written to: Model/Augmented/1/-152-15-Im055_1.jpg
# Rotated image written to: Model/Augmented/1/-152-16-Im055_1.jpg
# Rotated image written to: Model/Augmented/1/-152-17-Im055_1.jpg
# Rotated image written to: Model/Augmented/1/-152-18-Im055_1.jpg
# Rotated image written to: Model/Augmented/1/-152-19-Im055_1.jpg
# Total augmented files created so far 189
#
# Resized image written to: Model/Augmented/1/Im015_1.jpg
# Grayscaled image written to: Model/Augmented/1/Gray-Im015_1.jpg
# Histogram equalized image written to: Model/Augmented/1/Hist-Im015_1.jpg
# Horizontally reflected image written to: Model/Augmented/1/Hor-Im015_1.jpg
# Vertical reflected image written to: Model/Augmented/1/Ver-Im015_1.jpg
# Gaussian image written to: Model/Augmented/1/Gaus-Im015_1.jpg
# Translated image written to: Model/Augmented/1/Trans-Im015_1.jpg
# Rotated image written to: Model/Augmented/1/-152-0-Im015_1.jpg
# Rotated image written to: Model/Augmented/1/-152-1-Im015_1.jpg
# Rotated image written to: Model/Augmented/1/-152-2-Im015_1.jpg
# Rotated image written to: Model/Augmented/1/-152-3-Im015_1.jpg
# Rotated image written to: Model/Augmented/1/-152-4-Im015_1.jpg
# Rotated image written to: Model/Augmented/1/-152-5-Im015_1.jpg
# Rotated image written to: Model/Augmented/1/-152-6-Im015_1.jpg
# Rotated image written to: Model/Augmented/1/-152-7-Im015_1.jpg
# Rotated image written to: Model/Augmented/1/-152-8-Im015_1.jpg
# Rotated image written to: Model/Augmented/1/-152-9-Im015_1.jpg
# Rotated image written to: Model/Augmented/1/-152-10-Im015_1.jpg
# Rotated image written to: Model/Augmented/1/-152-11-Im015_1.jpg
# Rotated image written to: Model/Augmented/1/-152-12-Im015_1.jpg
# Rotated image written to: Model/Augmented/1/-152-13-Im015_1.jpg
# Rotated image written to: Model/Augmented/1/-152-14-Im015_1.jpg
# Rotated image written to: Model/Augmented/1/-152-15-Im015_1.jpg
# Rotated image written to: Model/Augmented/1/-152-16-Im015_1.jpg
# Rotated image written to: Model/Augmented/1/-152-17-Im015_1.jpg
# Rotated image written to: Model/Augmented/1/-152-18-Im015_1.jpg
# Rotated image written to: Model/Augmented/1/-152-19-Im015_1.jpg
# Total augmented files created so far 216
#
# Resized image written to: Model/Augmented/1/Im019_1.jpg
# Grayscaled image written to: Model/Augmented/1/Gray-Im019_1.jpg
# Histogram equalized image written to: Model/Augmented/1/Hist-Im019_1.jpg
# Horizontally reflected image written to: Model/Augmented/1/Hor-Im019_1.jpg
# Vertical reflected image written to: Model/Augmented/1/Ver-Im019_1.jpg
# Gaussian image written to: Model/Augmented/1/Gaus-Im019_1.jpg
# Translated image written to: Model/Augmented/1/Trans-Im019_1.jpg
# Rotated image written to: Model/Augmented/1/-152-0-Im019_1.jpg
# Rotated image written to: Model/Augmented/1/-152-1-Im019_1.jpg
# Rotated image written to: Model/Augmented/1/-152-2-Im019_1.jpg
# Rotated image written to: Model/Augmented/1/-152-3-Im019_1.jpg
# Rotated image written to: Model/Augmented/1/-152-4-Im019_1.jpg
# Rotated image written to: Model/Augmented/1/-152-5-Im019_1.jpg
# Rotated image written to: Model/Augmented/1/-152-6-Im019_1.jpg
# Rotated image written to: Model/Augmented/1/-152-7-Im019_1.jpg
# Rotated image written to: Model/Augmented/1/-152-8-Im019_1.jpg
# Rotated image written to: Model/Augmented/1/-152-9-Im019_1.jpg
# Rotated image written to: Model/Augmented/1/-152-10-Im019_1.jpg
# Rotated image written to: Model/Augmented/1/-152-11-Im019_1.jpg
# Rotated image written to: Model/Augmented/1/-152-12-Im019_1.jpg
# Rotated image written to: Model/Augmented/1/-152-13-Im019_1.jpg
# Rotated image written to: Model/Augmented/1/-152-14-Im019_1.jpg
# Rotated image written to: Model/Augmented/1/-152-15-Im019_1.jpg
# Rotated image written to: Model/Augmented/1/-152-16-Im019_1.jpg
# Rotated image written to: Model/Augmented/1/-152-17-Im019_1.jpg
# Rotated image written to: Model/Augmented/1/-152-18-Im019_1.jpg
# Rotated image written to: Model/Augmented/1/-152-19-Im019_1.jpg
# Total augmented files created so far 243
#
# Resized image written to: Model/Augmented/1/Im012_1.jpg
# Grayscaled image written to: Model/Augmented/1/Gray-Im012_1.jpg
# Histogram equalized image written to: Model/Augmented/1/Hist-Im012_1.jpg
# Horizontally reflected image written to: Model/Augmented/1/Hor-Im012_1.jpg
# Vertical reflected image written to: Model/Augmented/1/Ver-Im012_1.jpg
# Gaussian image written to: Model/Augmented/1/Gaus-Im012_1.jpg
# Translated image written to: Model/Augmented/1/Trans-Im012_1.jpg
# Rotated image written to: Model/Augmented/1/-152-0-Im012_1.jpg
# Rotated image written to: Model/Augmented/1/-152-1-Im012_1.jpg
# Rotated image written to: Model/Augmented/1/-152-2-Im012_1.jpg
# Rotated image written to: Model/Augmented/1/-152-3-Im012_1.jpg
# Rotated image written to: Model/Augmented/1/-152-4-Im012_1.jpg
# Rotated image written to: Model/Augmented/1/-152-5-Im012_1.jpg
# Rotated image written to: Model/Augmented/1/-152-6-Im012_1.jpg
# Rotated image written to: Model/Augmented/1/-152-7-Im012_1.jpg
# Rotated image written to: Model/Augmented/1/-152-8-Im012_1.jpg
# Rotated image written to: Model/Augmented/1/-152-9-Im012_1.jpg
# Rotated image written to: Model/Augmented/1/-152-10-Im012_1.jpg
# Rotated image written to: Model/Augmented/1/-152-11-Im012_1.jpg
# Rotated image written to: Model/Augmented/1/-152-12-Im012_1.jpg
# Rotated image written to: Model/Augmented/1/-152-13-Im012_1.jpg
# Rotated image written to: Model/Augmented/1/-152-14-Im012_1.jpg
# Rotated image written to: Model/Augmented/1/-152-15-Im012_1.jpg
# Rotated image written to: Model/Augmented/1/-152-16-Im012_1.jpg
# Rotated image written to: Model/Augmented/1/-152-17-Im012_1.jpg
# Rotated image written to: Model/Augmented/1/-152-18-Im012_1.jpg
# Rotated image written to: Model/Augmented/1/-152-19-Im012_1.jpg
# Total augmented files created so far 270
#
# Resized image written to: Model/Augmented/1/Im048_1.jpg
# Grayscaled image written to: Model/Augmented/1/Gray-Im048_1.jpg
# Histogram equalized image written to: Model/Augmented/1/Hist-Im048_1.jpg
# Horizontally reflected image written to: Model/Augmented/1/Hor-Im048_1.jpg
# Vertical reflected image written to: Model/Augmented/1/Ver-Im048_1.jpg
# Gaussian image written to: Model/Augmented/1/Gaus-Im048_1.jpg
# Translated image written to: Model/Augmented/1/Trans-Im048_1.jpg
# Rotated image written to: Model/Augmented/1/-152-0-Im048_1.jpg
# Rotated image written to: Model/Augmented/1/-152-1-Im048_1.jpg
# Rotated image written to: Model/Augmented/1/-152-2-Im048_1.jpg
# Rotated image written to: Model/Augmented/1/-152-3-Im048_1.jpg
# Rotated image written to: Model/Augmented/1/-152-4-Im048_1.jpg
# Rotated image written to: Model/Augmented/1/-152-5-Im048_1.jpg
# Rotated image written to: Model/Augmented/1/-152-6-Im048_1.jpg
# Rotated image written to: Model/Augmented/1/-152-7-Im048_1.jpg
# Rotated image written to: Model/Augmented/1/-152-8-Im048_1.jpg
# Rotated image written to: Model/Augmented/1/-152-9-Im048_1.jpg
# Rotated image written to: Model/Augmented/1/-152-10-Im048_1.jpg
# Rotated image written to: Model/Augmented/1/-152-11-Im048_1.jpg
# Rotated image written to: Model/Augmented/1/-152-12-Im048_1.jpg
# Rotated image written to: Model/Augmented/1/-152-13-Im048_1.jpg
# Rotated image written to: Model/Augmented/1/-152-14-Im048_1.jpg
# Rotated image written to: Model/Augmented/1/-152-15-Im048_1.jpg
# Rotated image written to: Model/Augmented/1/-152-16-Im048_1.jpg
# Rotated image written to: Model/Augmented/1/-152-17-Im048_1.jpg
# Rotated image written to: Model/Augmented/1/-152-18-Im048_1.jpg
# Rotated image written to: Model/Augmented/1/-152-19-Im048_1.jpg
# Total augmented files created so far 297
#
# Resized image written to: Model/Augmented/1/Im049_1.jpg
# Grayscaled image written to: Model/Augmented/1/Gray-Im049_1.jpg
# Histogram equalized image written to: Model/Augmented/1/Hist-Im049_1.jpg
# Horizontally reflected image written to: Model/Augmented/1/Hor-Im049_1.jpg
# Vertical reflected image written to: Model/Augmented/1/Ver-Im049_1.jpg
# Gaussian image written to: Model/Augmented/1/Gaus-Im049_1.jpg
# Translated image written to: Model/Augmented/1/Trans-Im049_1.jpg
# Rotated image written to: Model/Augmented/1/-152-0-Im049_1.jpg
# Rotated image written to: Model/Augmented/1/-152-1-Im049_1.jpg
# Rotated image written to: Model/Augmented/1/-152-2-Im049_1.jpg
# Rotated image written to: Model/Augmented/1/-152-3-Im049_1.jpg
# Rotated image written to: Model/Augmented/1/-152-4-Im049_1.jpg
# Rotated image written to: Model/Augmented/1/-152-5-Im049_1.jpg
# Rotated image written to: Model/Augmented/1/-152-6-Im049_1.jpg
# Rotated image written to: Model/Augmented/1/-152-7-Im049_1.jpg
# Rotated image written to: Model/Augmented/1/-152-8-Im049_1.jpg
# Rotated image written to: Model/Augmented/1/-152-9-Im049_1.jpg
# Rotated image written to: Model/Augmented/1/-152-10-Im049_1.jpg
# Rotated image written to: Model/Augmented/1/-152-11-Im049_1.jpg
# Rotated image written to: Model/Augmented/1/-152-12-Im049_1.jpg
# Rotated image written to: Model/Augmented/1/-152-13-Im049_1.jpg
# Rotated image written to: Model/Augmented/1/-152-14-Im049_1.jpg
# Rotated image written to: Model/Augmented/1/-152-15-Im049_1.jpg
# Rotated image written to: Model/Augmented/1/-152-16-Im049_1.jpg
# Rotated image written to: Model/Augmented/1/-152-17-Im049_1.jpg
# Rotated image written to: Model/Augmented/1/-152-18-Im049_1.jpg
# Rotated image written to: Model/Augmented/1/-152-19-Im049_1.jpg
# Total augmented files created so far 324
#
# Resized image written to: Model/Augmented/1/Im033_1.jpg
# Grayscaled image written to: Model/Augmented/1/Gray-Im033_1.jpg
# Histogram equalized image written to: Model/Augmented/1/Hist-Im033_1.jpg
# Horizontally reflected image written to: Model/Augmented/1/Hor-Im033_1.jpg
# Vertical reflected image written to: Model/Augmented/1/Ver-Im033_1.jpg
# Gaussian image written to: Model/Augmented/1/Gaus-Im033_1.jpg
# Translated image written to: Model/Augmented/1/Trans-Im033_1.jpg
# Rotated image written to: Model/Augmented/1/-152-0-Im033_1.jpg
# Rotated image written to: Model/Augmented/1/-152-1-Im033_1.jpg
# Rotated image written to: Model/Augmented/1/-152-2-Im033_1.jpg
# Rotated image written to: Model/Augmented/1/-152-3-Im033_1.jpg
# Rotated image written to: Model/Augmented/1/-152-4-Im033_1.jpg
# Rotated image written to: Model/Augmented/1/-152-5-Im033_1.jpg
# Rotated image written to: Model/Augmented/1/-152-6-Im033_1.jpg
# Rotated image written to: Model/Augmented/1/-152-7-Im033_1.jpg
# Rotated image written to: Model/Augmented/1/-152-8-Im033_1.jpg
# Rotated image written to: Model/Augmented/1/-152-9-Im033_1.jpg
# Rotated image written to: Model/Augmented/1/-152-10-Im033_1.jpg
# Rotated image written to: Model/Augmented/1/-152-11-Im033_1.jpg
# Rotated image written to: Model/Augmented/1/-152-12-Im033_1.jpg
# Rotated image written to: Model/Augmented/1/-152-13-Im033_1.jpg
# Rotated image written to: Model/Augmented/1/-152-14-Im033_1.jpg
# Rotated image written to: Model/Augmented/1/-152-15-Im033_1.jpg
# Rotated image written to: Model/Augmented/1/-152-16-Im033_1.jpg
# Rotated image written to: Model/Augmented/1/-152-17-Im033_1.jpg
# Rotated image written to: Model/Augmented/1/-152-18-Im033_1.jpg
# Rotated image written to: Model/Augmented/1/-152-19-Im033_1.jpg
# Total augmented files created so far 351
#
# Resized image written to: Model/Augmented/1/Im056_1.jpg
# Grayscaled image written to: Model/Augmented/1/Gray-Im056_1.jpg
# Histogram equalized image written to: Model/Augmented/1/Hist-Im056_1.jpg
# Horizontally reflected image written to: Model/Augmented/1/Hor-Im056_1.jpg
# Vertical reflected image written to: Model/Augmented/1/Ver-Im056_1.jpg
# Gaussian image written to: Model/Augmented/1/Gaus-Im056_1.jpg
# Translated image written to: Model/Augmented/1/Trans-Im056_1.jpg
# Rotated image written to: Model/Augmented/1/-152-0-Im056_1.jpg
# Rotated image written to: Model/Augmented/1/-152-1-Im056_1.jpg
# Rotated image written to: Model/Augmented/1/-152-2-Im056_1.jpg
# Rotated image written to: Model/Augmented/1/-152-3-Im056_1.jpg
# Rotated image written to: Model/Augmented/1/-152-4-Im056_1.jpg
# Rotated image written to: Model/Augmented/1/-152-5-Im056_1.jpg
# Rotated image written to: Model/Augmented/1/-152-6-Im056_1.jpg
# Rotated image written to: Model/Augmented/1/-152-7-Im056_1.jpg
# Rotated image written to: Model/Augmented/1/-152-8-Im056_1.jpg
# Rotated image written to: Model/Augmented/1/-152-9-Im056_1.jpg
# Rotated image written to: Model/Augmented/1/-152-10-Im056_1.jpg
# Rotated image written to: Model/Augmented/1/-152-11-Im056_1.jpg
# Rotated image written to: Model/Augmented/1/-152-12-Im056_1.jpg
# Rotated image written to: Model/Augmented/1/-152-13-Im056_1.jpg
# Rotated image written to: Model/Augmented/1/-152-14-Im056_1.jpg
# Rotated image written to: Model/Augmented/1/-152-15-Im056_1.jpg
# Rotated image written to: Model/Augmented/1/-152-16-Im056_1.jpg
# Rotated image written to: Model/Augmented/1/-152-17-Im056_1.jpg
# Rotated image written to: Model/Augmented/1/-152-18-Im056_1.jpg
# Rotated image written to: Model/Augmented/1/-152-19-Im056_1.jpg
# Total augmented files created so far 378
#
# Resized image written to: Model/Augmented/1/Im009_1.jpg
# Grayscaled image written to: Model/Augmented/1/Gray-Im009_1.jpg
# Histogram equalized image written to: Model/Augmented/1/Hist-Im009_1.jpg
# Horizontally reflected image written to: Model/Augmented/1/Hor-Im009_1.jpg
# Vertical reflected image written to: Model/Augmented/1/Ver-Im009_1.jpg
# Gaussian image written to: Model/Augmented/1/Gaus-Im009_1.jpg
# Translated image written to: Model/Augmented/1/Trans-Im009_1.jpg
# Rotated image written to: Model/Augmented/1/-152-0-Im009_1.jpg
# Rotated image written to: Model/Augmented/1/-152-1-Im009_1.jpg
# Rotated image written to: Model/Augmented/1/-152-2-Im009_1.jpg
# Rotated image written to: Model/Augmented/1/-152-3-Im009_1.jpg
# Rotated image written to: Model/Augmented/1/-152-4-Im009_1.jpg
# Rotated image written to: Model/Augmented/1/-152-5-Im009_1.jpg
# Rotated image written to: Model/Augmented/1/-152-6-Im009_1.jpg
# Rotated image written to: Model/Augmented/1/-152-7-Im009_1.jpg
# Rotated image written to: Model/Augmented/1/-152-8-Im009_1.jpg
# Rotated image written to: Model/Augmented/1/-152-9-Im009_1.jpg
# Rotated image written to: Model/Augmented/1/-152-10-Im009_1.jpg
# Rotated image written to: Model/Augmented/1/-152-11-Im009_1.jpg
# Rotated image written to: Model/Augmented/1/-152-12-Im009_1.jpg
# Rotated image written to: Model/Augmented/1/-152-13-Im009_1.jpg
# Rotated image written to: Model/Augmented/1/-152-14-Im009_1.jpg
# Rotated image written to: Model/Augmented/1/-152-15-Im009_1.jpg
# Rotated image written to: Model/Augmented/1/-152-16-Im009_1.jpg
# Rotated image written to: Model/Augmented/1/-152-17-Im009_1.jpg
# Rotated image written to: Model/Augmented/1/-152-18-Im009_1.jpg
# Rotated image written to: Model/Augmented/1/-152-19-Im009_1.jpg
# Total augmented files created so far 405
#
# Resized image written to: Model/Augmented/1/Im018_1.jpg
# Grayscaled image written to: Model/Augmented/1/Gray-Im018_1.jpg
# Histogram equalized image written to: Model/Augmented/1/Hist-Im018_1.jpg
# Horizontally reflected image written to: Model/Augmented/1/Hor-Im018_1.jpg
# Vertical reflected image written to: Model/Augmented/1/Ver-Im018_1.jpg
# Gaussian image written to: Model/Augmented/1/Gaus-Im018_1.jpg
# Translated image written to: Model/Augmented/1/Trans-Im018_1.jpg
# Rotated image written to: Model/Augmented/1/-152-0-Im018_1.jpg
# Rotated image written to: Model/Augmented/1/-152-1-Im018_1.jpg
# Rotated image written to: Model/Augmented/1/-152-2-Im018_1.jpg
# Rotated image written to: Model/Augmented/1/-152-3-Im018_1.jpg
# Rotated image written to: Model/Augmented/1/-152-4-Im018_1.jpg
# Rotated image written to: Model/Augmented/1/-152-5-Im018_1.jpg
# Rotated image written to: Model/Augmented/1/-152-6-Im018_1.jpg
# Rotated image written to: Model/Augmented/1/-152-7-Im018_1.jpg
# Rotated image written to: Model/Augmented/1/-152-8-Im018_1.jpg
# Rotated image written to: Model/Augmented/1/-152-9-Im018_1.jpg
# Rotated image written to: Model/Augmented/1/-152-10-Im018_1.jpg
# Rotated image written to: Model/Augmented/1/-152-11-Im018_1.jpg
# Rotated image written to: Model/Augmented/1/-152-12-Im018_1.jpg
# Rotated image written to: Model/Augmented/1/-152-13-Im018_1.jpg
# Rotated image written to: Model/Augmented/1/-152-14-Im018_1.jpg
# Rotated image written to: Model/Augmented/1/-152-15-Im018_1.jpg
# Rotated image written to: Model/Augmented/1/-152-16-Im018_1.jpg
# Rotated image written to: Model/Augmented/1/-152-17-Im018_1.jpg
# Rotated image written to: Model/Augmented/1/-152-18-Im018_1.jpg
# Rotated image written to: Model/Augmented/1/-152-19-Im018_1.jpg
# Total augmented files created so far 432
#
# Resized image written to: Model/Augmented/1/Im021_1.jpg
# Grayscaled image written to: Model/Augmented/1/Gray-Im021_1.jpg
# Histogram equalized image written to: Model/Augmented/1/Hist-Im021_1.jpg
# Horizontally reflected image written to: Model/Augmented/1/Hor-Im021_1.jpg
# Vertical reflected image written to: Model/Augmented/1/Ver-Im021_1.jpg
# Gaussian image written to: Model/Augmented/1/Gaus-Im021_1.jpg
# Translated image written to: Model/Augmented/1/Trans-Im021_1.jpg
# Rotated image written to: Model/Augmented/1/-152-0-Im021_1.jpg
# Rotated image written to: Model/Augmented/1/-152-1-Im021_1.jpg
# Rotated image written to: Model/Augmented/1/-152-2-Im021_1.jpg
# Rotated image written to: Model/Augmented/1/-152-3-Im021_1.jpg
# Rotated image written to: Model/Augmented/1/-152-4-Im021_1.jpg
# Rotated image written to: Model/Augmented/1/-152-5-Im021_1.jpg
# Rotated image written to: Model/Augmented/1/-152-6-Im021_1.jpg
# Rotated image written to: Model/Augmented/1/-152-7-Im021_1.jpg
# Rotated image written to: Model/Augmented/1/-152-8-Im021_1.jpg
# Rotated image written to: Model/Augmented/1/-152-9-Im021_1.jpg
# Rotated image written to: Model/Augmented/1/-152-10-Im021_1.jpg
# Rotated image written to: Model/Augmented/1/-152-11-Im021_1.jpg
# Rotated image written to: Model/Augmented/1/-152-12-Im021_1.jpg
# Rotated image written to: Model/Augmented/1/-152-13-Im021_1.jpg
# Rotated image written to: Model/Augmented/1/-152-14-Im021_1.jpg
# Rotated image written to: Model/Augmented/1/-152-15-Im021_1.jpg
# Rotated image written to: Model/Augmented/1/-152-16-Im021_1.jpg
# Rotated image written to: Model/Augmented/1/-152-17-Im021_1.jpg
# Rotated image written to: Model/Augmented/1/-152-18-Im021_1.jpg
# Rotated image written to: Model/Augmented/1/-152-19-Im021_1.jpg
# Total augmented files created so far 459
#
# Resized image written to: Model/Augmented/1/Im025_1.jpg
# Grayscaled image written to: Model/Augmented/1/Gray-Im025_1.jpg
# Histogram equalized image written to: Model/Augmented/1/Hist-Im025_1.jpg
# Horizontally reflected image written to: Model/Augmented/1/Hor-Im025_1.jpg
# Vertical reflected image written to: Model/Augmented/1/Ver-Im025_1.jpg
# Gaussian image written to: Model/Augmented/1/Gaus-Im025_1.jpg
# Translated image written to: Model/Augmented/1/Trans-Im025_1.jpg
# Rotated image written to: Model/Augmented/1/-152-0-Im025_1.jpg
# Rotated image written to: Model/Augmented/1/-152-1-Im025_1.jpg
# Rotated image written to: Model/Augmented/1/-152-2-Im025_1.jpg
# Rotated image written to: Model/Augmented/1/-152-3-Im025_1.jpg
# Rotated image written to: Model/Augmented/1/-152-4-Im025_1.jpg
# Rotated image written to: Model/Augmented/1/-152-5-Im025_1.jpg
# Rotated image written to: Model/Augmented/1/-152-6-Im025_1.jpg
# Rotated image written to: Model/Augmented/1/-152-7-Im025_1.jpg
# Rotated image written to: Model/Augmented/1/-152-8-Im025_1.jpg
# Rotated image written to: Model/Augmented/1/-152-9-Im025_1.jpg
# Rotated image written to: Model/Augmented/1/-152-10-Im025_1.jpg
# Rotated image written to: Model/Augmented/1/-152-11-Im025_1.jpg
# Rotated image written to: Model/Augmented/1/-152-12-Im025_1.jpg
# Rotated image written to: Model/Augmented/1/-152-13-Im025_1.jpg
# Rotated image written to: Model/Augmented/1/-152-14-Im025_1.jpg
# Rotated image written to: Model/Augmented/1/-152-15-Im025_1.jpg
# Rotated image written to: Model/Augmented/1/-152-16-Im025_1.jpg
# Rotated image written to: Model/Augmented/1/-152-17-Im025_1.jpg
# Rotated image written to: Model/Augmented/1/-152-18-Im025_1.jpg
# Rotated image written to: Model/Augmented/1/-152-19-Im025_1.jpg
# Total augmented files created so far 486
#
# Resized image written to: Model/Augmented/1/Im032_1.jpg
# Grayscaled image written to: Model/Augmented/1/Gray-Im032_1.jpg
# Histogram equalized image written to: Model/Augmented/1/Hist-Im032_1.jpg
# Horizontally reflected image written to: Model/Augmented/1/Hor-Im032_1.jpg
# Vertical reflected image written to: Model/Augmented/1/Ver-Im032_1.jpg
# Gaussian image written to: Model/Augmented/1/Gaus-Im032_1.jpg
# Translated image written to: Model/Augmented/1/Trans-Im032_1.jpg
# Rotated image written to: Model/Augmented/1/-152-0-Im032_1.jpg
# Rotated image written to: Model/Augmented/1/-152-1-Im032_1.jpg
# Rotated image written to: Model/Augmented/1/-152-2-Im032_1.jpg
# Rotated image written to: Model/Augmented/1/-152-3-Im032_1.jpg
# Rotated image written to: Model/Augmented/1/-152-4-Im032_1.jpg
# Rotated image written to: Model/Augmented/1/-152-5-Im032_1.jpg
# Rotated image written to: Model/Augmented/1/-152-6-Im032_1.jpg
# Rotated image written to: Model/Augmented/1/-152-7-Im032_1.jpg
# Rotated image written to: Model/Augmented/1/-152-8-Im032_1.jpg
# Rotated image written to: Model/Augmented/1/-152-9-Im032_1.jpg
# Rotated image written to: Model/Augmented/1/-152-10-Im032_1.jpg
# Rotated image written to: Model/Augmented/1/-152-11-Im032_1.jpg
# Rotated image written to: Model/Augmented/1/-152-12-Im032_1.jpg
# Rotated image written to: Model/Augmented/1/-152-13-Im032_1.jpg
# Rotated image written to: Model/Augmented/1/-152-14-Im032_1.jpg
# Rotated image written to: Model/Augmented/1/-152-15-Im032_1.jpg
# Rotated image written to: Model/Augmented/1/-152-16-Im032_1.jpg
# Rotated image written to: Model/Augmented/1/-152-17-Im032_1.jpg
# Rotated image written to: Model/Augmented/1/-152-18-Im032_1.jpg
# Rotated image written to: Model/Augmented/1/-152-19-Im032_1.jpg
# Total augmented files created so far 513
#
# Resized image written to: Model/Augmented/1/Im058_1.jpg
# Grayscaled image written to: Model/Augmented/1/Gray-Im058_1.jpg
# Histogram equalized image written to: Model/Augmented/1/Hist-Im058_1.jpg
# Horizontally reflected image written to: Model/Augmented/1/Hor-Im058_1.jpg
# Vertical reflected image written to: Model/Augmented/1/Ver-Im058_1.jpg
# Gaussian image written to: Model/Augmented/1/Gaus-Im058_1.jpg
# Translated image written to: Model/Augmented/1/Trans-Im058_1.jpg
# Rotated image written to: Model/Augmented/1/-152-0-Im058_1.jpg
# Rotated image written to: Model/Augmented/1/-152-1-Im058_1.jpg
# Rotated image written to: Model/Augmented/1/-152-2-Im058_1.jpg
# Rotated image written to: Model/Augmented/1/-152-3-Im058_1.jpg
# Rotated image written to: Model/Augmented/1/-152-4-Im058_1.jpg
# Rotated image written to: Model/Augmented/1/-152-5-Im058_1.jpg
# Rotated image written to: Model/Augmented/1/-152-6-Im058_1.jpg
# Rotated image written to: Model/Augmented/1/-152-7-Im058_1.jpg
# Rotated image written to: Model/Augmented/1/-152-8-Im058_1.jpg
# Rotated image written to: Model/Augmented/1/-152-9-Im058_1.jpg
# Rotated image written to: Model/Augmented/1/-152-10-Im058_1.jpg
# Rotated image written to: Model/Augmented/1/-152-11-Im058_1.jpg
# Rotated image written to: Model/Augmented/1/-152-12-Im058_1.jpg
# Rotated image written to: Model/Augmented/1/-152-13-Im058_1.jpg
# Rotated image written to: Model/Augmented/1/-152-14-Im058_1.jpg
# Rotated image written to: Model/Augmented/1/-152-15-Im058_1.jpg
# Rotated image written to: Model/Augmented/1/-152-16-Im058_1.jpg
# Rotated image written to: Model/Augmented/1/-152-17-Im058_1.jpg
# Rotated image written to: Model/Augmented/1/-152-18-Im058_1.jpg
# Rotated image written to: Model/Augmented/1/-152-19-Im058_1.jpg
# Total augmented files created so far 540
#
# Resized image written to: Model/Augmented/1/Im010_1.jpg
# Grayscaled image written to: Model/Augmented/1/Gray-Im010_1.jpg
# Histogram equalized image written to: Model/Augmented/1/Hist-Im010_1.jpg
# Horizontally reflected image written to: Model/Augmented/1/Hor-Im010_1.jpg
# Vertical reflected image written to: Model/Augmented/1/Ver-Im010_1.jpg
# Gaussian image written to: Model/Augmented/1/Gaus-Im010_1.jpg
# Translated image written to: Model/Augmented/1/Trans-Im010_1.jpg
# Rotated image written to: Model/Augmented/1/-152-0-Im010_1.jpg
# Rotated image written to: Model/Augmented/1/-152-1-Im010_1.jpg
# Rotated image written to: Model/Augmented/1/-152-2-Im010_1.jpg
# Rotated image written to: Model/Augmented/1/-152-3-Im010_1.jpg
# Rotated image written to: Model/Augmented/1/-152-4-Im010_1.jpg
# Rotated image written to: Model/Augmented/1/-152-5-Im010_1.jpg
# Rotated image written to: Model/Augmented/1/-152-6-Im010_1.jpg
# Rotated image written to: Model/Augmented/1/-152-7-Im010_1.jpg
# Rotated image written to: Model/Augmented/1/-152-8-Im010_1.jpg
# Rotated image written to: Model/Augmented/1/-152-9-Im010_1.jpg
# Rotated image written to: Model/Augmented/1/-152-10-Im010_1.jpg
# Rotated image written to: Model/Augmented/1/-152-11-Im010_1.jpg
# Rotated image written to: Model/Augmented/1/-152-12-Im010_1.jpg
# Rotated image written to: Model/Augmented/1/-152-13-Im010_1.jpg
# Rotated image written to: Model/Augmented/1/-152-14-Im010_1.jpg
# Rotated image written to: Model/Augmented/1/-152-15-Im010_1.jpg
# Rotated image written to: Model/Augmented/1/-152-16-Im010_1.jpg
# Rotated image written to: Model/Augmented/1/-152-17-Im010_1.jpg
# Rotated image written to: Model/Augmented/1/-152-18-Im010_1.jpg
# Rotated image written to: Model/Augmented/1/-152-19-Im010_1.jpg
# Total augmented files created so far 567
#
# Resized image written to: Model/Augmented/1/Im014_1.jpg
# Grayscaled image written to: Model/Augmented/1/Gray-Im014_1.jpg
# Histogram equalized image written to: Model/Augmented/1/Hist-Im014_1.jpg
# Horizontally reflected image written to: Model/Augmented/1/Hor-Im014_1.jpg
# Vertical reflected image written to: Model/Augmented/1/Ver-Im014_1.jpg
# Gaussian image written to: Model/Augmented/1/Gaus-Im014_1.jpg
# Translated image written to: Model/Augmented/1/Trans-Im014_1.jpg
# Rotated image written to: Model/Augmented/1/-152-0-Im014_1.jpg
# Rotated image written to: Model/Augmented/1/-152-1-Im014_1.jpg
# Rotated image written to: Model/Augmented/1/-152-2-Im014_1.jpg
# Rotated image written to: Model/Augmented/1/-152-3-Im014_1.jpg
# Rotated image written to: Model/Augmented/1/-152-4-Im014_1.jpg
# Rotated image written to: Model/Augmented/1/-152-5-Im014_1.jpg
# Rotated image written to: Model/Augmented/1/-152-6-Im014_1.jpg
# Rotated image written to: Model/Augmented/1/-152-7-Im014_1.jpg
# Rotated image written to: Model/Augmented/1/-152-8-Im014_1.jpg
# Rotated image written to: Model/Augmented/1/-152-9-Im014_1.jpg
# Rotated image written to: Model/Augmented/1/-152-10-Im014_1.jpg
# Rotated image written to: Model/Augmented/1/-152-11-Im014_1.jpg
# Rotated image written to: Model/Augmented/1/-152-12-Im014_1.jpg
# Rotated image written to: Model/Augmented/1/-152-13-Im014_1.jpg
# Rotated image written to: Model/Augmented/1/-152-14-Im014_1.jpg
# Rotated image written to: Model/Augmented/1/-152-15-Im014_1.jpg
# Rotated image written to: Model/Augmented/1/-152-16-Im014_1.jpg
# Rotated image written to: Model/Augmented/1/-152-17-Im014_1.jpg
# Rotated image written to: Model/Augmented/1/-152-18-Im014_1.jpg
# Rotated image written to: Model/Augmented/1/-152-19-Im014_1.jpg
# Total augmented files created so far 594
#
# Resized image written to: Model/Augmented/1/Im061_1.jpg
# Grayscaled image written to: Model/Augmented/1/Gray-Im061_1.jpg
# Histogram equalized image written to: Model/Augmented/1/Hist-Im061_1.jpg
# Horizontally reflected image written to: Model/Augmented/1/Hor-Im061_1.jpg
# Vertical reflected image written to: Model/Augmented/1/Ver-Im061_1.jpg
# Gaussian image written to: Model/Augmented/1/Gaus-Im061_1.jpg
# Translated image written to: Model/Augmented/1/Trans-Im061_1.jpg
# Rotated image written to: Model/Augmented/1/-152-0-Im061_1.jpg
# Rotated image written to: Model/Augmented/1/-152-1-Im061_1.jpg
# Rotated image written to: Model/Augmented/1/-152-2-Im061_1.jpg
# Rotated image written to: Model/Augmented/1/-152-3-Im061_1.jpg
# Rotated image written to: Model/Augmented/1/-152-4-Im061_1.jpg
# Rotated image written to: Model/Augmented/1/-152-5-Im061_1.jpg
# Rotated image written to: Model/Augmented/1/-152-6-Im061_1.jpg
# Rotated image written to: Model/Augmented/1/-152-7-Im061_1.jpg
# Rotated image written to: Model/Augmented/1/-152-8-Im061_1.jpg
# Rotated image written to: Model/Augmented/1/-152-9-Im061_1.jpg
# Rotated image written to: Model/Augmented/1/-152-10-Im061_1.jpg
# Rotated image written to: Model/Augmented/1/-152-11-Im061_1.jpg
# Rotated image written to: Model/Augmented/1/-152-12-Im061_1.jpg
# Rotated image written to: Model/Augmented/1/-152-13-Im061_1.jpg
# Rotated image written to: Model/Augmented/1/-152-14-Im061_1.jpg
# Rotated image written to: Model/Augmented/1/-152-15-Im061_1.jpg
# Rotated image written to: Model/Augmented/1/-152-16-Im061_1.jpg
# Rotated image written to: Model/Augmented/1/-152-17-Im061_1.jpg
# Rotated image written to: Model/Augmented/1/-152-18-Im061_1.jpg
# Rotated image written to: Model/Augmented/1/-152-19-Im061_1.jpg
# Total augmented files created so far 621
#
# Resized image written to: Model/Augmented/1/Im008_1.jpg
# Grayscaled image written to: Model/Augmented/1/Gray-Im008_1.jpg
# Histogram equalized image written to: Model/Augmented/1/Hist-Im008_1.jpg
# Horizontally reflected image written to: Model/Augmented/1/Hor-Im008_1.jpg
# Vertical reflected image written to: Model/Augmented/1/Ver-Im008_1.jpg
# Gaussian image written to: Model/Augmented/1/Gaus-Im008_1.jpg
# Translated image written to: Model/Augmented/1/Trans-Im008_1.jpg
# Rotated image written to: Model/Augmented/1/-152-0-Im008_1.jpg
# Rotated image written to: Model/Augmented/1/-152-1-Im008_1.jpg
# Rotated image written to: Model/Augmented/1/-152-2-Im008_1.jpg
# Rotated image written to: Model/Augmented/1/-152-3-Im008_1.jpg
# Rotated image written to: Model/Augmented/1/-152-4-Im008_1.jpg
# Rotated image written to: Model/Augmented/1/-152-5-Im008_1.jpg
# Rotated image written to: Model/Augmented/1/-152-6-Im008_1.jpg
# Rotated image written to: Model/Augmented/1/-152-7-Im008_1.jpg
# Rotated image written to: Model/Augmented/1/-152-8-Im008_1.jpg
# Rotated image written to: Model/Augmented/1/-152-9-Im008_1.jpg
# Rotated image written to: Model/Augmented/1/-152-10-Im008_1.jpg
# Rotated image written to: Model/Augmented/1/-152-11-Im008_1.jpg
# Rotated image written to: Model/Augmented/1/-152-12-Im008_1.jpg
# Rotated image written to: Model/Augmented/1/-152-13-Im008_1.jpg
# Rotated image written to: Model/Augmented/1/-152-14-Im008_1.jpg
# Rotated image written to: Model/Augmented/1/-152-15-Im008_1.jpg
# Rotated image written to: Model/Augmented/1/-152-16-Im008_1.jpg
# Rotated image written to: Model/Augmented/1/-152-17-Im008_1.jpg
# Rotated image written to: Model/Augmented/1/-152-18-Im008_1.jpg
# Rotated image written to: Model/Augmented/1/-152-19-Im008_1.jpg
# Total augmented files created so far 648
#
# Resized image written to: Model/Augmented/1/Im059_1.jpg
# Grayscaled image written to: Model/Augmented/1/Gray-Im059_1.jpg
# Histogram equalized image written to: Model/Augmented/1/Hist-Im059_1.jpg
# Horizontally reflected image written to: Model/Augmented/1/Hor-Im059_1.jpg
# Vertical reflected image written to: Model/Augmented/1/Ver-Im059_1.jpg
# Gaussian image written to: Model/Augmented/1/Gaus-Im059_1.jpg
# Translated image written to: Model/Augmented/1/Trans-Im059_1.jpg
# Rotated image written to: Model/Augmented/1/-152-0-Im059_1.jpg
# Rotated image written to: Model/Augmented/1/-152-1-Im059_1.jpg
# Rotated image written to: Model/Augmented/1/-152-2-Im059_1.jpg
# Rotated image written to: Model/Augmented/1/-152-3-Im059_1.jpg
# Rotated image written to: Model/Augmented/1/-152-4-Im059_1.jpg
# Rotated image written to: Model/Augmented/1/-152-5-Im059_1.jpg
# Rotated image written to: Model/Augmented/1/-152-6-Im059_1.jpg
# Rotated image written to: Model/Augmented/1/-152-7-Im059_1.jpg
# Rotated image written to: Model/Augmented/1/-152-8-Im059_1.jpg
# Rotated image written to: Model/Augmented/1/-152-9-Im059_1.jpg
# Rotated image written to: Model/Augmented/1/-152-10-Im059_1.jpg
# Rotated image written to: Model/Augmented/1/-152-11-Im059_1.jpg
# Rotated image written to: Model/Augmented/1/-152-12-Im059_1.jpg
# Rotated image written to: Model/Augmented/1/-152-13-Im059_1.jpg
# Rotated image written to: Model/Augmented/1/-152-14-Im059_1.jpg
# Rotated image written to: Model/Augmented/1/-152-15-Im059_1.jpg
# Rotated image written to: Model/Augmented/1/-152-16-Im059_1.jpg
# Rotated image written to: Model/Augmented/1/-152-17-Im059_1.jpg
# Rotated image written to: Model/Augmented/1/-152-18-Im059_1.jpg
# Rotated image written to: Model/Augmented/1/-152-19-Im059_1.jpg
# Total augmented files created so far 675
#
# Resized image written to: Model/Augmented/1/Im003_1.jpg
# Grayscaled image written to: Model/Augmented/1/Gray-Im003_1.jpg
# Histogram equalized image written to: Model/Augmented/1/Hist-Im003_1.jpg
# Horizontally reflected image written to: Model/Augmented/1/Hor-Im003_1.jpg
# Vertical reflected image written to: Model/Augmented/1/Ver-Im003_1.jpg
# Gaussian image written to: Model/Augmented/1/Gaus-Im003_1.jpg
# Translated image written to: Model/Augmented/1/Trans-Im003_1.jpg
# Rotated image written to: Model/Augmented/1/-152-0-Im003_1.jpg
# Rotated image written to: Model/Augmented/1/-152-1-Im003_1.jpg
# Rotated image written to: Model/Augmented/1/-152-2-Im003_1.jpg
# Rotated image written to: Model/Augmented/1/-152-3-Im003_1.jpg
# Rotated image written to: Model/Augmented/1/-152-4-Im003_1.jpg
# Rotated image written to: Model/Augmented/1/-152-5-Im003_1.jpg
# Rotated image written to: Model/Augmented/1/-152-6-Im003_1.jpg
# Rotated image written to: Model/Augmented/1/-152-7-Im003_1.jpg
# Rotated image written to: Model/Augmented/1/-152-8-Im003_1.jpg
# Rotated image written to: Model/Augmented/1/-152-9-Im003_1.jpg
# Rotated image written to: Model/Augmented/1/-152-10-Im003_1.jpg
# Rotated image written to: Model/Augmented/1/-152-11-Im003_1.jpg
# Rotated image written to: Model/Augmented/1/-152-12-Im003_1.jpg
# Rotated image written to: Model/Augmented/1/-152-13-Im003_1.jpg
# Rotated image written to: Model/Augmented/1/-152-14-Im003_1.jpg
# Rotated image written to: Model/Augmented/1/-152-15-Im003_1.jpg
# Rotated image written to: Model/Augmented/1/-152-16-Im003_1.jpg
# Rotated image written to: Model/Augmented/1/-152-17-Im003_1.jpg
# Rotated image written to: Model/Augmented/1/-152-18-Im003_1.jpg
# Rotated image written to: Model/Augmented/1/-152-19-Im003_1.jpg
# Total augmented files created so far 702
#
# Resized image written to: Model/Augmented/1/Im054_1.jpg
# Grayscaled image written to: Model/Augmented/1/Gray-Im054_1.jpg
# Histogram equalized image written to: Model/Augmented/1/Hist-Im054_1.jpg
# Horizontally reflected image written to: Model/Augmented/1/Hor-Im054_1.jpg
# Vertical reflected image written to: Model/Augmented/1/Ver-Im054_1.jpg
# Gaussian image written to: Model/Augmented/1/Gaus-Im054_1.jpg
# Translated image written to: Model/Augmented/1/Trans-Im054_1.jpg
# Rotated image written to: Model/Augmented/1/-152-0-Im054_1.jpg
# Rotated image written to: Model/Augmented/1/-152-1-Im054_1.jpg
# Rotated image written to: Model/Augmented/1/-152-2-Im054_1.jpg
# Rotated image written to: Model/Augmented/1/-152-3-Im054_1.jpg
# Rotated image written to: Model/Augmented/1/-152-4-Im054_1.jpg
# Rotated image written to: Model/Augmented/1/-152-5-Im054_1.jpg
# Rotated image written to: Model/Augmented/1/-152-6-Im054_1.jpg
# Rotated image written to: Model/Augmented/1/-152-7-Im054_1.jpg
# Rotated image written to: Model/Augmented/1/-152-8-Im054_1.jpg
# Rotated image written to: Model/Augmented/1/-152-9-Im054_1.jpg
# Rotated image written to: Model/Augmented/1/-152-10-Im054_1.jpg
# Rotated image written to: Model/Augmented/1/-152-11-Im054_1.jpg
# Rotated image written to: Model/Augmented/1/-152-12-Im054_1.jpg
# Rotated image written to: Model/Augmented/1/-152-13-Im054_1.jpg
# Rotated image written to: Model/Augmented/1/-152-14-Im054_1.jpg
# Rotated image written to: Model/Augmented/1/-152-15-Im054_1.jpg
# Rotated image written to: Model/Augmented/1/-152-16-Im054_1.jpg
# Rotated image written to: Model/Augmented/1/-152-17-Im054_1.jpg
# Rotated image written to: Model/Augmented/1/-152-18-Im054_1.jpg
# Rotated image written to: Model/Augmented/1/-152-19-Im054_1.jpg
# ...
# Horizontally reflected image written to: Model/Augmented/0/Hor-Im098_0.jpg
# Vertical reflected image written to: Model/Augmented/0/Ver-Im098_0.jpg
# Gaussian image written to: Model/Augmented/0/Gaus-Im098_0.jpg
# Translated image written to: Model/Augmented/0/Trans-Im098_0.jpg
# Rotated image written to: Model/Augmented/0/-152-0-Im098_0.jpg
# Rotated image written to: Model/Augmented/0/-152-1-Im098_0.jpg
# Rotated image written to: Model/Augmented/0/-152-2-Im098_0.jpg
# Rotated image written to: Model/Augmented/0/-152-3-Im098_0.jpg
# Rotated image written to: Model/Augmented/0/-152-4-Im098_0.jpg
# Rotated image written to: Model/Augmented/0/-152-5-Im098_0.jpg
# Rotated image written to: Model/Augmented/0/-152-6-Im098_0.jpg
# Rotated image written to: Model/Augmented/0/-152-7-Im098_0.jpg
# Rotated image written to: Model/Augmented/0/-152-8-Im098_0.jpg
# Rotated image written to: Model/Augmented/0/-152-9-Im098_0.jpg
# Rotated image written to: Model/Augmented/0/-152-10-Im098_0.jpg
# Rotated image written to: Model/Augmented/0/-152-11-Im098_0.jpg
# Rotated image written to: Model/Augmented/0/-152-12-Im098_0.jpg
# Rotated image written to: Model/Augmented/0/-152-13-Im098_0.jpg
# Rotated image written to: Model/Augmented/0/-152-14-Im098_0.jpg
# Rotated image written to: Model/Augmented/0/-152-15-Im098_0.jpg
# Rotated image written to: Model/Augmented/0/-152-16-Im098_0.jpg
# Rotated image written to: Model/Augmented/0/-152-17-Im098_0.jpg
# Rotated image written to: Model/Augmented/0/-152-18-Im098_0.jpg
# Rotated image written to: Model/Augmented/0/-152-19-Im098_0.jpg
# Total augmented files created so far 837
#
# Resized image written to: Model/Augmented/0/Im085_0.jpg
# Grayscaled image written to: Model/Augmented/0/Gray-Im085_0.jpg
# Histogram equalized image written to: Model/Augmented/0/Hist-Im085_0.jpg
# Horizontally reflected image written to: Model/Augmented/0/Hor-Im085_0.jpg
# Vertical reflected image written to: Model/Augmented/0/Ver-Im085_0.jpg
# Gaussian image written to: Model/Augmented/0/Gaus-Im085_0.jpg
# Translated image written to: Model/Augmented/0/Trans-Im085_0.jpg
# Rotated image written to: Model/Augmented/0/-152-0-Im085_0.jpg
# Rotated image written to: Model/Augmented/0/-152-1-Im085_0.jpg
# Rotated image written to: Model/Augmented/0/-152-2-Im085_0.jpg
# Rotated image written to: Model/Augmented/0/-152-3-Im085_0.jpg
# Rotated image written to: Model/Augmented/0/-152-4-Im085_0.jpg
# Rotated image written to: Model/Augmented/0/-152-5-Im085_0.jpg
# Rotated image written to: Model/Augmented/0/-152-6-Im085_0.jpg
# Rotated image written to: Model/Augmented/0/-152-7-Im085_0.jpg
# Rotated image written to: Model/Augmented/0/-152-8-Im085_0.jpg
# Rotated image written to: Model/Augmented/0/-152-9-Im085_0.jpg
# Rotated image written to: Model/Augmented/0/-152-10-Im085_0.jpg
# Rotated image written to: Model/Augmented/0/-152-11-Im085_0.jpg
# Rotated image written to: Model/Augmented/0/-152-12-Im085_0.jpg
# Rotated image written to: Model/Augmented/0/-152-13-Im085_0.jpg
# Rotated image written to: Model/Augmented/0/-152-14-Im085_0.jpg
# Rotated image written to: Model/Augmented/0/-152-15-Im085_0.jpg
# Rotated image written to: Model/Augmented/0/-152-16-Im085_0.jpg
# Rotated image written to: Model/Augmented/0/-152-17-Im085_0.jpg
# Rotated image written to: Model/Augmented/0/-152-18-Im085_0.jpg
# Rotated image written to: Model/Augmented/0/-152-19-Im085_0.jpg
# Total augmented files created so far 864
#
# Resized image written to: Model/Augmented/0/Im083_0.jpg
# Grayscaled image written to: Model/Augmented/0/Gray-Im083_0.jpg
# Histogram equalized image written to: Model/Augmented/0/Hist-Im083_0.jpg
# Horizontally reflected image written to: Model/Augmented/0/Hor-Im083_0.jpg
# Vertical reflected image written to: Model/Augmented/0/Ver-Im083_0.jpg
# Gaussian image written to: Model/Augmented/0/Gaus-Im083_0.jpg
# Translated image written to: Model/Augmented/0/Trans-Im083_0.jpg
# Rotated image written to: Model/Augmented/0/-152-0-Im083_0.jpg
# Rotated image written to: Model/Augmented/0/-152-1-Im083_0.jpg
# Rotated image written to: Model/Augmented/0/-152-2-Im083_0.jpg
# Rotated image written to: Model/Augmented/0/-152-3-Im083_0.jpg
# Rotated image written to: Model/Augmented/0/-152-4-Im083_0.jpg
# Rotated image written to: Model/Augmented/0/-152-5-Im083_0.jpg
# Rotated image written to: Model/Augmented/0/-152-6-Im083_0.jpg
# Rotated image written to: Model/Augmented/0/-152-7-Im083_0.jpg
# Rotated image written to: Model/Augmented/0/-152-8-Im083_0.jpg
# Rotated image written to: Model/Augmented/0/-152-9-Im083_0.jpg
# Rotated image written to: Model/Augmented/0/-152-10-Im083_0.jpg
# Rotated image written to: Model/Augmented/0/-152-11-Im083_0.jpg
# Rotated image written to: Model/Augmented/0/-152-12-Im083_0.jpg
# Rotated image written to: Model/Augmented/0/-152-13-Im083_0.jpg
# Rotated image written to: Model/Augmented/0/-152-14-Im083_0.jpg
# Rotated image written to: Model/Augmented/0/-152-15-Im083_0.jpg
# Rotated image written to: Model/Augmented/0/-152-16-Im083_0.jpg
# Rotated image written to: Model/Augmented/0/-152-17-Im083_0.jpg
# Rotated image written to: Model/Augmented/0/-152-18-Im083_0.jpg
# Rotated image written to: Model/Augmented/0/-152-19-Im083_0.jpg
# Total augmented files created so far 891
#
# Resized image written to: Model/Augmented/0/Im040_0.jpg
# Grayscaled image written to: Model/Augmented/0/Gray-Im040_0.jpg
# Histogram equalized image written to: Model/Augmented/0/Hist-Im040_0.jpg
# Horizontally reflected image written to: Model/Augmented/0/Hor-Im040_0.jpg
# Vertical reflected image written to: Model/Augmented/0/Ver-Im040_0.jpg
# Gaussian image written to: Model/Augmented/0/Gaus-Im040_0.jpg
# Translated image written to: Model/Augmented/0/Trans-Im040_0.jpg
# Rotated image written to: Model/Augmented/0/-152-0-Im040_0.jpg
# Rotated image written to: Model/Augmented/0/-152-1-Im040_0.jpg
# Rotated image written to: Model/Augmented/0/-152-2-Im040_0.jpg
# Rotated image written to: Model/Augmented/0/-152-3-Im040_0.jpg
# Rotated image written to: Model/Augmented/0/-152-4-Im040_0.jpg
# Rotated image written to: Model/Augmented/0/-152-5-Im040_0.jpg
# Rotated image written to: Model/Augmented/0/-152-6-Im040_0.jpg
# Rotated image written to: Model/Augmented/0/-152-7-Im040_0.jpg
# Rotated image written to: Model/Augmented/0/-152-8-Im040_0.jpg
# Rotated image written to: Model/Augmented/0/-152-9-Im040_0.jpg
# Rotated image written to: Model/Augmented/0/-152-10-Im040_0.jpg
# Rotated image written to: Model/Augmented/0/-152-11-Im040_0.jpg
# Rotated image written to: Model/Augmented/0/-152-12-Im040_0.jpg
# Rotated image written to: Model/Augmented/0/-152-13-Im040_0.jpg
# Rotated image written to: Model/Augmented/0/-152-14-Im040_0.jpg
# Rotated image written to: Model/Augmented/0/-152-15-Im040_0.jpg
# Rotated image written to: Model/Augmented/0/-152-16-Im040_0.jpg
# Rotated image written to: Model/Augmented/0/-152-17-Im040_0.jpg
# Rotated image written to: Model/Augmented/0/-152-18-Im040_0.jpg
# Rotated image written to: Model/Augmented/0/-152-19-Im040_0.jpg
# Total augmented files created so far 918
#
# Resized image written to: Model/Augmented/0/Im093_0.jpg
# Grayscaled image written to: Model/Augmented/0/Gray-Im093_0.jpg
# Histogram equalized image written to: Model/Augmented/0/Hist-Im093_0.jpg
# Horizontally reflected image written to: Model/Augmented/0/Hor-Im093_0.jpg
# Vertical reflected image written to: Model/Augmented/0/Ver-Im093_0.jpg
# Gaussian image written to: Model/Augmented/0/Gaus-Im093_0.jpg
# Translated image written to: Model/Augmented/0/Trans-Im093_0.jpg
# Rotated image written to: Model/Augmented/0/-152-0-Im093_0.jpg
# Rotated image written to: Model/Augmented/0/-152-1-Im093_0.jpg
# Rotated image written to: Model/Augmented/0/-152-2-Im093_0.jpg
# Rotated image written to: Model/Augmented/0/-152-3-Im093_0.jpg
# Rotated image written to: Model/Augmented/0/-152-4-Im093_0.jpg
# Rotated image written to: Model/Augmented/0/-152-5-Im093_0.jpg
# Rotated image written to: Model/Augmented/0/-152-6-Im093_0.jpg
# Rotated image written to: Model/Augmented/0/-152-7-Im093_0.jpg
# Rotated image written to: Model/Augmented/0/-152-8-Im093_0.jpg
# Rotated image written to: Model/Augmented/0/-152-9-Im093_0.jpg
# Rotated image written to: Model/Augmented/0/-152-10-Im093_0.jpg
# Rotated image written to: Model/Augmented/0/-152-11-Im093_0.jpg
# Rotated image written to: Model/Augmented/0/-152-12-Im093_0.jpg
# Rotated image written to: Model/Augmented/0/-152-13-Im093_0.jpg
# Rotated image written to: Model/Augmented/0/-152-14-Im093_0.jpg
# Rotated image written to: Model/Augmented/0/-152-15-Im093_0.jpg
# Rotated image written to: Model/Augmented/0/-152-16-Im093_0.jpg
# Rotated image written to: Model/Augmented/0/-152-17-Im093_0.jpg
# Rotated image written to: Model/Augmented/0/-152-18-Im093_0.jpg
# Rotated image written to: Model/Augmented/0/-152-19-Im093_0.jpg
# Total augmented files created so far 945
#
# Resized image written to: Model/Augmented/0/Im068_0.jpg
# Grayscaled image written to: Model/Augmented/0/Gray-Im068_0.jpg
# Histogram equalized image written to: Model/Augmented/0/Hist-Im068_0.jpg
# Horizontally reflected image written to: Model/Augmented/0/Hor-Im068_0.jpg
# Vertical reflected image written to: Model/Augmented/0/Ver-Im068_0.jpg
# Gaussian image written to: Model/Augmented/0/Gaus-Im068_0.jpg
# Translated image written to: Model/Augmented/0/Trans-Im068_0.jpg
# Rotated image written to: Model/Augmented/0/-152-0-Im068_0.jpg
# Rotated image written to: Model/Augmented/0/-152-1-Im068_0.jpg
# Rotated image written to: Model/Augmented/0/-152-2-Im068_0.jpg
# Rotated image written to: Model/Augmented/0/-152-3-Im068_0.jpg
# Rotated image written to: Model/Augmented/0/-152-4-Im068_0.jpg
# Rotated image written to: Model/Augmented/0/-152-5-Im068_0.jpg
# Rotated image written to: Model/Augmented/0/-152-6-Im068_0.jpg
# Rotated image written to: Model/Augmented/0/-152-7-Im068_0.jpg
# Rotated image written to: Model/Augmented/0/-152-8-Im068_0.jpg
# Rotated image written to: Model/Augmented/0/-152-9-Im068_0.jpg
# Rotated image written to: Model/Augmented/0/-152-10-Im068_0.jpg
# Rotated image written to: Model/Augmented/0/-152-11-Im068_0.jpg
# Rotated image written to: Model/Augmented/0/-152-12-Im068_0.jpg
# Rotated image written to: Model/Augmented/0/-152-13-Im068_0.jpg
# Rotated image written to: Model/Augmented/0/-152-14-Im068_0.jpg
# Rotated image written to: Model/Augmented/0/-152-15-Im068_0.jpg
# Rotated image written to: Model/Augmented/0/-152-16-Im068_0.jpg
# Rotated image written to: Model/Augmented/0/-152-17-Im068_0.jpg
# Rotated image written to: Model/Augmented/0/-152-18-Im068_0.jpg
# Rotated image written to: Model/Augmented/0/-152-19-Im068_0.jpg
# Total augmented files created so far 972
#
# Resized image written to: Model/Augmented/0/Im097_0.jpg
# Grayscaled image written to: Model/Augmented/0/Gray-Im097_0.jpg
# Histogram equalized image written to: Model/Augmented/0/Hist-Im097_0.jpg
# Horizontally reflected image written to: Model/Augmented/0/Hor-Im097_0.jpg
# Vertical reflected image written to: Model/Augmented/0/Ver-Im097_0.jpg
# Gaussian image written to: Model/Augmented/0/Gaus-Im097_0.jpg
# Translated image written to: Model/Augmented/0/Trans-Im097_0.jpg
# Rotated image written to: Model/Augmented/0/-152-0-Im097_0.jpg
# Rotated image written to: Model/Augmented/0/-152-1-Im097_0.jpg
# Rotated image written to: Model/Augmented/0/-152-2-Im097_0.jpg
# Rotated image written to: Model/Augmented/0/-152-3-Im097_0.jpg
# Rotated image written to: Model/Augmented/0/-152-4-Im097_0.jpg
# Rotated image written to: Model/Augmented/0/-152-5-Im097_0.jpg
# Rotated image written to: Model/Augmented/0/-152-6-Im097_0.jpg
# Rotated image written to: Model/Augmented/0/-152-7-Im097_0.jpg
# Rotated image written to: Model/Augmented/0/-152-8-Im097_0.jpg
# Rotated image written to: Model/Augmented/0/-152-9-Im097_0.jpg
# Rotated image written to: Model/Augmented/0/-152-10-Im097_0.jpg
# Rotated image written to: Model/Augmented/0/-152-11-Im097_0.jpg
# Rotated image written to: Model/Augmented/0/-152-12-Im097_0.jpg
# Rotated image written to: Model/Augmented/0/-152-13-Im097_0.jpg
# Rotated image written to: Model/Augmented/0/-152-14-Im097_0.jpg
# Rotated image written to: Model/Augmented/0/-152-15-Im097_0.jpg
# Rotated image written to: Model/Augmented/0/-152-16-Im097_0.jpg
# Rotated image written to: Model/Augmented/0/-152-17-Im097_0.jpg
# Rotated image written to: Model/Augmented/0/-152-18-Im097_0.jpg
# Rotated image written to: Model/Augmented/0/-152-19-Im097_0.jpg
# Total augmented files created so far 999
#
# Resized image written to: Model/Augmented/0/Im044_0.jpg
# Grayscaled image written to: Model/Augmented/0/Gray-Im044_0.jpg
# Histogram equalized image written to: Model/Augmented/0/Hist-Im044_0.jpg
# Horizontally reflected image written to: Model/Augmented/0/Hor-Im044_0.jpg
# Vertical reflected image written to: Model/Augmented/0/Ver-Im044_0.jpg
# Gaussian image written to: Model/Augmented/0/Gaus-Im044_0.jpg
# Translated image written to: Model/Augmented/0/Trans-Im044_0.jpg
# Rotated image written to: Model/Augmented/0/-152-0-Im044_0.jpg
# Rotated image written to: Model/Augmented/0/-152-1-Im044_0.jpg
# Rotated image written to: Model/Augmented/0/-152-2-Im044_0.jpg
# Rotated image written to: Model/Augmented/0/-152-3-Im044_0.jpg
# Rotated image written to: Model/Augmented/0/-152-4-Im044_0.jpg
# Rotated image written to: Model/Augmented/0/-152-5-Im044_0.jpg
# Rotated image written to: Model/Augmented/0/-152-6-Im044_0.jpg
# Rotated image written to: Model/Augmented/0/-152-7-Im044_0.jpg
# Rotated image written to: Model/Augmented/0/-152-8-Im044_0.jpg
# Rotated image written to: Model/Augmented/0/-152-9-Im044_0.jpg
# Rotated image written to: Model/Augmented/0/-152-10-Im044_0.jpg
# Rotated image written to: Model/Augmented/0/-152-11-Im044_0.jpg
# Rotated image written to: Model/Augmented/0/-152-12-Im044_0.jpg
# Rotated image written to: Model/Augmented/0/-152-13-Im044_0.jpg
# Rotated image written to: Model/Augmented/0/-152-14-Im044_0.jpg
# Rotated image written to: Model/Augmented/0/-152-15-Im044_0.jpg
# Rotated image written to: Model/Augmented/0/-152-16-Im044_0.jpg
# Rotated image written to: Model/Augmented/0/-152-17-Im044_0.jpg
# Rotated image written to: Model/Augmented/0/-152-18-Im044_0.jpg
# Rotated image written to: Model/Augmented/0/-152-19-Im044_0.jpg
# Total augmented files created so far 1026
#
# Resized image written to: Model/Augmented/0/Im091_0.jpg
# Grayscaled image written to: Model/Augmented/0/Gray-Im091_0.jpg
# Histogram equalized image written to: Model/Augmented/0/Hist-Im091_0.jpg
# Horizontally reflected image written to: Model/Augmented/0/Hor-Im091_0.jpg
# Vertical reflected image written to: Model/Augmented/0/Ver-Im091_0.jpg
# Gaussian image written to: Model/Augmented/0/Gaus-Im091_0.jpg
# Translated image written to: Model/Augmented/0/Trans-Im091_0.jpg
# Rotated image written to: Model/Augmented/0/-152-0-Im091_0.jpg
# Rotated image written to: Model/Augmented/0/-152-1-Im091_0.jpg
# Rotated image written to: Model/Augmented/0/-152-2-Im091_0.jpg
# Rotated image written to: Model/Augmented/0/-152-3-Im091_0.jpg
# Rotated image written to: Model/Augmented/0/-152-4-Im091_0.jpg
# Rotated image written to: Model/Augmented/0/-152-5-Im091_0.jpg
# Rotated image written to: Model/Augmented/0/-152-6-Im091_0.jpg
# Rotated image written to: Model/Augmented/0/-152-7-Im091_0.jpg
# Rotated image written to: Model/Augmented/0/-152-8-Im091_0.jpg
# Rotated image written to: Model/Augmented/0/-152-9-Im091_0.jpg
# Rotated image written to: Model/Augmented/0/-152-10-Im091_0.jpg
# Rotated image written to: Model/Augmented/0/-152-11-Im091_0.jpg
# Rotated image written to: Model/Augmented/0/-152-12-Im091_0.jpg
# Rotated image written to: Model/Augmented/0/-152-13-Im091_0.jpg
# Rotated image written to: Model/Augmented/0/-152-14-Im091_0.jpg
# Rotated image written to: Model/Augmented/0/-152-15-Im091_0.jpg
# Rotated image written to: Model/Augmented/0/-152-16-Im091_0.jpg
# Rotated image written to: Model/Augmented/0/-152-17-Im091_0.jpg
# Rotated image written to: Model/Augmented/0/-152-18-Im091_0.jpg
# Rotated image written to: Model/Augmented/0/-152-19-Im091_0.jpg
# Total augmented files created so far 1053
#
#  AML/ALL Augmentation: 2020-07-14 21:57:50  - Added filters to 39 files in the 0 directory, with a total of 1053 augmented files created.

# %% [markdown]
# # Your augmented dataset
#
# If you head to your **Model/Data/** directory you will notice the **Augmented** directory. Inside the augmented directory you will find **0** (negative) and **1** (postive) directories including resized copies of the original along with augmented copies.
#
# Using data augmentation I was able to increase the dataset from **39** images per class to **1053** per class.
#
# &nbsp;
#
# # Contributing
#
# The Peter Moss Acute Myeloid & Lymphoblastic Leukemia AI Research project encourages and welcomes code contributions, bug fixes and enhancements from the Github.
#
# Please read the [CONTRIBUTING](../CONTRIBUTING.md "CONTRIBUTING") document for a full guide to forking our repositories and submitting your pull requests. You will also find information about our code of conduct on this page.
#
# ## Contributors
#
# - [Adam Milton-Barker](https://www.leukemiaresearchassociation.ai/team/adam-milton-barker "Adam Milton-Barker") - [Asociacion De Investigation En Inteligencia Artificial Para La Leucemia Peter Moss](https://www.leukemiaresearchassociation.ai "Asociacion De Investigation En Inteligencia Artificial Para La Leucemia Peter Moss") President & Lead Developer, Sabadell, Spain
#
# &nbsp;
#
# # Versioning
#
# We use SemVer for versioning. For the versions available, see [Releases](../releases "Releases").
#
# &nbsp;
#
# # License
#
# This project is licensed under the **MIT License** - see the [LICENSE](../LICENSE "LICENSE") file for details.
#
# &nbsp;
#
# # Bugs/Issues
#
# We use the [repo issues](../issues "repo issues") to track bugs and general requests related to using this project.
