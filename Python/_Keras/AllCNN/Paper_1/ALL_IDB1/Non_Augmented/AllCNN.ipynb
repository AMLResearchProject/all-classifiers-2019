# %% [markdown]
# # Peter Moss Acute Myeloid / Lymphoblastic Leukemia AI Research Project

# %% [markdown]
# ## Detecting Acute Lymphoblastic Leukemia With Keras & Tensorflow
# **Using the ACUTE LEUKEMIA CLASSIFICATION USING CONVOLUTION NEURAL NETWORK IN CLINICAL DECISION SUPPORT SYSTEM paper & ALL_IDB1**
#
# ![Peter Moss Acute Myeloid / Lymphoblastic Leukemia AI Research Project](https://www.PeterMossAmlAllResearch.com/media/images/banner.png)
#
# In this notebook you will create and train a Convolutional Neural Network, (KAllCNN_IDB1), to detect Acute Lymphoblastic Leukemia (ALL) using Keras & Tensorflow on Google Colab. The architecture you will create is based on the network proposed in the [ACUTE LEUKEMIA CLASSIFICATION USING CONVOLUTION NEURAL NETWORK IN CLINICAL DECISION SUPPORT SYSTEM](https://airccj.org/CSCP/vol7/csit77505.pdf "ACUTE LEUKEMIA CLASSIFICATION USING CONVOLUTION NEURAL NETWORK IN CLINICAL DECISION SUPPORT SYSTEM") paper by Thanh.TTP, Giao N. Pham, Jin-Hyeok Park, Kwang-Seok Moon, Suk-Hwan Lee, and Ki-Ryong Kwon.
#
# This notebook is written by [Adam Milton-Barker](https://www.petermossamlallresearch.com/team/adam-milton-barker/profile "Adam Milton-Barker") and based on a notebook written by [Amita Kapoor](https://www.petermossamlallresearch.com/team/amita-kapoor/profile "Amita Kapoor"), and [Taru Jain](https://www.petermossamlallresearch.com/students/student/taru-jain/profile "Taru Jain"), one of the students from the [AML/ALL AI Student Program](https://www.petermossamlallresearch.com/students/ "AML/ALL AI Student Program").

# %% [markdown]
# # ALL Image Database for Image Processing
#
# ![Acute Lymphoblastic Leukemia Image Database for Image Processing](https://www.petermossamlallresearch.com/media/images/repositories/ALL_IDB1_Augmented_Slides.png)
# _Fig 1. Samples of augmented data generated using ALL_IDB1 from the Acute Lymphoblastic Leukemia Image Database for Image Processing dataset._
#
#
# The [Acute Lymphoblastic Leukemia Image Database for Image Processing](https://homes.di.unimi.it/scotti/all/) dataset created by [Fabio Scotti, Associate Professor Dipartimento di Informatica, Università degli Studi di Milano](https://homes.di.unimi.it/scotti/) is used in this notebook, you will use the **ALL_IDB1** dataset.

# %% [markdown]
# ## Gain Access To ALL-IDB
#
# You you need to be granted access to use the Acute Lymphoblastic Leukemia Image Database for Image Processing dataset. You can find the application form and information about getting access to the dataset on [this page](https://homes.di.unimi.it/scotti/all/#download) as well as information on how to contribute back to the project [here](https://homes.di.unimi.it/scotti/all/results.php).

# %% [markdown]
# # Clone AML & ALL Classifiers Repository
#
# First of all you should clone the [AML & ALL Classifiers](https://github.com/AMLResearchProject/AML-ALL-Classifiers/ "AML & ALL Classifiers") repo to your device. To do this you can navigate to the location you want to clone the repository to on your device using terminal (cd Your/Clone/Location), and then use the following command:
#
# ```
#   $ git clone https://github.com/AMLResearchProject/AML-ALL-Classifiers.git
# ```
#
# Once you have used the command above you will see a directory called **AML-ALL-Classifiers** in the location you chose to clone the repo to. In terminal, navigate to the **AML-ALL-Classifiers/Python/_Keras/AllCNN/Paper_1/ALL_IDB1/Non_Augmented/** directory, this is your project root directory.

# %% [markdown]
# # Google Drive / Colab

# %% [markdown]
# ## Upload Project Root To Google Drive
#
#
# Now you need to upload the project root to your Google Drive, placing the jpg files from the ALL_IDB1 dataset in the **Model/Data/Training/** directory.

# %% [markdown]
# ## Mount Google Drive In Colab
#
# ![Peter Moss Acute Myeloid / Lymphoblastic Leukemia AI Research Project](https://www.PeterMossAmlAllResearch.com/media/images/repositories/Colab.png)
# _Fig 2. Example of Colab connected to Google Drive._
#
# The first step is to mount your Google Drive in Colab.
#
# **To do this execute the following code block:**

# %%
# %matplotlib inline

import sys
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Go to this URL in a browser: ###
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %% [markdown]
# # Install & Import Requirements
# **Install and import requirements by executing the following code block:**

# %%
# !pip install keras_metrics

import os,  cv2, keras, keras_metrics, matplotlib.image, random
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '0' 

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from keras import backend as K
from keras import layers
from keras.layers import Activation, Dense, Dropout, Conv2D
from keras.layers import Flatten, MaxPooling2D, ZeroPadding2D
from keras.models import load_model, Model, model_from_json, Sequential
from keras.optimizers import Adam
from keras.preprocessing import image
from keras.utils import np_utils

from numpy.random import seed

from pathlib import Path

from scipy import ndimage
from sklearn.utils import shuffle
from sklearn.metrics import confusion_matrix, precision_score, recall_score
from sklearn.metrics import roc_auc_score

from tensorflow import set_random_seed

# %matplotlib inline

seed(3)
set_random_seed(3)
# Out:
# Collecting keras_metrics
#   Downloading https://files.pythonhosted.org/packages/32/c9/a87420da8e73de944e63a8e9cdcfb1f03ca31a7c4cdcdbd45d2cdf13275a/keras_metrics-1.1.0-py2.py3-none-any.whl
# Requirement already satisfied: Keras>=2.1.5 in /usr/local/lib/python3.6/dist-packages (from keras_metrics) (2.2.5)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.6/dist-packages (from Keras>=2.1.5->keras_metrics) (1.3.1)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from Keras>=2.1.5->keras_metrics) (1.12.0)
# Requirement already satisfied: keras-preprocessing>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from Keras>=2.1.5->keras_metrics) (1.1.0)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.6/dist-packages (from Keras>=2.1.5->keras_metrics) (1.17.3)
# Requirement already satisfied: keras-applications>=1.0.8 in /usr/local/lib/python3.6/dist-packages (from Keras>=2.1.5->keras_metrics) (1.0.8)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from Keras>=2.1.5->keras_metrics) (3.13)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from Keras>=2.1.5->keras_metrics) (2.8.0)
# Installing collected packages: keras-metrics
# Successfully installed keras-metrics-1.1.0
# Using TensorFlow backend.
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>

# %% [markdown]
# # Program Settings
# Update the settings below to match the locations of the dataset, augmented and test directories on your Google Drive.. The Classes directory path is added allowing the files in the Classes directory to be executed.
#
# **Once you have updated the settings below, execute the following code block:**

# %%
local_drive = "/content/gdrive/My Drive/"
project_root = "AMLResearchProject/AML-ALL-Classifiers/Python/_Keras/AllCNN/Paper_1/ALL_IDB1/Non_Augmented/"
project_root_full = local_drive + project_root

sys.path.append(project_root_full + 'Classes')

import Data as AllCnnData
import Helpers as AllCnnHelpers
import Test as AllCnnTest

core = AllCnnHelpers.Helpers("Classifier", project_root_full)
configs = core.confs

model_root_path = project_root_full + configs["model_root"]
model_path = model_root_path + "/" + configs["model_file"]

data_dir = model_root_path + configs["data_dir"]
training_dir = model_root_path + data_dir + "/" + configs["training_dir"]
validation_dir = model_root_path + data_dir + "/" + configs["validation_dir"]

batch_size = configs["batch_size"]
epochs = configs["epochs"]
val_steps = configs["val_steps"]

core.logger.info("Class Path: " + project_root + 'Classes')
core.logger.info("Data Path: " + data_dir)
core.logger.info("Model Path: " + model_path)
core.logger.info("Model Root Dir: " + model_root_path)
core.logger.info("Project Root: " + project_root)
core.logger.info("Program settings setup complete.")
# Out:
# 2019-10-26 18:26:13,274 - Classifier - INFO - Helpers class initialization complete.
# 2019-10-26 18:26:13,589 - Classifier - INFO - Class Path: AMLResearchProject/AML-ALL-Classifiers/Python/_Keras/AllCNN/Paper_1/ALL_IDB1/Non_Augmented/Classes
# 2019-10-26 18:26:13,591 - Classifier - INFO - Data Path: /content/gdrive/My Drive/AMLResearchProject/AML-ALL-Classifiers/Python/_Keras/AllCNN/Paper_1/ALL_IDB1/Non_Augmented/Model/Data/Training
# 2019-10-26 18:26:13,593 - Classifier - INFO - Model Path: /content/gdrive/My Drive/AMLResearchProject/AML-ALL-Classifiers/Python/_Keras/AllCNN/Paper_1/ALL_IDB1/Non_Augmented/Model/model.json
# 2019-10-26 18:26:13,596 - Classifier - INFO - Model Root Dir: /content/gdrive/My Drive/AMLResearchProject/AML-ALL-Classifiers/Python/_Keras/AllCNN/Paper_1/ALL_IDB1/Non_Augmented/Model
# 2019-10-26 18:26:13,597 - Classifier - INFO - Project Root: AMLResearchProject/AML-ALL-Classifiers/Python/_Keras/AllCNN/Paper_1/ALL_IDB1/Non_Augmented/
# 2019-10-26 18:26:13,599 - Classifier - INFO - Program settings setup complete.

# %% [markdown]
# # Prepare Your Data
# Now you need to prepare your training and validation data.

# %% [markdown]
# ## Proposed Training / Validation Sets
# The training and validation sets proposed in the paper are as follows, where **Normal cell** refers to ALL negative examples and **Abnormal cell** refers to ALL positive examples.
#
# | | Training Set | Test Set |
# | --- | --- | --- |
# | Normal cell | 40 | 19 |
# | Abnormal cell | 40 | 9 |
# | **Total** | **80** | **28** |

# %% [markdown]
# If you haven't already, navigate to the **AML-ALL-Classifiers/Python/_Keras/AllCNN/Paper_1/ALL_IDB1/Non_Augmented/Model/Data/Training/** directory and upload the jpg files from ALL_IDB1.

# %% [markdown]
# ## Sort Your Data
# **Ensure that you have completed all steps above and then execute the following code block to sort/split your data, recreating the dataset splits proposed in the paper:**
#
# (This may take some time)

# %%
AllData = AllCnnData.Data(core.logger, configs)
data, labels = AllData.prepare_data(data_dir)
X_train, y_train, X_test, y_test = AllData.data_and_labels(data, labels)
# Out:
# 2019-10-26 18:26:20,251 - Classifier - INFO - Positive training data length: 49
# 2019-10-26 18:26:20,253 - Classifier - INFO - Negative training data length: 59
# 2019-10-26 18:26:20,254 - Classifier - INFO - Total training data length: 108
#
# 2019-10-26 18:26:20,258 - Classifier - INFO - Paper positive training dataset recreated, size: 40
# 2019-10-26 18:26:20,262 - Classifier - INFO - Paper negative training dataset recreated, size: 40
# 2019-10-26 18:26:20,264 - Classifier - INFO - Total training dataset recreated: 80
#
# 2019-10-26 18:26:20,266 - Classifier - INFO - Paper positive validation data created, size: 9
# 2019-10-26 18:26:20,267 - Classifier - INFO - Paper negative validation data created, size: 19
# 2019-10-26 18:26:20,269 - Classifier - INFO - Total validation dataset recreated: 28
#
# 2019-10-26 18:26:35,295 - Classifier - INFO - Validation data shape: (28, 50, 50, 3)
# 2019-10-26 18:26:35,297 - Classifier - INFO - Validation labels shape: (28, 2)
#
# 2019-10-26 18:27:15,835 - Classifier - INFO - Training data shape: (80, 50, 50, 3)
# 2019-10-26 18:27:15,837 - Classifier - INFO - Training labels shape: (80, 2)

# %% [markdown]
# ## Shuffle Data
# Shuffle the new training data, remembering to use our seed of 3.
#
# **To shuffle the training date, execute the following code block:**

# %%
data = np.asarray(X_train)
labels = np.asarray(y_train)

Data, Label = shuffle(data, labels, random_state = 3)
data_list = [Data, Label]

# %% [markdown]
# # View Dataset Sample
# **To view a sample of your dataset, execute the following code block:**

# %%
y = np.argmax(Label, axis=-1)
f, ax = plt.subplots(4, 5, figsize=(30, 7))

for i in range(0, 20):
    ax[i//5, i%5].imshow(Data[i])
    if y[i]==1:
        ax[i//5, i%5].set_title("Non-ALL")
    else:
        ax[i//5, i%5].set_title("ALL")

# %% [markdown]
# # Model Architecture
# <img src="https://www.PeterMossAmlAllResearch.com/media/images/repositories/paper_1_architecture.png" alt="Proposed Architecture" />
#
# _Fig 3. Proposed Architecture  ([Source](https://airccj.org/CSCP/vol7/csit77505.pdf "Source"))_

# %% [markdown]
# ## Proposed Architecture
#
# In the [ACUTE LEUKEMIA CLASSIFICATION USING CONVOLUTION NEURAL NETWORK IN CLINICAL DECISION SUPPORT SYSTEM](https://airccj.org/CSCP/vol7/csit77505.pdf "ACUTE LEUKEMIA CLASSIFICATION USING CONVOLUTION NEURAL NETWORK IN CLINICAL DECISION SUPPORT SYSTEM") paper the authors explain the layers they used to create their convolutional neural network.
#
# > "In this work, we proposed a network contains 4 layers. The first 3 layers for detecting features
# and the other two layers (Fully connected and Softmax) are for classifying the features. The input
# image has the size [50x50x3]. The receptive field (or the filter size) is 5x5. The stride is 1 then we
# move the filters one pixel at a time. The zero-padding is 2. It will allow us to control the spatial
# size of the output image (we will use it to exactly preserve the spatial size of the input volume so
# the input and output width and height are the same). During the experiment, we found that in our
# case, altering the size of original image during the convolution lead to decrease the accuracy
# about 40%. Thus the output image after convolution layer 1 has the same size with the input
# image."
#
# > "The convolution layer 2 has the same structure with the convolution layer 1. The filter size is 5x5,
# the stride is 1 and the zero-padding is 2. The number of feature maps (the channel or the depth) in
# our case is 30. If the number of feature maps is lower or higher than 30, the accuracy will
# decrease 50%. By experiment, we found the accuracy also decrease 50% if we remove
# Convolution layer 2.""
#
# > "The Max-Pooling layer 25x25 has Filter size is 2 and stride is 2. The fully connected layer has 2
# neural. Finally, we use the Softmax layer for the classification. "
#
# **To recreate the proposed architecture, execute the following code block:**

# %%
model = Sequential()
model.name="KAllCnn_IDB1"

model.add(ZeroPadding2D(padding=(2, 2), input_shape=X_train.shape[1:]))
model.add(Conv2D(30, (5, 5), strides=1, padding = "valid", input_shape = X_train.shape[1:], activation = 'relu'))
model.add(Dropout(0.4))

model.add(ZeroPadding2D(padding=(2, 2), input_shape=X_train.shape[1:]))
model.add(Conv2D(30, (5, 5), strides=1, padding = "valid", activation = 'relu'))
model.add(MaxPooling2D(pool_size=(2, 2), strides=2, padding = 'valid'))
model.add(Dropout(0.6))

model.add(Flatten())
model.add(Dense(2))
model.add(Activation("softmax"))
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:148: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3733: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4267: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:Large dropout rate: 0.6 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.

# %% [markdown]
# ## View Network Architecture (Summary)
# **To view a summary of your networ architecture, execute the following code block:**

# %%
model.summary()
# Out:
# Model: "KAllCnn_IDB1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# zero_padding2d_1 (ZeroPaddin (None, 54, 54, 3)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 50, 50, 30)        2280
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 50, 50, 30)        0
# _________________________________________________________________
# zero_padding2d_2 (ZeroPaddin (None, 54, 54, 30)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 50, 50, 30)        22530
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 25, 25, 30)        0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 25, 25, 30)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 18750)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 37502
# _________________________________________________________________
# activation_1 (Activation)    (None, 2)                 0
# =================================================================
# Total params: 62,312
# Trainable params: 62,312
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Compile &  Fit Your Model
#
# In the following code block first the program complies the model, then fits the model. The **validation_data**, _(X_test, y_test)_, and the number of **validation_steps** are passed to the **Keras model.fit** function. This means that in addition to showing training loss, accuracy, precision and recall the program will show validation loss, accuracy, precision and recall in its output.
#
# **Assuming you have completed all above steps you can execute the following code block to beging training:**

# %%
optimizer = keras.optimizers.rmsprop(lr = 0.0001, decay = 1e-6)
model.compile(loss = 'binary_crossentropy', optimizer = optimizer, 
              metrics = ['accuracy', keras_metrics.precision(), keras_metrics.recall()])

history = model.fit(X_train, y_train, validation_data = (X_test, y_test), validation_steps = val_steps, 
                    steps_per_epoch = int(len(X_train)/batch_size), epochs = epochs)
history
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3657: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/nn_impl.py:183: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3005: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# Train on 80 samples, validate on 28 samples
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# Epoch 1/100
# 8/8 [==============================] - 4s 472ms/step - loss: 0.7734 - acc: 0.4688 - precision: 0.4673 - recall: 0.4469 - val_loss: 0.6746 - val_acc: 0.6786 - val_precision: 0.6786 - val_recall: 1.0000
# Epoch 2/100
# 8/8 [==============================] - 0s 39ms/step - loss: 0.7202 - acc: 0.5063 - precision: 0.5070 - recall: 0.4531 - val_loss: 0.6836 - val_acc: 0.8214 - val_precision: 0.8500 - val_recall: 0.8947
# Epoch 3/100
# 8/8 [==============================] - 0s 37ms/step - loss: 0.6946 - acc: 0.5359 - precision: 0.5428 - recall: 0.4562 - val_loss: 0.6723 - val_acc: 0.8571 - val_precision: 0.8261 - val_recall: 1.0000
# Epoch 4/100
# 8/8 [==============================] - 0s 37ms/step - loss: 0.6823 - acc: 0.5484 - precision: 0.5585 - recall: 0.4625 - val_loss: 0.6699 - val_acc: 0.8214 - val_precision: 0.8182 - val_recall: 0.9474
# Epoch 5/100
# 8/8 [==============================] - 0s 38ms/step - loss: 0.6575 - acc: 0.6109 - precision: 0.6340 - recall: 0.5250 - val_loss: 0.6457 - val_acc: 0.8929 - val_precision: 0.8636 - val_recall: 1.0000
# Epoch 6/100
# 8/8 [==============================] - 0s 39ms/step - loss: 0.6146 - acc: 0.6844 - precision: 0.6993 - recall: 0.6469 - val_loss: 0.6302 - val_acc: 0.8929 - val_precision: 0.8636 - val_recall: 1.0000
# Epoch 7/100
# 8/8 [==============================] - 0s 37ms/step - loss: 0.5908 - acc: 0.7000 - precision: 0.7148 - recall: 0.6656 - val_loss: 0.6038 - val_acc: 0.8929 - val_precision: 0.8636 - val_recall: 1.0000
# Epoch 8/100
# 8/8 [==============================] - 0s 37ms/step - loss: 0.5632 - acc: 0.7734 - precision: 0.7644 - recall: 0.7906 - val_loss: 0.5839 - val_acc: 0.8929 - val_precision: 0.8636 - val_recall: 1.0000
# Epoch 9/100
# 8/8 [==============================] - 0s 39ms/step - loss: 0.5361 - acc: 0.7609 - precision: 0.7601 - recall: 0.7625 - val_loss: 0.5767 - val_acc: 0.7857 - val_precision: 0.8421 - val_recall: 0.8421
# Epoch 10/100
# 8/8 [==============================] - 0s 39ms/step - loss: 0.5215 - acc: 0.7687 - precision: 0.7638 - recall: 0.7781 - val_loss: 0.5322 - val_acc: 0.8929 - val_precision: 0.8636 - val_recall: 1.0000
# Epoch 11/100
# 8/8 [==============================] - 0s 38ms/step - loss: 0.4868 - acc: 0.8016 - precision: 0.7734 - recall: 0.8531 - val_loss: 0.5126 - val_acc: 0.8929 - val_precision: 0.8636 - val_recall: 1.0000
# Epoch 12/100
# 8/8 [==============================] - 0s 38ms/step - loss: 0.4744 - acc: 0.8078 - precision: 0.7872 - recall: 0.8437 - val_loss: 0.5073 - val_acc: 0.8929 - val_precision: 0.8636 - val_recall: 1.0000
# Epoch 13/100
# 8/8 [==============================] - 0s 38ms/step - loss: 0.4390 - acc: 0.8219 - precision: 0.8047 - recall: 0.8500 - val_loss: 0.4799 - val_acc: 0.8929 - val_precision: 0.8636 - val_recall: 1.0000
# Epoch 14/100
# 8/8 [==============================] - 0s 37ms/step - loss: 0.4345 - acc: 0.8234 - precision: 0.7966 - recall: 0.8687 - val_loss: 0.4727 - val_acc: 0.8929 - val_precision: 0.8636 - val_recall: 1.0000
# Epoch 15/100
# 8/8 [==============================] - 0s 37ms/step - loss: 0.4225 - acc: 0.8234 - precision: 0.7983 - recall: 0.8656 - val_loss: 0.4641 - val_acc: 0.8929 - val_precision: 0.8636 - val_recall: 1.0000
# Epoch 16/100
# 8/8 [==============================] - 0s 37ms/step - loss: 0.4276 - acc: 0.8203 - precision: 0.7937 - recall: 0.8656 - val_loss: 0.4539 - val_acc: 0.8929 - val_precision: 0.8636 - val_recall: 1.0000
# Epoch 17/100
# 8/8 [==============================] - 0s 37ms/step - loss: 0.3964 - acc: 0.8234 - precision: 0.7983 - recall: 0.8656 - val_loss: 0.4415 - val_acc: 0.8929 - val_precision: 0.8636 - val_recall: 1.0000
# Epoch 18/100
# 8/8 [==============================] - 0s 38ms/step - loss: 0.4068 - acc: 0.8266 - precision: 0.7977 - recall: 0.8750 - val_loss: 0.4344 - val_acc: 0.8929 - val_precision: 0.8636 - val_recall: 1.0000
# Epoch 19/100
# 8/8 [==============================] - 0s 36ms/step - loss: 0.3941 - acc: 0.8328 - precision: 0.8052 - recall: 0.8781 - val_loss: 0.4266 - val_acc: 0.8929 - val_precision: 0.8636 - val_recall: 1.0000
# Epoch 20/100
# 8/8 [==============================] - 0s 38ms/step - loss: 0.3821 - acc: 0.8234 - precision: 0.7899 - recall: 0.8812 - val_loss: 0.4161 - val_acc: 0.8929 - val_precision: 0.8636 - val_recall: 1.0000
# Epoch 21/100
# 8/8 [==============================] - 0s 37ms/step - loss: 0.3653 - acc: 0.8359 - precision: 0.8063 - recall: 0.8844 - val_loss: 0.4081 - val_acc: 0.8929 - val_precision: 0.8636 - val_recall: 1.0000
# Epoch 22/100
# 8/8 [==============================] - 0s 37ms/step - loss: 0.3762 - acc: 0.8344 - precision: 0.8023 - recall: 0.8875 - val_loss: 0.4051 - val_acc: 0.8929 - val_precision: 0.8636 - val_recall: 1.0000
# Epoch 23/100
# 8/8 [==============================] - 0s 37ms/step - loss: 0.3529 - acc: 0.8375 - precision: 0.7967 - recall: 0.9062 - val_loss: 0.4002 - val_acc: 0.8929 - val_precision: 0.8636 - val_recall: 1.0000
# Epoch 24/100
# 8/8 [==============================] - 0s 39ms/step - loss: 0.3598 - acc: 0.8422 - precision: 0.8085 - recall: 0.8969 - val_loss: 0.3965 - val_acc: 0.8929 - val_precision: 0.8636 - val_recall: 1.0000
# Epoch 25/100
# 8/8 [==============================] - 0s 40ms/step - loss: 0.3411 - acc: 0.8359 - precision: 0.8045 - recall: 0.8875 - val_loss: 0.3948 - val_acc: 0.8929 - val_precision: 0.8636 - val_recall: 1.0000
# Epoch 26/100
# 8/8 [==============================] - 0s 37ms/step - loss: 0.3543 - acc: 0.8422 - precision: 0.8085 - recall: 0.8969 - val_loss: 0.3889 - val_acc: 0.8929 - val_precision: 0.8636 - val_recall: 1.0000
# Epoch 27/100
# 8/8 [==============================] - 0s 36ms/step - loss: 0.3337 - acc: 0.8375 - precision: 0.8034 - recall: 0.8937 - val_loss: 0.3886 - val_acc: 0.8929 - val_precision: 0.8636 - val_recall: 1.0000
# Epoch 28/100
# 8/8 [==============================] - 0s 39ms/step - loss: 0.3353 - acc: 0.8516 - precision: 0.8151 - recall: 0.9094 - val_loss: 0.3826 - val_acc: 0.8929 - val_precision: 0.8636 - val_recall: 1.0000
# Epoch 29/100
# 8/8 [==============================] - 0s 39ms/step - loss: 0.3344 - acc: 0.8484 - precision: 0.8123 - recall: 0.9062 - val_loss: 0.3831 - val_acc: 0.8929 - val_precision: 0.8636 - val_recall: 1.0000
# Epoch 30/100
# 8/8 [==============================] - 0s 38ms/step - loss: 0.3156 - acc: 0.8594 - precision: 0.8230 - recall: 0.9156 - val_loss: 0.3825 - val_acc: 0.8929 - val_precision: 0.8636 - val_recall: 1.0000
# Epoch 31/100
# 8/8 [==============================] - 0s 38ms/step - loss: 0.3276 - acc: 0.8500 - precision: 0.8111 - recall: 0.9125 - val_loss: 0.3797 - val_acc: 0.8929 - val_precision: 0.8636 - val_recall: 1.0000
# Epoch 32/100
# 8/8 [==============================] - 0s 37ms/step - loss: 0.3158 - acc: 0.8594 - precision: 0.8230 - recall: 0.9156 - val_loss: 0.3822 - val_acc: 0.8929 - val_precision: 0.8636 - val_recall: 1.0000
# Epoch 33/100
# 8/8 [==============================] - 0s 37ms/step - loss: 0.3010 - acc: 0.8656 - precision: 0.8287 - recall: 0.9219 - val_loss: 0.3790 - val_acc: 0.8929 - val_precision: 0.8636 - val_recall: 1.0000
# Epoch 34/100
# 8/8 [==============================] - 0s 37ms/step - loss: 0.3041 - acc: 0.8578 - precision: 0.8207 - recall: 0.9156 - val_loss: 0.3703 - val_acc: 0.8929 - val_precision: 0.8636 - val_recall: 1.0000
# Epoch 35/100
# 8/8 [==============================] - 0s 37ms/step - loss: 0.3076 - acc: 0.8531 - precision: 0.8192 - recall: 0.9062 - val_loss: 0.3775 - val_acc: 0.8929 - val_precision: 0.8636 - val_recall: 1.0000
# Epoch 36/100
# 8/8 [==============================] - 0s 36ms/step - loss: 0.2888 - acc: 0.8672 - precision: 0.8273 - recall: 0.9281 - val_loss: 0.3618 - val_acc: 0.8929 - val_precision: 0.8636 - val_recall: 1.0000
# Epoch 37/100
# 8/8 [==============================] - 0s 38ms/step - loss: 0.2838 - acc: 0.8656 - precision: 0.8268 - recall: 0.9250 - val_loss: 0.3768 - val_acc: 0.8571 - val_precision: 0.8261 - val_recall: 1.0000
# Epoch 38/100
# 8/8 [==============================] - 0s 37ms/step - loss: 0.2871 - acc: 0.8703 - precision: 0.8357 - recall: 0.9219 - val_loss: 0.3659 - val_acc: 0.8929 - val_precision: 0.8636 - val_recall: 1.0000
# Epoch 39/100
# 8/8 [==============================] - 0s 37ms/step - loss: 0.2720 - acc: 0.8719 - precision: 0.8324 - recall: 0.9312 - val_loss: 0.3497 - val_acc: 0.8929 - val_precision: 0.8636 - val_recall: 1.0000
# Epoch 40/100
# 8/8 [==============================] - 0s 37ms/step - loss: 0.2885 - acc: 0.8734 - precision: 0.8424 - recall: 0.9187 - val_loss: 0.3577 - val_acc: 0.8929 - val_precision: 0.8636 - val_recall: 1.0000
# Epoch 41/100
# 8/8 [==============================] - 0s 37ms/step - loss: 0.2574 - acc: 0.8875 - precision: 0.8483 - recall: 0.9437 - val_loss: 0.3465 - val_acc: 0.8929 - val_precision: 0.8636 - val_recall: 1.0000
# Epoch 42/100
# 8/8 [==============================] - 0s 37ms/step - loss: 0.2603 - acc: 0.8906 - precision: 0.8551 - recall: 0.9406 - val_loss: 0.3548 - val_acc: 0.8571 - val_precision: 0.8261 - val_recall: 1.0000
# Epoch 43/100
# 8/8 [==============================] - 0s 39ms/step - loss: 0.2521 - acc: 0.8891 - precision: 0.8527 - recall: 0.9406 - val_loss: 0.3274 - val_acc: 0.8929 - val_precision: 0.8636 - val_recall: 1.0000
# Epoch 44/100
# 8/8 [==============================] - 0s 40ms/step - loss: 0.2549 - acc: 0.8891 - precision: 0.8588 - recall: 0.9312 - val_loss: 0.3461 - val_acc: 0.8571 - val_precision: 0.8261 - val_recall: 1.0000
# Epoch 45/100
# 8/8 [==============================] - 0s 37ms/step - loss: 0.2362 - acc: 0.9031 - precision: 0.8665 - recall: 0.9531 - val_loss: 0.3380 - val_acc: 0.8571 - val_precision: 0.8261 - val_recall: 1.0000
# Epoch 46/100
# 8/8 [==============================] - 0s 37ms/step - loss: 0.2386 - acc: 0.8937 - precision: 0.8559 - recall: 0.9469 - val_loss: 0.3328 - val_acc: 0.8571 - val_precision: 0.8261 - val_recall: 1.0000
# Epoch 47/100
# 8/8 [==============================] - 0s 40ms/step - loss: 0.2392 - acc: 0.9016 - precision: 0.8682 - recall: 0.9469 - val_loss: 0.3339 - val_acc: 0.8571 - val_precision: 0.8261 - val_recall: 1.0000
# Epoch 48/100
# 8/8 [==============================] - 0s 38ms/step - loss: 0.2196 - acc: 0.9094 - precision: 0.8743 - recall: 0.9562 - val_loss: 0.3269 - val_acc: 0.8571 - val_precision: 0.8261 - val_recall: 1.0000
# Epoch 49/100
# 8/8 [==============================] - 0s 39ms/step - loss: 0.2173 - acc: 0.9203 - precision: 0.8899 - recall: 0.9594 - val_loss: 0.3266 - val_acc: 0.8571 - val_precision: 0.8261 - val_recall: 1.0000
# Epoch 50/100
# 8/8 [==============================] - 0s 38ms/step - loss: 0.2130 - acc: 0.9125 - precision: 0.8771 - recall: 0.9594 - val_loss: 0.3126 - val_acc: 0.8571 - val_precision: 0.8261 - val_recall: 1.0000
# Epoch 51/100
# 8/8 [==============================] - 0s 37ms/step - loss: 0.2128 - acc: 0.9156 - precision: 0.8889 - recall: 0.9500 - val_loss: 0.3284 - val_acc: 0.8571 - val_precision: 0.8261 - val_recall: 1.0000
# Epoch 52/100
# 8/8 [==============================] - 0s 38ms/step - loss: 0.1964 - acc: 0.9250 - precision: 0.8908 - recall: 0.9687 - val_loss: 0.3218 - val_acc: 0.8571 - val_precision: 0.8261 - val_recall: 1.0000
# Epoch 53/100
# 8/8 [==============================] - 0s 38ms/step - loss: 0.2015 - acc: 0.9250 - precision: 0.8953 - recall: 0.9625 - val_loss: 0.3004 - val_acc: 0.8571 - val_precision: 0.8261 - val_recall: 1.0000
# Epoch 54/100
# 8/8 [==============================] - 0s 38ms/step - loss: 0.1846 - acc: 0.9250 - precision: 0.8953 - recall: 0.9625 - val_loss: 0.2930 - val_acc: 0.8929 - val_precision: 0.8636 - val_recall: 1.0000
# Epoch 55/100
# 8/8 [==============================] - 0s 39ms/step - loss: 0.1957 - acc: 0.9234 - precision: 0.8950 - recall: 0.9594 - val_loss: 0.2882 - val_acc: 0.8929 - val_precision: 0.8636 - val_recall: 1.0000
# Epoch 56/100
# 8/8 [==============================] - 0s 37ms/step - loss: 0.1656 - acc: 0.9438 - precision: 0.9104 - recall: 0.9844 - val_loss: 0.2776 - val_acc: 0.9286 - val_precision: 0.9048 - val_recall: 1.0000
# Epoch 57/100
# 8/8 [==============================] - 0s 37ms/step - loss: 0.1849 - acc: 0.9312 - precision: 0.9059 - recall: 0.9625 - val_loss: 0.2773 - val_acc: 0.9286 - val_precision: 0.9048 - val_recall: 1.0000
# Epoch 58/100
# 8/8 [==============================] - 0s 38ms/step - loss: 0.1560 - acc: 0.9469 - precision: 0.9256 - recall: 0.9719 - val_loss: 0.3167 - val_acc: 0.8571 - val_precision: 0.8261 - val_recall: 1.0000
# Epoch 59/100
# 8/8 [==============================] - 0s 37ms/step - loss: 0.1612 - acc: 0.9375 - precision: 0.9023 - recall: 0.9812 - val_loss: 0.2841 - val_acc: 0.8929 - val_precision: 0.8636 - val_recall: 1.0000
# Epoch 60/100
# 8/8 [==============================] - 0s 38ms/step - loss: 0.1565 - acc: 0.9437 - precision: 0.9176 - recall: 0.9750 - val_loss: 0.2887 - val_acc: 0.8929 - val_precision: 0.8636 - val_recall: 1.0000
# Epoch 61/100
# 8/8 [==============================] - 0s 38ms/step - loss: 0.1600 - acc: 0.9422 - precision: 0.9150 - recall: 0.9750 - val_loss: 0.2647 - val_acc: 0.8929 - val_precision: 0.8636 - val_recall: 1.0000
# Epoch 62/100
# 8/8 [==============================] - 0s 39ms/step - loss: 0.1514 - acc: 0.9516 - precision: 0.9263 - recall: 0.9812 - val_loss: 0.2777 - val_acc: 0.8929 - val_precision: 0.8636 - val_recall: 1.0000
# Epoch 63/100
# 8/8 [==============================] - 0s 39ms/step - loss: 0.1347 - acc: 0.9563 - precision: 0.9320 - recall: 0.9844 - val_loss: 0.2703 - val_acc: 0.8929 - val_precision: 0.8636 - val_recall: 1.0000
# Epoch 64/100
# 8/8 [==============================] - 0s 37ms/step - loss: 0.1419 - acc: 0.9516 - precision: 0.9263 - recall: 0.9812 - val_loss: 0.2636 - val_acc: 0.8929 - val_precision: 0.8636 - val_recall: 1.0000
# Epoch 65/100
# 8/8 [==============================] - 0s 37ms/step - loss: 0.1273 - acc: 0.9563 - precision: 0.9320 - recall: 0.9844 - val_loss: 0.2802 - val_acc: 0.8929 - val_precision: 0.8636 - val_recall: 1.0000
# Epoch 66/100
# 8/8 [==============================] - 0s 39ms/step - loss: 0.1233 - acc: 0.9609 - precision: 0.9403 - recall: 0.9844 - val_loss: 0.2511 - val_acc: 0.8929 - val_precision: 0.8636 - val_recall: 1.0000
# Epoch 67/100
# 8/8 [==============================] - 0s 38ms/step - loss: 0.1224 - acc: 0.9625 - precision: 0.9405 - recall: 0.9875 - val_loss: 0.2753 - val_acc: 0.8929 - val_precision: 0.8636 - val_recall: 1.0000
# Epoch 68/100
# 8/8 [==============================] - 0s 37ms/step - loss: 0.1111 - acc: 0.9734 - precision: 0.9605 - recall: 0.9875 - val_loss: 0.2294 - val_acc: 0.8929 - val_precision: 0.8636 - val_recall: 1.0000
# Epoch 69/100
# 8/8 [==============================] - 0s 38ms/step - loss: 0.1141 - acc: 0.9703 - precision: 0.9547 - recall: 0.9875 - val_loss: 0.2499 - val_acc: 0.8929 - val_precision: 0.8636 - val_recall: 1.0000
# Epoch 70/100
# 8/8 [==============================] - 0s 38ms/step - loss: 0.0988 - acc: 0.9750 - precision: 0.9634 - recall: 0.9875 - val_loss: 0.2419 - val_acc: 0.8929 - val_precision: 0.8636 - val_recall: 1.0000
# Epoch 71/100
# 8/8 [==============================] - 0s 37ms/step - loss: 0.1055 - acc: 0.9703 - precision: 0.9574 - recall: 0.9844 - val_loss: 0.2295 - val_acc: 0.8929 - val_precision: 0.8636 - val_recall: 1.0000
# Epoch 72/100
# 8/8 [==============================] - 0s 38ms/step - loss: 0.0954 - acc: 0.9734 - precision: 0.9605 - recall: 0.9875 - val_loss: 0.2161 - val_acc: 0.8929 - val_precision: 0.8636 - val_recall: 1.0000
# Epoch 73/100
# 8/8 [==============================] - 0s 39ms/step - loss: 0.0865 - acc: 0.9813 - precision: 0.9753 - recall: 0.9875 - val_loss: 0.2621 - val_acc: 0.8929 - val_precision: 0.8636 - val_recall: 1.0000
# Epoch 74/100
# 8/8 [==============================] - 0s 38ms/step - loss: 0.0906 - acc: 0.9750 - precision: 0.9634 - recall: 0.9875 - val_loss: 0.1927 - val_acc: 0.9286 - val_precision: 0.9048 - val_recall: 1.0000
# Epoch 75/100
# 8/8 [==============================] - 0s 38ms/step - loss: 0.0815 - acc: 0.9828 - precision: 0.9783 - recall: 0.9875 - val_loss: 0.2420 - val_acc: 0.8929 - val_precision: 0.8636 - val_recall: 1.0000
# Epoch 76/100
# 8/8 [==============================] - 0s 37ms/step - loss: 0.0829 - acc: 0.9797 - precision: 0.9752 - recall: 0.9844 - val_loss: 0.2116 - val_acc: 0.8929 - val_precision: 0.8636 - val_recall: 1.0000
# Epoch 77/100
# 8/8 [==============================] - 0s 37ms/step - loss: 0.0814 - acc: 0.9766 - precision: 0.9692 - recall: 0.9844 - val_loss: 0.2344 - val_acc: 0.8929 - val_precision: 0.8636 - val_recall: 1.0000
# Epoch 78/100
# 8/8 [==============================] - 0s 37ms/step - loss: 0.0632 - acc: 0.9859 - precision: 0.9814 - recall: 0.9906 - val_loss: 0.2012 - val_acc: 0.8929 - val_precision: 0.8636 - val_recall: 1.0000
# Epoch 79/100
# 8/8 [==============================] - 0s 38ms/step - loss: 0.0721 - acc: 0.9828 - precision: 0.9783 - recall: 0.9875 - val_loss: 0.1906 - val_acc: 0.8929 - val_precision: 0.8636 - val_recall: 1.0000
# Epoch 80/100
# 8/8 [==============================] - 0s 38ms/step - loss: 0.0619 - acc: 0.9828 - precision: 0.9813 - recall: 0.9844 - val_loss: 0.2411 - val_acc: 0.8929 - val_precision: 0.8636 - val_recall: 1.0000
# Epoch 81/100
# 8/8 [==============================] - 0s 38ms/step - loss: 0.0643 - acc: 0.9859 - precision: 0.9785 - recall: 0.9937 - val_loss: 0.1756 - val_acc: 0.9286 - val_precision: 0.9048 - val_recall: 1.0000
# Epoch 82/100
# 8/8 [==============================] - 0s 37ms/step - loss: 0.0512 - acc: 0.9906 - precision: 0.9846 - recall: 0.9969 - val_loss: 0.2201 - val_acc: 0.8929 - val_precision: 0.8636 - val_recall: 1.0000
# Epoch 83/100
# 8/8 [==============================] - 0s 37ms/step - loss: 0.0643 - acc: 0.9828 - precision: 0.9754 - recall: 0.9906 - val_loss: 0.1737 - val_acc: 0.9286 - val_precision: 0.9048 - val_recall: 1.0000
# Epoch 84/100
# 8/8 [==============================] - 0s 37ms/step - loss: 0.0411 - acc: 0.9938 - precision: 0.9907 - recall: 0.9969 - val_loss: 0.1863 - val_acc: 0.8929 - val_precision: 0.8636 - val_recall: 1.0000
# Epoch 85/100
# 8/8 [==============================] - 0s 37ms/step - loss: 0.0653 - acc: 0.9797 - precision: 0.9752 - recall: 0.9844 - val_loss: 0.1691 - val_acc: 0.9286 - val_precision: 0.9048 - val_recall: 1.0000
# Epoch 86/100
# 8/8 [==============================] - 0s 38ms/step - loss: 0.0371 - acc: 0.9984 - precision: 0.9969 - recall: 1.0000 - val_loss: 0.1401 - val_acc: 0.9643 - val_precision: 0.9500 - val_recall: 1.0000
# Epoch 87/100
# 8/8 [==============================] - 0s 41ms/step - loss: 0.0452 - acc: 0.9891 - precision: 0.9845 - recall: 0.9937 - val_loss: 0.1497 - val_acc: 0.9643 - val_precision: 0.9500 - val_recall: 1.0000
# Epoch 88/100
# 8/8 [==============================] - 0s 40ms/step - loss: 0.0465 - acc: 0.9906 - precision: 0.9906 - recall: 0.9906 - val_loss: 0.1495 - val_acc: 0.9286 - val_precision: 0.9048 - val_recall: 1.0000
# Epoch 89/100
# 8/8 [==============================] - 0s 37ms/step - loss: 0.0293 - acc: 0.9984 - precision: 0.9969 - recall: 1.0000 - val_loss: 0.1474 - val_acc: 0.9286 - val_precision: 0.9048 - val_recall: 1.0000
# Epoch 90/100
# 8/8 [==============================] - 0s 38ms/step - loss: 0.0665 - acc: 0.9766 - precision: 0.9721 - recall: 0.9812 - val_loss: 0.1474 - val_acc: 0.9286 - val_precision: 0.9048 - val_recall: 1.0000
# Epoch 91/100
# 8/8 [==============================] - 0s 39ms/step - loss: 0.0274 - acc: 0.9984 - precision: 0.9969 - recall: 1.0000 - val_loss: 0.1464 - val_acc: 0.9286 - val_precision: 0.9048 - val_recall: 1.0000
# Epoch 92/100
# 8/8 [==============================] - 0s 38ms/step - loss: 0.0302 - acc: 0.9969 - precision: 0.9969 - recall: 0.9969 - val_loss: 0.1258 - val_acc: 0.9643 - val_precision: 0.9500 - val_recall: 1.0000
# Epoch 93/100
# 8/8 [==============================] - 0s 37ms/step - loss: 0.0371 - acc: 0.9906 - precision: 0.9876 - recall: 0.9937 - val_loss: 0.1448 - val_acc: 0.9643 - val_precision: 0.9500 - val_recall: 1.0000
# Epoch 94/100
# 8/8 [==============================] - 0s 37ms/step - loss: 0.0317 - acc: 0.9984 - precision: 1.0000 - recall: 0.9969 - val_loss: 0.1365 - val_acc: 0.9286 - val_precision: 0.9048 - val_recall: 1.0000
# Epoch 95/100
# 8/8 [==============================] - 0s 37ms/step - loss: 0.0250 - acc: 0.9984 - precision: 1.0000 - recall: 0.9969 - val_loss: 0.2691 - val_acc: 0.8929 - val_precision: 0.8636 - val_recall: 1.0000
# Epoch 96/100
# 8/8 [==============================] - 0s 37ms/step - loss: 0.0471 - acc: 0.9859 - precision: 0.9814 - recall: 0.9906 - val_loss: 0.1395 - val_acc: 0.9286 - val_precision: 0.9048 - val_recall: 1.0000
# Epoch 97/100
# 8/8 [==============================] - 0s 37ms/step - loss: 0.0198 - acc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.1420 - val_acc: 0.9286 - val_precision: 0.9048 - val_recall: 1.0000
# Epoch 98/100
# 8/8 [==============================] - 0s 37ms/step - loss: 0.0178 - acc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.1506 - val_acc: 0.9286 - val_precision: 0.9048 - val_recall: 1.0000
# Epoch 99/100
# 8/8 [==============================] - 0s 37ms/step - loss: 0.0492 - acc: 0.9875 - precision: 0.9906 - recall: 0.9844 - val_loss: 0.1326 - val_acc: 0.9286 - val_precision: 0.9048 - val_recall: 1.0000
# Epoch 100/100
# 8/8 [==============================] - 0s 37ms/step - loss: 0.0167 - acc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.1319 - val_acc: 0.9286 - val_precision: 0.9048 - val_recall: 1.0000

# %% [markdown]
# # Evaluate Your Model
# Now we will evaluate how well our model has done.

# %% [markdown]
# ## View Metrics Names
# **Execute the following code block to view the names of the metrics used during training:**

# %%
model.metrics_names
# Out:
# ['loss', 'acc', 'precision', 'recall']

# %% [markdown]
# ## Evaluate Model & Print Metrics
# **Execute the following code block to evaluate your model and print the training metrics:**

# %%
score = model.evaluate(X_test, y_test, verbose=0)
score
# Out:
# [0.13190045952796936,
#  0.9285714030265808,
#  0.9047619004535147,
#  0.9999999947368421]

# %% [markdown]
# ## Generate AUC Score
# **Execute the following code block to generate your AUC score:**

# %%
roc_auc_score(y_test, model.predict_proba(X_test))
# Out:
# 0.9941520467836258

# %% [markdown]
# # Results
#
# Below are the training results for 500 epochs.
#
# | Loss   |  Accuracy   | Precision   | Recall   | AUC |
# |------|---|---|--|--|
# | 0.131 (~0.13)  | 0.928 (~93%)   | 0.904 (~0.91)   | 0.999 (~1.0) | 0.994 (~1.0) |

# %% [markdown]
# ## Visualise Metrics

# %% [markdown]
# ### Training Loss & Accuracy

# %%
training_acc = history.history['acc']
training_loss = history.history['loss']

plt.figure(figsize = (8, 8))
plt.subplot(2, 1, 1)
plt.plot(training_acc, label = 'Training Accuracy')
plt.legend(loc = 'lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('Training Accuracy')

plt.subplot(2, 1, 2)
plt.plot(training_loss, label = 'Training Loss')
plt.legend(loc = 'upper right')
plt.ylabel('Cross Entropy')
plt.ylim([0,max(plt.ylim())])
plt.title('Training Loss')
plt.show()

# %% [markdown]
# ### Validation Loss & Accuracy

# %%
validation_acc = history.history['val_acc']
validation_loss = history.history['val_loss']

plt.figure(figsize = (8, 8))
plt.subplot(2, 1, 1)
plt.plot(validation_acc, label = 'Validation Accuracy')
plt.legend(loc = 'lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('Validation Accuracy')

plt.subplot(2, 1, 2)
plt.plot(validation_loss, label = 'Validation Loss')
plt.legend(loc = 'upper right')
plt.ylabel('Cross Entropy')
plt.ylim([0,max(plt.ylim())])
plt.title('Validation Loss')
plt.show()

# %% [markdown]
# ## Predictions

# %%
y_pred = model.predict(X_test)
y_pred
# Out:
# array([[9.5853877e-01, 4.1461233e-02],
#        [9.5855457e-01, 4.1445427e-02],
#        [9.8212218e-01, 1.7877819e-02],
#        [5.0955517e-03, 9.9490440e-01],
#        [9.7323936e-01, 2.6760604e-02],
#        [9.6858448e-01, 3.1415477e-02],
#        [9.4980139e-01, 5.0198603e-02],
#        [9.8384827e-01, 1.6151698e-02],
#        [9.6719402e-01, 3.2805987e-02],
#        [1.0712057e-11, 1.0000000e+00],
#        [9.9171549e-01, 8.2845315e-03],
#        [9.1428918e-01, 8.5710764e-02],
#        [3.2543629e-01, 6.7456371e-01],
#        [9.9219972e-01, 7.8003290e-03],
#        [9.6832764e-01, 3.1672351e-02],
#        [9.8358649e-01, 1.6413543e-02],
#        [2.1114703e-03, 9.9788851e-01],
#        [7.3500109e-01, 2.6499891e-01],
#        [9.7967774e-01, 2.0322230e-02],
#        [3.8563232e-07, 9.9999964e-01],
#        [7.9975569e-01, 2.0024429e-01],
#        [5.6587517e-01, 4.3412486e-01],
#        [9.5997584e-01, 4.0024139e-02],
#        [9.8292333e-01, 1.7076600e-02],
#        [9.7969729e-01, 2.0302707e-02],
#        [8.0113663e-05, 9.9991989e-01],
#        [1.3248472e-06, 9.9999869e-01],
#        [9.7512668e-01, 2.4873352e-02]], dtype=float32)

# %% [markdown]
# ### Confusion Matrix

# %%
matrix = confusion_matrix(y_test.argmax(axis=1), y_pred.argmax(axis=1))
matrix
# Out:
# array([[19,  0],
#        [ 2,  7]])

# %%
plt.imshow(matrix, cmap=plt.cm.Blues)
plt.xlabel("Predicted labels")
plt.ylabel("True labels")
plt.xticks([], [])
plt.yticks([], [])
plt.title('Confusion matrix ')
plt.colorbar()
plt.show()

# %% [markdown]
# ## Results on ALL-IDB (Images)

# %%
TN = matrix[0][0]
FN = matrix[0][1]
TP = matrix[1][0]
FP = matrix[1][1]

(TP, FP, TN, FN)
# Out:
# (2, 7, 19, 0)

# %%
test_len = len(X_test)

TPP = (TP * 100) / test_len
FPP = (FP * 100) / test_len
FNP = (FN * 100) / test_len
TNP = (TN * 100) / test_len

(TPP, FPP, TNP, FNP)
# Out:
# (7.142857142857143, 25.0, 67.85714285714286, 0.0)

# %%
specificity = TN/(TN+FP) 
specificity
# Out:
# 0.7307692307692307

# %%
misc = FP + FN
misc
# Out:
# 7

# %%
misc = (misc * 100) / test_len
misc
# Out:
# 25.0

# %% [markdown]
# | Figures of merit  | Value | Percentage |
# | ----------------  | ----- | ---------- |
# | True Positives | 2 | 7.14% |
# | False Positives | 7 | 25.00%
# | True Negatives | 19 | 67.96% |
# | False Negatives | 0 | 0.00% |
# | Misclassification | 7 | 25.00% |
# | Sensitivity / Recall | 1.0 | 100% |
# | Specificity | 0.73 | 73% |

# %% [markdown]
# # Save Your Keras Model
#
# Now you will save your Keras model and weights so that they can be used again.

# %% [markdown]
# ## Save Model As Json

# %%
with open(model_path, "w") as file:
    file.write(model.to_json())

# %% [markdown]
# ## Save Weights

# %%
model.save_weights(model_root_path + "/weights.h5")

# %% [markdown]
# # Load Your Saved Keras Model

# %%
with open(model_path, "r") as file:
    jmodel = file.read()

K.set_learning_phase(0)
model = model_from_json(jmodel)
model.load_weights(model_root_path + "/weights.h5")

model.summary()
# Out:
# Model: "KAllCnn_IDB1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# zero_padding2d_1 (ZeroPaddin (None, 54, 54, 3)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 50, 50, 30)        2280
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 50, 50, 30)        0
# _________________________________________________________________
# zero_padding2d_2 (ZeroPaddin (None, 54, 54, 30)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 50, 50, 30)        22530
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 25, 25, 30)        0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 25, 25, 30)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 18750)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 37502
# _________________________________________________________________
# activation_1 (Activation)    (None, 2)                 0
# =================================================================
# Total params: 62,312
# Trainable params: 62,312
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Contributing
#
# The Peter Moss Acute Myeloid & Lymphoblastic Leukemia AI Research project encourages and welcomes code contributions, bug fixes and enhancements from the Github.
#
# **Please read the [CONTRIBUTING](https://github.com/AMLResearchProject/AML-ALL-Classifiers/blob/master/CONTRIBUTING.md "CONTRIBUTING") document for a full guide to forking our repositories and submitting your pull requests. You will also find information about our code of conduct on this page.**

# %% [markdown]
# ## Acute Myeloid & Lymphoblastic Leukemia Classifiers Contributors
#
# - [Adam Milton-Barker](https://github.com/AdamMiltonBarker "Adam Milton-Barker") - Bigfinite IoT Network Engineer & Intel Software Innovator, Barcelona, Spain
# - [Salvatore Raieli](https://github.com/salvatorera "Salvatore Raieli") - PhD Immunolgy / Bioinformaticia, Bologna, Italy
# - [Dr Amita Kapoor](https://github.com/salvatorera "Dr Amita Kapoor") - Delhi University, Delhi, India

# %% [markdown]
# # Versioning
#
# We use SemVer for versioning. For the versions available, see [Releases](https://github.com/AMLResearchProject/AML-ALL-Classifiers/releases "Releases").

# %% [markdown]
# # License
#
# This project is licensed under the **MIT License** - see the [LICENSE](https://github.com/AMLResearchProject/AML-ALL-Classifiers/blob/master/LICENSE "LICENSE") file for details.

# %% [markdown]
# # Bugs/Issues
#
# We use the [repo issues](https://github.com/AMLResearchProject/AML-ALL-Classifiers/issues "repo issues") to track bugs and general requests related to using this project.
