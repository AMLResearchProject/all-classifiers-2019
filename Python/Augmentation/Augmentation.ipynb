# %% [markdown]
# # AML/ALL Classifier Data Augmentation
#
# ![Acute Myeloid Leukemia Research Python Classifier](Media/Images/banner.png)
#
# The AML/ALL Classifier Data Augmentation program applies filters to datasets and increases the amount of training / test data available to use. The program is part of the computer vision research and development for the [Peter Moss Acute Myeloid/Lymphoblastic (AML/ALL) Leukemia AI Research Project](https://www.facebook.com/AMLResearchProject/).
#
# Before you start the tutorial on below you should complete the steps in the [Augmentation README](https://github.com/AMLResearchProject/AML-Detection-System/tree/master/Augmentation/)

# %% [markdown]
# # Research papers followed
# The papers that this part of the project is based on were provided by project team member, Ho Leung, Associate Professor of Biochemistry & Molecular Biophysics at Kansas State University.
#
# ## Leukemia Blood Cell Image Classification Using Convolutional Neural Network
# T. T. P. Thanh, Caleb Vununu, Sukhrob Atoev, Suk-Hwan Lee, and Ki-Ryong Kwon
# http://www.ijcte.org/vol10/1198-H0012.pdf

# %% [markdown]
# # Dataset
# The [Acute Lymphoblastic Leukemia Image Database for Image Processing](https://homes.di.unimi.it/scotti/all/) dataset is used for this project. The dataset was created by [Fabio Scotti, Associate Professor Dipartimento di Informatica, Università degli Studi di Milano](https://homes.di.unimi.it/scotti/). Big thanks to Fabio for his research and time put in to creating the dataset and documentation, it is one of his personal projects. You will need to follow the steps outlined [here](https://homes.di.unimi.it/scotti/all/#download) to gain access to the dataset.
#
# ## Data augmentation
#
# ![Acute Myeloid Leukemia Research Python Classifier](Media/Images/slides.png)
#
# I decided to use some augmentation proposals outlined in Leukemia Blood Cell Image Classification Using Convolutional Neural Network by T. T. P. Thanh, Caleb Vununu, Sukhrob Atoev, Suk-Hwan Lee, and Ki-Ryong Kwon. The augmentations I chose were grayscaling, histogram equalization, horizontal and vertical reflection and gaussian blur to start with. Using these techniques so far I have been able to increase a dataset from 49 positive and 49 negative images to 683 positive and 683 negative, with more augmentations to experiment with.
#
# The full Python class that holds the functions mentioned below can be found in [Classes/Data.py](Classes/Data.py), The Data class is a wrapper class around releated functions provided in popular computer vision libraries including as OpenCV and Scipy.
#
# ### Grayscaling
#
# In general grayscaled images are not as complex as color images and result in a less complex model. In the paper the authors described using grayscaling to create more data easily. To create a greyscale copy of each image I wrapped the built in OpenCV function, [cv2.cvtColor()](https://opencv-python-tutroals.readthedocs.io/en/latest/py_tutorials/py_imgproc/py_colorspaces/py_colorspaces.html). The created images will be saved to the relevant directories in the default configuration.
#
#     def grayScale(self, image, grayPath, show = False):
#
#         ###############################################################
#         #
#         # Writes a grayscale copy of the image to the filepath provided.
#         #
#         ###############################################################
#
#         gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
#         self.writeImage(grayPath, gray)
#         if show is True:
#             print(grayPath)
#             plt.imshow(gray)
#             plt.show()
#         return image, gray
#
# ### Histogram Equalization
#
# Histogram equalization is basically stretching the histogram horizontally on both sides, increasing the intensity/contrast. Histogram equalization is described in the paper to enhance the contrast.
#
# In the case of this dataset, it makes both the white and red blood cells more distinguishable. The created images will be saved to the relevant directories in the default configuration.
#
#     def equalizeHist(self, gray, histPath, show = False):
#
#         ###############################################################
#         #
#         # Writes histogram equalized copy of the image to the filepath
#         # provided.
#         #
#         ###############################################################
#
#         hist = cv2.equalizeHist(gray)
#         self.writeImage(histPath, cv2.equalizeHist(gray))
#         if show is True:
#             print(histPath)
#             plt.imshow(hist)
#             plt.show()
#         return hist
#
# ### Reflection
#
# Reflection is a way of increasing your dataset by creating a copy that is fliped on its X axis, and a copy that is flipped on its Y axis. The reflection function below uses the built in OpenCV function, cv2.flip, to flip the image on the mentioned axis.  The created images will be saved to the relevant directories in the default configuration.
#
#     def reflection(self, image, horPath, verPath, show = False):
#
#         ###############################################################
#         #
#         # Writes histogram equalized copy of the image to the filepath
#         # provided.
#         #
#         ###############################################################
#
#         horImg = cv2.flip(image, 0)
#         self.writeImage(horPath, horImg)
#         if show is True:
#             print(horPath)
#             plt.imshow(horImg)
#             plt.show()
#         verImg = cv2.flip( image, 1 )
#         self.writeImage(verPath, verImg)
#         if show is True:
#             print(verPath)
#             plt.imshow(verImg)
#             plt.show()
#         return horImg, verImg
#
# ### Gaussian Blur
#
# Gaussian Blur is a popular technique used on images and is especially popular in the computer vision world. The function below uses the ndimage.gaussian_filter function. The created images will be saved to the relevant directories in the default configuration.
#
#     def gaussian(self, filePath, gaussianPath, show = False):
#
#         ###############################################################
#         #
#         # Writes gaussian blurred copy of the image to the filepath
#         # provided.
#         #
#         ###############################################################
#
#         gaussianBlur = ndimage.gaussian_filter(plt.imread(filePath), sigma=5.11)
#         self.writeImage(gaussianPath, gaussianBlur)
#         if show is True:
#             print(gaussianPath)
#             plt.imshow(gaussianBlur)
#             plt.show()
#         return gaussianBlur
#
# ### Rotation
#
# Gaussian Blur is a popular technique used on images and is especially popular in the computer vision world. The function below uses the ndimage.gaussian_filter function. The created images will be saved to the relevant directories in the default configuration.
#
#     def rotation(self, path, filePath, filename, show = False):
#
#         ###############################################################
#         #
#         # Writes rotated copies of the image to the filepath
#         # provided.
#         #
#         ###############################################################
#
#         img = Image.open(filePath)
#
#         for i in range(1, 10):
#             randDeg = random.randint(-180, 180)
#             fullPath = os.path.join(path, str(randDeg) + '-' + filename)
#             if show is True:
#                 print(fullPath)
#                 img.rotate(randDeg, expand=True).resize((self.confs["Settings"]["ImgDims"], self.confs["Settings"]["ImgDims"])).save(fullPath).show()
#             else:
#                 print(fullPath)
#                 img.rotate(randDeg, expand=True).resize((self.confs["Settings"]["ImgDims"], self.confs["Settings"]["ImgDims"])).save(fullPath)
#
# # Augment your data
# You can use the code below to augment your data. The full Python class that holds the core data functions can be found in [Classes/Data.py](Classes/Data.py). The AMLDnnData class below is a wrapper class around the Data class that allows you to run the code in this Notebook. Follow the steps below and execute the code blocks using __SHIFT + ENTER__.
#
# ## Sort your dataset
# The ALL IDB_1 dataset is the one used in this tutorial. In this dataset there were 49 negative and 59 positive. To make this even I removed 10 images from the positive dataset. From here I removed a further 10 images per class for testing further on in the tutorial and for the purpose of demos etc. In my case I ended up with 20 test images (10 pos/10 neg) and 39 images per class ready for augmentation. Place the original images that you wish to augment into the __Model/Data/0__ & __Model/Data/1__. Using this program I was able to create a dataset of __624__ positive and __624__ negative augmented images.
#
#
# ## Import required libraries
# We are going to run the above code in the browser, to do this you need to run the following code. Execute the code block by placing your cursor inside and clicking __shift__ & __enter__.

# %%
import matplotlib.pyplot as plt

# %matplotlib inline
plt.rcParams['figure.figsize'] = (5.0, 4.0) 
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

from Classes.Data import Data

# %% [markdown]
# ## Initiate the data wrapper
# The following Python class is a wrapper for the [Data (Classes/Data.py)](Classes/Data.py) class.

# %%
class AMLDnnData():
    
    def __init__(self):
        
        ###############################################################
        #
        # Sets up all default requirements and placeholders 
        # needed for the Acute Myeloid Leukemia Classifier. 
        #
        ###############################################################

        self.Data = Data()
        
    def processDataset(self):
        
        ###############################################################
        #
        # Make sure you have your equal amounts of positive and negative
        # samples in the Model/Data directories.
        # 
        # Only run this function once! it will continually make copies 
        # of all images in the Settings->TrainDir directory specified 
        # in Required/confs.json        
        #
        ###############################################################
        
        self.Data.processDataset() 
        
AMLDnnData = AMLDnnData()

# %% [markdown]
# ## Augment the dataset
#
# Make sure you have your equal amounts of positive and negative samples in the Model/Data directories, in my program I use the directories 0 and 1, but you can name them what you like as long as they are integers.
#
# __Only run this function once! it will continually make copies of all images in the Settings->TrainDir directory specified in Required/confs.json__
#
# Execute the following code block to process the dataset by running all of the functions shown above. You may see slides that are a strange color or not square, you can ignore this as the actual saved image is correct.

# %%
# Uncomment the code, only run once!
AMLDnnData.processDataset()
# Out:
# Resized image written to: Model/Augmented/1/Im029_1.jpg
# Grayscaled image written to: Model/Augmented/1/Gray-Im029_1.jpg
# Histogram equalized image written to: Model/Augmented/1/Hist-Im029_1.jpg
# Horizontally reflected image written to: Model/Augmented/1/Hor-Im029_1.jpg
# Vertical reflected image written to: Model/Augmented/1/Ver-Im029_1.jpg
# Gaussian image written to: Model/Augmented/1/Gaus-Im029_1.jpg
# Rotated image written to: Model/Augmented/1/-168-0-Im029_1.jpg
# Rotated image written to: Model/Augmented/1/-174-1-Im029_1.jpg
# Rotated image written to: Model/Augmented/1/-144-2-Im029_1.jpg
# Rotated image written to: Model/Augmented/1/-99-3-Im029_1.jpg
# Rotated image written to: Model/Augmented/1/-139-4-Im029_1.jpg
# Rotated image written to: Model/Augmented/1/39-5-Im029_1.jpg
# Rotated image written to: Model/Augmented/1/-7-6-Im029_1.jpg
# Rotated image written to: Model/Augmented/1/178-7-Im029_1.jpg
# Rotated image written to: Model/Augmented/1/112-8-Im029_1.jpg
# Rotated image written to: Model/Augmented/1/-16-9-Im029_1.jpg
# Total augmented files created so far 16
#
# Resized image written to: Model/Augmented/1/Im030_1.jpg
# Grayscaled image written to: Model/Augmented/1/Gray-Im030_1.jpg
# Histogram equalized image written to: Model/Augmented/1/Hist-Im030_1.jpg
# Horizontally reflected image written to: Model/Augmented/1/Hor-Im030_1.jpg
# Vertical reflected image written to: Model/Augmented/1/Ver-Im030_1.jpg
# Gaussian image written to: Model/Augmented/1/Gaus-Im030_1.jpg
# Rotated image written to: Model/Augmented/1/-48-0-Im030_1.jpg
# Rotated image written to: Model/Augmented/1/-69-1-Im030_1.jpg
# Rotated image written to: Model/Augmented/1/66-2-Im030_1.jpg
# Rotated image written to: Model/Augmented/1/-72-3-Im030_1.jpg
# Rotated image written to: Model/Augmented/1/-136-4-Im030_1.jpg
# Rotated image written to: Model/Augmented/1/-122-5-Im030_1.jpg
# Rotated image written to: Model/Augmented/1/23-6-Im030_1.jpg
# Rotated image written to: Model/Augmented/1/-155-7-Im030_1.jpg
# Rotated image written to: Model/Augmented/1/35-8-Im030_1.jpg
# Rotated image written to: Model/Augmented/1/-121-9-Im030_1.jpg
# Total augmented files created so far 32
#
# Resized image written to: Model/Augmented/1/Im055_1.jpg
# Grayscaled image written to: Model/Augmented/1/Gray-Im055_1.jpg
# Histogram equalized image written to: Model/Augmented/1/Hist-Im055_1.jpg
# Horizontally reflected image written to: Model/Augmented/1/Hor-Im055_1.jpg
# Vertical reflected image written to: Model/Augmented/1/Ver-Im055_1.jpg
# Gaussian image written to: Model/Augmented/1/Gaus-Im055_1.jpg
# Rotated image written to: Model/Augmented/1/68-0-Im055_1.jpg
# Rotated image written to: Model/Augmented/1/150-1-Im055_1.jpg
# Rotated image written to: Model/Augmented/1/112-2-Im055_1.jpg
# Rotated image written to: Model/Augmented/1/84-3-Im055_1.jpg
# Rotated image written to: Model/Augmented/1/-171-4-Im055_1.jpg
# Rotated image written to: Model/Augmented/1/84-5-Im055_1.jpg
# Rotated image written to: Model/Augmented/1/89-6-Im055_1.jpg
# Rotated image written to: Model/Augmented/1/103-7-Im055_1.jpg
# Rotated image written to: Model/Augmented/1/47-8-Im055_1.jpg
# Rotated image written to: Model/Augmented/1/-92-9-Im055_1.jpg
# Total augmented files created so far 48
#
# Resized image written to: Model/Augmented/1/Im026_1.jpg
# Grayscaled image written to: Model/Augmented/1/Gray-Im026_1.jpg
# Histogram equalized image written to: Model/Augmented/1/Hist-Im026_1.jpg
# Horizontally reflected image written to: Model/Augmented/1/Hor-Im026_1.jpg
# Vertical reflected image written to: Model/Augmented/1/Ver-Im026_1.jpg
# Gaussian image written to: Model/Augmented/1/Gaus-Im026_1.jpg
# Rotated image written to: Model/Augmented/1/-164-0-Im026_1.jpg
# Rotated image written to: Model/Augmented/1/137-1-Im026_1.jpg
# Rotated image written to: Model/Augmented/1/-133-2-Im026_1.jpg
# Rotated image written to: Model/Augmented/1/6-3-Im026_1.jpg
# Rotated image written to: Model/Augmented/1/156-4-Im026_1.jpg
# Rotated image written to: Model/Augmented/1/-43-5-Im026_1.jpg
# Rotated image written to: Model/Augmented/1/-86-6-Im026_1.jpg
# Rotated image written to: Model/Augmented/1/96-7-Im026_1.jpg
# Rotated image written to: Model/Augmented/1/163-8-Im026_1.jpg
# Rotated image written to: Model/Augmented/1/54-9-Im026_1.jpg
# Total augmented files created so far 64
#
# Resized image written to: Model/Augmented/1/Im019_1.jpg
# Grayscaled image written to: Model/Augmented/1/Gray-Im019_1.jpg
# Histogram equalized image written to: Model/Augmented/1/Hist-Im019_1.jpg
# Horizontally reflected image written to: Model/Augmented/1/Hor-Im019_1.jpg
# Vertical reflected image written to: Model/Augmented/1/Ver-Im019_1.jpg
# Gaussian image written to: Model/Augmented/1/Gaus-Im019_1.jpg
# Rotated image written to: Model/Augmented/1/-67-0-Im019_1.jpg
# Rotated image written to: Model/Augmented/1/25-1-Im019_1.jpg
# Rotated image written to: Model/Augmented/1/131-2-Im019_1.jpg
# Rotated image written to: Model/Augmented/1/95-3-Im019_1.jpg
# Rotated image written to: Model/Augmented/1/70-4-Im019_1.jpg
# Rotated image written to: Model/Augmented/1/-74-5-Im019_1.jpg
# Rotated image written to: Model/Augmented/1/168-6-Im019_1.jpg
# Rotated image written to: Model/Augmented/1/6-7-Im019_1.jpg
# Rotated image written to: Model/Augmented/1/-42-8-Im019_1.jpg
# Rotated image written to: Model/Augmented/1/83-9-Im019_1.jpg
# Total augmented files created so far 80
#
# Resized image written to: Model/Augmented/1/Im052_1.jpg
# Grayscaled image written to: Model/Augmented/1/Gray-Im052_1.jpg
# Histogram equalized image written to: Model/Augmented/1/Hist-Im052_1.jpg
# Horizontally reflected image written to: Model/Augmented/1/Hor-Im052_1.jpg
# Vertical reflected image written to: Model/Augmented/1/Ver-Im052_1.jpg
# Gaussian image written to: Model/Augmented/1/Gaus-Im052_1.jpg
# Rotated image written to: Model/Augmented/1/100-0-Im052_1.jpg
# Rotated image written to: Model/Augmented/1/-109-1-Im052_1.jpg
# Rotated image written to: Model/Augmented/1/53-2-Im052_1.jpg
# Rotated image written to: Model/Augmented/1/114-3-Im052_1.jpg
# Rotated image written to: Model/Augmented/1/174-4-Im052_1.jpg
# Rotated image written to: Model/Augmented/1/-93-5-Im052_1.jpg
# Rotated image written to: Model/Augmented/1/-131-6-Im052_1.jpg
# Rotated image written to: Model/Augmented/1/-155-7-Im052_1.jpg
# Rotated image written to: Model/Augmented/1/0-8-Im052_1.jpg
# Rotated image written to: Model/Augmented/1/-61-9-Im052_1.jpg
# Total augmented files created so far 96
#
# Resized image written to: Model/Augmented/1/Im015_1.jpg
# Grayscaled image written to: Model/Augmented/1/Gray-Im015_1.jpg
# Histogram equalized image written to: Model/Augmented/1/Hist-Im015_1.jpg
# Horizontally reflected image written to: Model/Augmented/1/Hor-Im015_1.jpg
# Vertical reflected image written to: Model/Augmented/1/Ver-Im015_1.jpg
# Gaussian image written to: Model/Augmented/1/Gaus-Im015_1.jpg
# Rotated image written to: Model/Augmented/1/13-0-Im015_1.jpg
# Rotated image written to: Model/Augmented/1/131-1-Im015_1.jpg
# Rotated image written to: Model/Augmented/1/152-2-Im015_1.jpg
# Rotated image written to: Model/Augmented/1/-31-3-Im015_1.jpg
# Rotated image written to: Model/Augmented/1/-41-4-Im015_1.jpg
# Rotated image written to: Model/Augmented/1/-137-5-Im015_1.jpg
# Rotated image written to: Model/Augmented/1/130-6-Im015_1.jpg
# Rotated image written to: Model/Augmented/1/89-7-Im015_1.jpg
# Rotated image written to: Model/Augmented/1/-121-8-Im015_1.jpg
# Rotated image written to: Model/Augmented/1/-126-9-Im015_1.jpg
# Total augmented files created so far 112
#
# Resized image written to: Model/Augmented/1/Im018_1.jpg
# Grayscaled image written to: Model/Augmented/1/Gray-Im018_1.jpg
# Histogram equalized image written to: Model/Augmented/1/Hist-Im018_1.jpg
# Horizontally reflected image written to: Model/Augmented/1/Hor-Im018_1.jpg
# Vertical reflected image written to: Model/Augmented/1/Ver-Im018_1.jpg
# Gaussian image written to: Model/Augmented/1/Gaus-Im018_1.jpg
# Rotated image written to: Model/Augmented/1/79-0-Im018_1.jpg
# Rotated image written to: Model/Augmented/1/144-1-Im018_1.jpg
# Rotated image written to: Model/Augmented/1/166-2-Im018_1.jpg
# Rotated image written to: Model/Augmented/1/177-3-Im018_1.jpg
# Rotated image written to: Model/Augmented/1/-15-4-Im018_1.jpg
# Rotated image written to: Model/Augmented/1/95-5-Im018_1.jpg
# Rotated image written to: Model/Augmented/1/166-6-Im018_1.jpg
# Rotated image written to: Model/Augmented/1/-104-7-Im018_1.jpg
# Rotated image written to: Model/Augmented/1/-81-8-Im018_1.jpg
# Rotated image written to: Model/Augmented/1/-155-9-Im018_1.jpg
# Total augmented files created so far 128
#
# Resized image written to: Model/Augmented/1/Im063_1.jpg
# Grayscaled image written to: Model/Augmented/1/Gray-Im063_1.jpg
# Histogram equalized image written to: Model/Augmented/1/Hist-Im063_1.jpg
# Horizontally reflected image written to: Model/Augmented/1/Hor-Im063_1.jpg
# Vertical reflected image written to: Model/Augmented/1/Ver-Im063_1.jpg
# Gaussian image written to: Model/Augmented/1/Gaus-Im063_1.jpg
# Rotated image written to: Model/Augmented/1/171-0-Im063_1.jpg
# Rotated image written to: Model/Augmented/1/68-1-Im063_1.jpg
# Rotated image written to: Model/Augmented/1/168-2-Im063_1.jpg
# Rotated image written to: Model/Augmented/1/37-3-Im063_1.jpg
# Rotated image written to: Model/Augmented/1/82-4-Im063_1.jpg
# Rotated image written to: Model/Augmented/1/179-5-Im063_1.jpg
# Rotated image written to: Model/Augmented/1/-39-6-Im063_1.jpg
# Rotated image written to: Model/Augmented/1/125-7-Im063_1.jpg
# Rotated image written to: Model/Augmented/1/-153-8-Im063_1.jpg
# Rotated image written to: Model/Augmented/1/-33-9-Im063_1.jpg
# Total augmented files created so far 144
#
# Resized image written to: Model/Augmented/1/Im003_1.jpg
# Grayscaled image written to: Model/Augmented/1/Gray-Im003_1.jpg
# Histogram equalized image written to: Model/Augmented/1/Hist-Im003_1.jpg
# Horizontally reflected image written to: Model/Augmented/1/Hor-Im003_1.jpg
# Vertical reflected image written to: Model/Augmented/1/Ver-Im003_1.jpg
# Gaussian image written to: Model/Augmented/1/Gaus-Im003_1.jpg
# Rotated image written to: Model/Augmented/1/-178-0-Im003_1.jpg
# Rotated image written to: Model/Augmented/1/111-1-Im003_1.jpg
# Rotated image written to: Model/Augmented/1/65-2-Im003_1.jpg
# Rotated image written to: Model/Augmented/1/-17-3-Im003_1.jpg
# Rotated image written to: Model/Augmented/1/-104-4-Im003_1.jpg
# Rotated image written to: Model/Augmented/1/152-5-Im003_1.jpg
# Rotated image written to: Model/Augmented/1/25-6-Im003_1.jpg
# Rotated image written to: Model/Augmented/1/64-7-Im003_1.jpg
# Rotated image written to: Model/Augmented/1/-132-8-Im003_1.jpg
# Rotated image written to: Model/Augmented/1/-107-9-Im003_1.jpg
# Total augmented files created so far 160
#
# Resized image written to: Model/Augmented/1/Im050_1.jpg
# Grayscaled image written to: Model/Augmented/1/Gray-Im050_1.jpg
# Histogram equalized image written to: Model/Augmented/1/Hist-Im050_1.jpg
# Horizontally reflected image written to: Model/Augmented/1/Hor-Im050_1.jpg
# Vertical reflected image written to: Model/Augmented/1/Ver-Im050_1.jpg
# Gaussian image written to: Model/Augmented/1/Gaus-Im050_1.jpg
# Rotated image written to: Model/Augmented/1/37-0-Im050_1.jpg
# Rotated image written to: Model/Augmented/1/75-1-Im050_1.jpg
# Rotated image written to: Model/Augmented/1/72-2-Im050_1.jpg
# Rotated image written to: Model/Augmented/1/-172-3-Im050_1.jpg
# Rotated image written to: Model/Augmented/1/151-4-Im050_1.jpg
# Rotated image written to: Model/Augmented/1/-179-5-Im050_1.jpg
# Rotated image written to: Model/Augmented/1/89-6-Im050_1.jpg
# Rotated image written to: Model/Augmented/1/-142-7-Im050_1.jpg
# Rotated image written to: Model/Augmented/1/-5-8-Im050_1.jpg
# Rotated image written to: Model/Augmented/1/-8-9-Im050_1.jpg
# Total augmented files created so far 176
#
# Resized image written to: Model/Augmented/1/Im002_1.jpg
# Grayscaled image written to: Model/Augmented/1/Gray-Im002_1.jpg
# Histogram equalized image written to: Model/Augmented/1/Hist-Im002_1.jpg
# Horizontally reflected image written to: Model/Augmented/1/Hor-Im002_1.jpg
# Vertical reflected image written to: Model/Augmented/1/Ver-Im002_1.jpg
# Gaussian image written to: Model/Augmented/1/Gaus-Im002_1.jpg
# Rotated image written to: Model/Augmented/1/174-0-Im002_1.jpg
# Rotated image written to: Model/Augmented/1/-158-1-Im002_1.jpg
# Rotated image written to: Model/Augmented/1/63-2-Im002_1.jpg
# Rotated image written to: Model/Augmented/1/-126-3-Im002_1.jpg
# Rotated image written to: Model/Augmented/1/-93-4-Im002_1.jpg
# Rotated image written to: Model/Augmented/1/-79-5-Im002_1.jpg
# Rotated image written to: Model/Augmented/1/-62-6-Im002_1.jpg
# Rotated image written to: Model/Augmented/1/-166-7-Im002_1.jpg
# Rotated image written to: Model/Augmented/1/33-8-Im002_1.jpg
# Rotated image written to: Model/Augmented/1/-158-9-Im002_1.jpg
# Total augmented files created so far 192
#
# Resized image written to: Model/Augmented/1/Im009_1.jpg
# Grayscaled image written to: Model/Augmented/1/Gray-Im009_1.jpg
# Histogram equalized image written to: Model/Augmented/1/Hist-Im009_1.jpg
# Horizontally reflected image written to: Model/Augmented/1/Hor-Im009_1.jpg
# Vertical reflected image written to: Model/Augmented/1/Ver-Im009_1.jpg
# Gaussian image written to: Model/Augmented/1/Gaus-Im009_1.jpg
# Rotated image written to: Model/Augmented/1/-10-0-Im009_1.jpg
# Rotated image written to: Model/Augmented/1/-34-1-Im009_1.jpg
# Rotated image written to: Model/Augmented/1/128-2-Im009_1.jpg
# Rotated image written to: Model/Augmented/1/90-3-Im009_1.jpg
# Rotated image written to: Model/Augmented/1/-44-4-Im009_1.jpg
# Rotated image written to: Model/Augmented/1/66-5-Im009_1.jpg
# Rotated image written to: Model/Augmented/1/-102-6-Im009_1.jpg
# Rotated image written to: Model/Augmented/1/-153-7-Im009_1.jpg
# Rotated image written to: Model/Augmented/1/-164-8-Im009_1.jpg
# Rotated image written to: Model/Augmented/1/-14-9-Im009_1.jpg
# Total augmented files created so far 208
#
# Resized image written to: Model/Augmented/1/Im004_1.jpg
# Grayscaled image written to: Model/Augmented/1/Gray-Im004_1.jpg
# Histogram equalized image written to: Model/Augmented/1/Hist-Im004_1.jpg
# Horizontally reflected image written to: Model/Augmented/1/Hor-Im004_1.jpg
# Vertical reflected image written to: Model/Augmented/1/Ver-Im004_1.jpg
# Gaussian image written to: Model/Augmented/1/Gaus-Im004_1.jpg
# Rotated image written to: Model/Augmented/1/179-0-Im004_1.jpg
# Rotated image written to: Model/Augmented/1/-157-1-Im004_1.jpg
# Rotated image written to: Model/Augmented/1/89-2-Im004_1.jpg
# Rotated image written to: Model/Augmented/1/-91-3-Im004_1.jpg
# Rotated image written to: Model/Augmented/1/174-4-Im004_1.jpg
# Rotated image written to: Model/Augmented/1/92-5-Im004_1.jpg
# Rotated image written to: Model/Augmented/1/15-6-Im004_1.jpg
# Rotated image written to: Model/Augmented/1/-42-7-Im004_1.jpg
# Rotated image written to: Model/Augmented/1/87-8-Im004_1.jpg
# Rotated image written to: Model/Augmented/1/-91-9-Im004_1.jpg
# Total augmented files created so far 224
#
# Resized image written to: Model/Augmented/1/Im048_1.jpg
# Grayscaled image written to: Model/Augmented/1/Gray-Im048_1.jpg
# Histogram equalized image written to: Model/Augmented/1/Hist-Im048_1.jpg
# Horizontally reflected image written to: Model/Augmented/1/Hor-Im048_1.jpg
# Vertical reflected image written to: Model/Augmented/1/Ver-Im048_1.jpg
# Gaussian image written to: Model/Augmented/1/Gaus-Im048_1.jpg
# Rotated image written to: Model/Augmented/1/65-0-Im048_1.jpg
# Rotated image written to: Model/Augmented/1/-147-1-Im048_1.jpg
# Rotated image written to: Model/Augmented/1/-11-2-Im048_1.jpg
# Rotated image written to: Model/Augmented/1/165-3-Im048_1.jpg
# Rotated image written to: Model/Augmented/1/-102-4-Im048_1.jpg
# Rotated image written to: Model/Augmented/1/130-5-Im048_1.jpg
# Rotated image written to: Model/Augmented/1/59-6-Im048_1.jpg
# Rotated image written to: Model/Augmented/1/58-7-Im048_1.jpg
# Rotated image written to: Model/Augmented/1/86-8-Im048_1.jpg
# Rotated image written to: Model/Augmented/1/46-9-Im048_1.jpg
# Total augmented files created so far 240
#
# Resized image written to: Model/Augmented/1/Im060_1.jpg
# Grayscaled image written to: Model/Augmented/1/Gray-Im060_1.jpg
# Histogram equalized image written to: Model/Augmented/1/Hist-Im060_1.jpg
# Horizontally reflected image written to: Model/Augmented/1/Hor-Im060_1.jpg
# Vertical reflected image written to: Model/Augmented/1/Ver-Im060_1.jpg
# Gaussian image written to: Model/Augmented/1/Gaus-Im060_1.jpg
# Rotated image written to: Model/Augmented/1/-35-0-Im060_1.jpg
# Rotated image written to: Model/Augmented/1/64-1-Im060_1.jpg
# Rotated image written to: Model/Augmented/1/-144-2-Im060_1.jpg
# Rotated image written to: Model/Augmented/1/-105-3-Im060_1.jpg
# Rotated image written to: Model/Augmented/1/-159-4-Im060_1.jpg
# Rotated image written to: Model/Augmented/1/10-5-Im060_1.jpg
# Rotated image written to: Model/Augmented/1/36-6-Im060_1.jpg
# Rotated image written to: Model/Augmented/1/88-7-Im060_1.jpg
# Rotated image written to: Model/Augmented/1/-126-8-Im060_1.jpg
# Rotated image written to: Model/Augmented/1/76-9-Im060_1.jpg
# Total augmented files created so far 256
#
# Resized image written to: Model/Augmented/1/Im020_1.jpg
# Grayscaled image written to: Model/Augmented/1/Gray-Im020_1.jpg
# Histogram equalized image written to: Model/Augmented/1/Hist-Im020_1.jpg
# Horizontally reflected image written to: Model/Augmented/1/Hor-Im020_1.jpg
# Vertical reflected image written to: Model/Augmented/1/Ver-Im020_1.jpg
# Gaussian image written to: Model/Augmented/1/Gaus-Im020_1.jpg
# Rotated image written to: Model/Augmented/1/102-0-Im020_1.jpg
# Rotated image written to: Model/Augmented/1/-62-1-Im020_1.jpg
# Rotated image written to: Model/Augmented/1/-42-2-Im020_1.jpg
# Rotated image written to: Model/Augmented/1/-100-3-Im020_1.jpg
# Rotated image written to: Model/Augmented/1/-115-4-Im020_1.jpg
# Rotated image written to: Model/Augmented/1/-13-5-Im020_1.jpg
# Rotated image written to: Model/Augmented/1/147-6-Im020_1.jpg
# Rotated image written to: Model/Augmented/1/122-7-Im020_1.jpg
# Rotated image written to: Model/Augmented/1/-156-8-Im020_1.jpg
# Rotated image written to: Model/Augmented/1/63-9-Im020_1.jpg
# Total augmented files created so far 272
#
# Resized image written to: Model/Augmented/1/Im011_1.jpg
# Grayscaled image written to: Model/Augmented/1/Gray-Im011_1.jpg
# Histogram equalized image written to: Model/Augmented/1/Hist-Im011_1.jpg
# Horizontally reflected image written to: Model/Augmented/1/Hor-Im011_1.jpg
# Vertical reflected image written to: Model/Augmented/1/Ver-Im011_1.jpg
# Gaussian image written to: Model/Augmented/1/Gaus-Im011_1.jpg
# Rotated image written to: Model/Augmented/1/-157-0-Im011_1.jpg
# Rotated image written to: Model/Augmented/1/104-1-Im011_1.jpg
# Rotated image written to: Model/Augmented/1/-51-2-Im011_1.jpg
# Rotated image written to: Model/Augmented/1/139-3-Im011_1.jpg
# Rotated image written to: Model/Augmented/1/-61-4-Im011_1.jpg
# Rotated image written to: Model/Augmented/1/-14-5-Im011_1.jpg
# Rotated image written to: Model/Augmented/1/-96-6-Im011_1.jpg
# Rotated image written to: Model/Augmented/1/-131-7-Im011_1.jpg
# Rotated image written to: Model/Augmented/1/-57-8-Im011_1.jpg
# Rotated image written to: Model/Augmented/1/-74-9-Im011_1.jpg
# Total augmented files created so far 288
#
# Resized image written to: Model/Augmented/1/Im008_1.jpg
# Grayscaled image written to: Model/Augmented/1/Gray-Im008_1.jpg
# Histogram equalized image written to: Model/Augmented/1/Hist-Im008_1.jpg
# Horizontally reflected image written to: Model/Augmented/1/Hor-Im008_1.jpg
# Vertical reflected image written to: Model/Augmented/1/Ver-Im008_1.jpg
# Gaussian image written to: Model/Augmented/1/Gaus-Im008_1.jpg
# Rotated image written to: Model/Augmented/1/-75-0-Im008_1.jpg
# Rotated image written to: Model/Augmented/1/-47-1-Im008_1.jpg
# Rotated image written to: Model/Augmented/1/99-2-Im008_1.jpg
# Rotated image written to: Model/Augmented/1/39-3-Im008_1.jpg
# Rotated image written to: Model/Augmented/1/-132-4-Im008_1.jpg
# Rotated image written to: Model/Augmented/1/-168-5-Im008_1.jpg
# Rotated image written to: Model/Augmented/1/1-6-Im008_1.jpg
# Rotated image written to: Model/Augmented/1/-19-7-Im008_1.jpg
# Rotated image written to: Model/Augmented/1/139-8-Im008_1.jpg
# Rotated image written to: Model/Augmented/1/-106-9-Im008_1.jpg
# Total augmented files created so far 304
#
# Resized image written to: Model/Augmented/1/Im051_1.jpg
# Grayscaled image written to: Model/Augmented/1/Gray-Im051_1.jpg
# Histogram equalized image written to: Model/Augmented/1/Hist-Im051_1.jpg
# Horizontally reflected image written to: Model/Augmented/1/Hor-Im051_1.jpg
# Vertical reflected image written to: Model/Augmented/1/Ver-Im051_1.jpg
# Gaussian image written to: Model/Augmented/1/Gaus-Im051_1.jpg
# Rotated image written to: Model/Augmented/1/83-0-Im051_1.jpg
# Rotated image written to: Model/Augmented/1/-85-1-Im051_1.jpg
# Rotated image written to: Model/Augmented/1/11-2-Im051_1.jpg
# Rotated image written to: Model/Augmented/1/84-3-Im051_1.jpg
# Rotated image written to: Model/Augmented/1/-123-4-Im051_1.jpg
# Rotated image written to: Model/Augmented/1/149-5-Im051_1.jpg
# Rotated image written to: Model/Augmented/1/-142-6-Im051_1.jpg
# Rotated image written to: Model/Augmented/1/-169-7-Im051_1.jpg
# Rotated image written to: Model/Augmented/1/69-8-Im051_1.jpg
# Rotated image written to: Model/Augmented/1/-77-9-Im051_1.jpg
# Total augmented files created so far 320
#
# Resized image written to: Model/Augmented/1/Im028_1.jpg
# Grayscaled image written to: Model/Augmented/1/Gray-Im028_1.jpg
# Histogram equalized image written to: Model/Augmented/1/Hist-Im028_1.jpg
# Horizontally reflected image written to: Model/Augmented/1/Hor-Im028_1.jpg
# Vertical reflected image written to: Model/Augmented/1/Ver-Im028_1.jpg
# Gaussian image written to: Model/Augmented/1/Gaus-Im028_1.jpg
# Rotated image written to: Model/Augmented/1/-45-0-Im028_1.jpg
# Rotated image written to: Model/Augmented/1/-83-1-Im028_1.jpg
# Rotated image written to: Model/Augmented/1/45-2-Im028_1.jpg
# Rotated image written to: Model/Augmented/1/-140-3-Im028_1.jpg
# Rotated image written to: Model/Augmented/1/8-4-Im028_1.jpg
# Rotated image written to: Model/Augmented/1/22-5-Im028_1.jpg
# Rotated image written to: Model/Augmented/1/51-6-Im028_1.jpg
# Rotated image written to: Model/Augmented/1/-62-7-Im028_1.jpg
# Rotated image written to: Model/Augmented/1/69-8-Im028_1.jpg
# Rotated image written to: Model/Augmented/1/-170-9-Im028_1.jpg
# Total augmented files created so far 336
#
# Resized image written to: Model/Augmented/1/Im053_1.jpg
# Grayscaled image written to: Model/Augmented/1/Gray-Im053_1.jpg
# Histogram equalized image written to: Model/Augmented/1/Hist-Im053_1.jpg
# Horizontally reflected image written to: Model/Augmented/1/Hor-Im053_1.jpg
# Vertical reflected image written to: Model/Augmented/1/Ver-Im053_1.jpg
# Gaussian image written to: Model/Augmented/1/Gaus-Im053_1.jpg
# Rotated image written to: Model/Augmented/1/125-0-Im053_1.jpg
# Rotated image written to: Model/Augmented/1/76-1-Im053_1.jpg
# Rotated image written to: Model/Augmented/1/0-2-Im053_1.jpg
# Rotated image written to: Model/Augmented/1/159-3-Im053_1.jpg
# Rotated image written to: Model/Augmented/1/-139-4-Im053_1.jpg
# Rotated image written to: Model/Augmented/1/170-5-Im053_1.jpg
# Rotated image written to: Model/Augmented/1/-66-6-Im053_1.jpg
# Rotated image written to: Model/Augmented/1/-78-7-Im053_1.jpg
# Rotated image written to: Model/Augmented/1/70-8-Im053_1.jpg
# Rotated image written to: Model/Augmented/1/-117-9-Im053_1.jpg
# Total augmented files created so far 352
#
# Resized image written to: Model/Augmented/1/Im024_1.jpg
# Grayscaled image written to: Model/Augmented/1/Gray-Im024_1.jpg
# Histogram equalized image written to: Model/Augmented/1/Hist-Im024_1.jpg
# Horizontally reflected image written to: Model/Augmented/1/Hor-Im024_1.jpg
# Vertical reflected image written to: Model/Augmented/1/Ver-Im024_1.jpg
# Gaussian image written to: Model/Augmented/1/Gaus-Im024_1.jpg
# Rotated image written to: Model/Augmented/1/-73-0-Im024_1.jpg
# Rotated image written to: Model/Augmented/1/-83-1-Im024_1.jpg
# Rotated image written to: Model/Augmented/1/-157-2-Im024_1.jpg
# Rotated image written to: Model/Augmented/1/-45-3-Im024_1.jpg
# Rotated image written to: Model/Augmented/1/-88-4-Im024_1.jpg
# Rotated image written to: Model/Augmented/1/-144-5-Im024_1.jpg
# Rotated image written to: Model/Augmented/1/68-6-Im024_1.jpg
# Rotated image written to: Model/Augmented/1/-146-7-Im024_1.jpg
# Rotated image written to: Model/Augmented/1/-123-8-Im024_1.jpg
# Rotated image written to: Model/Augmented/1/-177-9-Im024_1.jpg
# Total augmented files created so far 368
#
# Resized image written to: Model/Augmented/1/Im059_1.jpg
# Grayscaled image written to: Model/Augmented/1/Gray-Im059_1.jpg
# Histogram equalized image written to: Model/Augmented/1/Hist-Im059_1.jpg
# Horizontally reflected image written to: Model/Augmented/1/Hor-Im059_1.jpg
# Vertical reflected image written to: Model/Augmented/1/Ver-Im059_1.jpg
# Gaussian image written to: Model/Augmented/1/Gaus-Im059_1.jpg
# Rotated image written to: Model/Augmented/1/54-0-Im059_1.jpg
# Rotated image written to: Model/Augmented/1/29-1-Im059_1.jpg
# Rotated image written to: Model/Augmented/1/-98-2-Im059_1.jpg
# Rotated image written to: Model/Augmented/1/135-3-Im059_1.jpg
# Rotated image written to: Model/Augmented/1/-106-4-Im059_1.jpg
# Rotated image written to: Model/Augmented/1/-8-5-Im059_1.jpg
# Rotated image written to: Model/Augmented/1/131-6-Im059_1.jpg
# Rotated image written to: Model/Augmented/1/-55-7-Im059_1.jpg
# Rotated image written to: Model/Augmented/1/-85-8-Im059_1.jpg
# Rotated image written to: Model/Augmented/1/-47-9-Im059_1.jpg
# Total augmented files created so far 384
#
# Resized image written to: Model/Augmented/1/Im016_1.jpg
# Grayscaled image written to: Model/Augmented/1/Gray-Im016_1.jpg
# Histogram equalized image written to: Model/Augmented/1/Hist-Im016_1.jpg
# Horizontally reflected image written to: Model/Augmented/1/Hor-Im016_1.jpg
# Vertical reflected image written to: Model/Augmented/1/Ver-Im016_1.jpg
# Gaussian image written to: Model/Augmented/1/Gaus-Im016_1.jpg
# Rotated image written to: Model/Augmented/1/111-0-Im016_1.jpg
# Rotated image written to: Model/Augmented/1/-138-1-Im016_1.jpg
# Rotated image written to: Model/Augmented/1/-115-2-Im016_1.jpg
# Rotated image written to: Model/Augmented/1/-18-3-Im016_1.jpg
# Rotated image written to: Model/Augmented/1/-171-4-Im016_1.jpg
# Rotated image written to: Model/Augmented/1/-161-5-Im016_1.jpg
# Rotated image written to: Model/Augmented/1/-25-6-Im016_1.jpg
# Rotated image written to: Model/Augmented/1/80-7-Im016_1.jpg
# Rotated image written to: Model/Augmented/1/164-8-Im016_1.jpg
# Rotated image written to: Model/Augmented/1/-117-9-Im016_1.jpg
# Total augmented files created so far 400
#
# Resized image written to: Model/Augmented/1/Im007_1.jpg
# Grayscaled image written to: Model/Augmented/1/Gray-Im007_1.jpg
# Histogram equalized image written to: Model/Augmented/1/Hist-Im007_1.jpg
# Horizontally reflected image written to: Model/Augmented/1/Hor-Im007_1.jpg
# Vertical reflected image written to: Model/Augmented/1/Ver-Im007_1.jpg
# Gaussian image written to: Model/Augmented/1/Gaus-Im007_1.jpg
# Rotated image written to: Model/Augmented/1/-154-0-Im007_1.jpg
# Rotated image written to: Model/Augmented/1/162-1-Im007_1.jpg
# Rotated image written to: Model/Augmented/1/18-2-Im007_1.jpg
# Rotated image written to: Model/Augmented/1/-38-3-Im007_1.jpg
# Rotated image written to: Model/Augmented/1/160-4-Im007_1.jpg
# Rotated image written to: Model/Augmented/1/-12-5-Im007_1.jpg
# Rotated image written to: Model/Augmented/1/-11-6-Im007_1.jpg
# Rotated image written to: Model/Augmented/1/75-7-Im007_1.jpg
# Rotated image written to: Model/Augmented/1/-178-8-Im007_1.jpg
# Rotated image written to: Model/Augmented/1/126-9-Im007_1.jpg
# Total augmented files created so far 416
#
# Resized image written to: Model/Augmented/1/Im054_1.jpg
# Grayscaled image written to: Model/Augmented/1/Gray-Im054_1.jpg
# Histogram equalized image written to: Model/Augmented/1/Hist-Im054_1.jpg
# Horizontally reflected image written to: Model/Augmented/1/Hor-Im054_1.jpg
# Vertical reflected image written to: Model/Augmented/1/Ver-Im054_1.jpg
# Gaussian image written to: Model/Augmented/1/Gaus-Im054_1.jpg
# Rotated image written to: Model/Augmented/1/53-0-Im054_1.jpg
# Rotated image written to: Model/Augmented/1/-51-1-Im054_1.jpg
# Rotated image written to: Model/Augmented/1/64-2-Im054_1.jpg
# Rotated image written to: Model/Augmented/1/-22-3-Im054_1.jpg
# Rotated image written to: Model/Augmented/1/128-4-Im054_1.jpg
# Rotated image written to: Model/Augmented/1/168-5-Im054_1.jpg
# Rotated image written to: Model/Augmented/1/34-6-Im054_1.jpg
# Rotated image written to: Model/Augmented/1/22-7-Im054_1.jpg
# Rotated image written to: Model/Augmented/1/86-8-Im054_1.jpg
# Rotated image written to: Model/Augmented/1/-113-9-Im054_1.jpg
# Total augmented files created so far 432
#
# Resized image written to: Model/Augmented/1/Im012_1.jpg
# Grayscaled image written to: Model/Augmented/1/Gray-Im012_1.jpg
# Histogram equalized image written to: Model/Augmented/1/Hist-Im012_1.jpg
# Horizontally reflected image written to: Model/Augmented/1/Hor-Im012_1.jpg
# Vertical reflected image written to: Model/Augmented/1/Ver-Im012_1.jpg
# Gaussian image written to: Model/Augmented/1/Gaus-Im012_1.jpg
# Rotated image written to: Model/Augmented/1/165-0-Im012_1.jpg
# Rotated image written to: Model/Augmented/1/-31-1-Im012_1.jpg
# Rotated image written to: Model/Augmented/1/-151-2-Im012_1.jpg
# Rotated image written to: Model/Augmented/1/-34-3-Im012_1.jpg
# Rotated image written to: Model/Augmented/1/88-4-Im012_1.jpg
# Rotated image written to: Model/Augmented/1/-23-5-Im012_1.jpg
# Rotated image written to: Model/Augmented/1/126-6-Im012_1.jpg
# Rotated image written to: Model/Augmented/1/154-7-Im012_1.jpg
# Rotated image written to: Model/Augmented/1/-32-8-Im012_1.jpg
# Rotated image written to: Model/Augmented/1/-124-9-Im012_1.jpg
# Total augmented files created so far 448
#
# Resized image written to: Model/Augmented/1/Im023_1.jpg
# Grayscaled image written to: Model/Augmented/1/Gray-Im023_1.jpg
# Histogram equalized image written to: Model/Augmented/1/Hist-Im023_1.jpg
# Horizontally reflected image written to: Model/Augmented/1/Hor-Im023_1.jpg
# Vertical reflected image written to: Model/Augmented/1/Ver-Im023_1.jpg
# Gaussian image written to: Model/Augmented/1/Gaus-Im023_1.jpg
# Rotated image written to: Model/Augmented/1/68-0-Im023_1.jpg
# Rotated image written to: Model/Augmented/1/-17-1-Im023_1.jpg
# Rotated image written to: Model/Augmented/1/139-2-Im023_1.jpg
# Rotated image written to: Model/Augmented/1/67-3-Im023_1.jpg
# Rotated image written to: Model/Augmented/1/-37-4-Im023_1.jpg
# Rotated image written to: Model/Augmented/1/35-5-Im023_1.jpg
# Rotated image written to: Model/Augmented/1/-153-6-Im023_1.jpg
# Rotated image written to: Model/Augmented/1/-114-7-Im023_1.jpg
# Rotated image written to: Model/Augmented/1/123-8-Im023_1.jpg
# Rotated image written to: Model/Augmented/1/56-9-Im023_1.jpg
# Total augmented files created so far 464
#
# Resized image written to: Model/Augmented/1/Im005_1.jpg
# Grayscaled image written to: Model/Augmented/1/Gray-Im005_1.jpg
# Histogram equalized image written to: Model/Augmented/1/Hist-Im005_1.jpg
# Horizontally reflected image written to: Model/Augmented/1/Hor-Im005_1.jpg
# Vertical reflected image written to: Model/Augmented/1/Ver-Im005_1.jpg
# Gaussian image written to: Model/Augmented/1/Gaus-Im005_1.jpg
# Rotated image written to: Model/Augmented/1/-171-0-Im005_1.jpg
# Rotated image written to: Model/Augmented/1/-37-1-Im005_1.jpg
# Rotated image written to: Model/Augmented/1/53-2-Im005_1.jpg
# Rotated image written to: Model/Augmented/1/78-3-Im005_1.jpg
# Rotated image written to: Model/Augmented/1/-65-4-Im005_1.jpg
# Rotated image written to: Model/Augmented/1/-108-5-Im005_1.jpg
# Rotated image written to: Model/Augmented/1/18-6-Im005_1.jpg
# Rotated image written to: Model/Augmented/1/86-7-Im005_1.jpg
# Rotated image written to: Model/Augmented/1/3-8-Im005_1.jpg
# Rotated image written to: Model/Augmented/1/-71-9-Im005_1.jpg
# Total augmented files created so far 480
#
# Resized image written to: Model/Augmented/1/Im057_1.jpg
# Grayscaled image written to: Model/Augmented/1/Gray-Im057_1.jpg
# Histogram equalized image written to: Model/Augmented/1/Hist-Im057_1.jpg
# Horizontally reflected image written to: Model/Augmented/1/Hor-Im057_1.jpg
# Vertical reflected image written to: Model/Augmented/1/Ver-Im057_1.jpg
# Gaussian image written to: Model/Augmented/1/Gaus-Im057_1.jpg
# Rotated image written to: Model/Augmented/1/168-0-Im057_1.jpg
# Rotated image written to: Model/Augmented/1/114-1-Im057_1.jpg
# Rotated image written to: Model/Augmented/1/159-2-Im057_1.jpg
# Rotated image written to: Model/Augmented/1/113-3-Im057_1.jpg
# Rotated image written to: Model/Augmented/1/19-4-Im057_1.jpg
# Rotated image written to: Model/Augmented/1/6-5-Im057_1.jpg
# Rotated image written to: Model/Augmented/1/-135-6-Im057_1.jpg
# Rotated image written to: Model/Augmented/1/170-7-Im057_1.jpg
# Rotated image written to: Model/Augmented/1/-103-8-Im057_1.jpg
# Rotated image written to: Model/Augmented/1/31-9-Im057_1.jpg
# Total augmented files created so far 496
#
# Resized image written to: Model/Augmented/1/Im006_1.jpg
# Grayscaled image written to: Model/Augmented/1/Gray-Im006_1.jpg
# Histogram equalized image written to: Model/Augmented/1/Hist-Im006_1.jpg
# Horizontally reflected image written to: Model/Augmented/1/Hor-Im006_1.jpg
# Vertical reflected image written to: Model/Augmented/1/Ver-Im006_1.jpg
# Gaussian image written to: Model/Augmented/1/Gaus-Im006_1.jpg
# Rotated image written to: Model/Augmented/1/-143-0-Im006_1.jpg
# Rotated image written to: Model/Augmented/1/28-1-Im006_1.jpg
# Rotated image written to: Model/Augmented/1/-85-2-Im006_1.jpg
# Rotated image written to: Model/Augmented/1/-75-3-Im006_1.jpg
# Rotated image written to: Model/Augmented/1/18-4-Im006_1.jpg
# Rotated image written to: Model/Augmented/1/24-5-Im006_1.jpg
# Rotated image written to: Model/Augmented/1/152-6-Im006_1.jpg
# Rotated image written to: Model/Augmented/1/-56-7-Im006_1.jpg
# Rotated image written to: Model/Augmented/1/-125-8-Im006_1.jpg
# Rotated image written to: Model/Augmented/1/107-9-Im006_1.jpg
# Total augmented files created so far 512
#
# Resized image written to: Model/Augmented/1/Im027_1.jpg
# Grayscaled image written to: Model/Augmented/1/Gray-Im027_1.jpg
# Histogram equalized image written to: Model/Augmented/1/Hist-Im027_1.jpg
# Horizontally reflected image written to: Model/Augmented/1/Hor-Im027_1.jpg
# Vertical reflected image written to: Model/Augmented/1/Ver-Im027_1.jpg
# Gaussian image written to: Model/Augmented/1/Gaus-Im027_1.jpg
# Rotated image written to: Model/Augmented/1/-78-0-Im027_1.jpg
# Rotated image written to: Model/Augmented/1/152-1-Im027_1.jpg
# Rotated image written to: Model/Augmented/1/-153-2-Im027_1.jpg
# Rotated image written to: Model/Augmented/1/33-3-Im027_1.jpg
# Rotated image written to: Model/Augmented/1/2-4-Im027_1.jpg
# Rotated image written to: Model/Augmented/1/-178-5-Im027_1.jpg
# Rotated image written to: Model/Augmented/1/52-6-Im027_1.jpg
# Rotated image written to: Model/Augmented/1/-125-7-Im027_1.jpg
# Rotated image written to: Model/Augmented/1/-51-8-Im027_1.jpg
# Rotated image written to: Model/Augmented/1/67-9-Im027_1.jpg
# Total augmented files created so far 528
#
# Resized image written to: Model/Augmented/1/Im014_1.jpg
# Grayscaled image written to: Model/Augmented/1/Gray-Im014_1.jpg
# Histogram equalized image written to: Model/Augmented/1/Hist-Im014_1.jpg
# Horizontally reflected image written to: Model/Augmented/1/Hor-Im014_1.jpg
# Vertical reflected image written to: Model/Augmented/1/Ver-Im014_1.jpg
# Gaussian image written to: Model/Augmented/1/Gaus-Im014_1.jpg
# Rotated image written to: Model/Augmented/1/-112-0-Im014_1.jpg
# Rotated image written to: Model/Augmented/1/-6-1-Im014_1.jpg
# Rotated image written to: Model/Augmented/1/30-2-Im014_1.jpg
# Rotated image written to: Model/Augmented/1/-31-3-Im014_1.jpg
# Rotated image written to: Model/Augmented/1/-91-4-Im014_1.jpg
# Rotated image written to: Model/Augmented/1/133-5-Im014_1.jpg
# Rotated image written to: Model/Augmented/1/28-6-Im014_1.jpg
# Rotated image written to: Model/Augmented/1/55-7-Im014_1.jpg
# Rotated image written to: Model/Augmented/1/44-8-Im014_1.jpg
# Rotated image written to: Model/Augmented/1/-38-9-Im014_1.jpg
# Total augmented files created so far 544
#
# Resized image written to: Model/Augmented/1/Im013_1.jpg
# Grayscaled image written to: Model/Augmented/1/Gray-Im013_1.jpg
# Histogram equalized image written to: Model/Augmented/1/Hist-Im013_1.jpg
# Horizontally reflected image written to: Model/Augmented/1/Hor-Im013_1.jpg
# Vertical reflected image written to: Model/Augmented/1/Ver-Im013_1.jpg
# Gaussian image written to: Model/Augmented/1/Gaus-Im013_1.jpg
# Rotated image written to: Model/Augmented/1/170-0-Im013_1.jpg
# Rotated image written to: Model/Augmented/1/-152-1-Im013_1.jpg
# Rotated image written to: Model/Augmented/1/133-2-Im013_1.jpg
# Rotated image written to: Model/Augmented/1/103-3-Im013_1.jpg
# Rotated image written to: Model/Augmented/1/49-4-Im013_1.jpg
# Rotated image written to: Model/Augmented/1/35-5-Im013_1.jpg
# Rotated image written to: Model/Augmented/1/-21-6-Im013_1.jpg
# Rotated image written to: Model/Augmented/1/109-7-Im013_1.jpg
# Rotated image written to: Model/Augmented/1/123-8-Im013_1.jpg
# Rotated image written to: Model/Augmented/1/-42-9-Im013_1.jpg
# Total augmented files created so far 560
#
# Resized image written to: Model/Augmented/1/Im056_1.jpg
# Grayscaled image written to: Model/Augmented/1/Gray-Im056_1.jpg
# Histogram equalized image written to: Model/Augmented/1/Hist-Im056_1.jpg
# Horizontally reflected image written to: Model/Augmented/1/Hor-Im056_1.jpg
# Vertical reflected image written to: Model/Augmented/1/Ver-Im056_1.jpg
# Gaussian image written to: Model/Augmented/1/Gaus-Im056_1.jpg
# Rotated image written to: Model/Augmented/1/119-0-Im056_1.jpg
# Rotated image written to: Model/Augmented/1/23-1-Im056_1.jpg
# Rotated image written to: Model/Augmented/1/30-2-Im056_1.jpg
# Rotated image written to: Model/Augmented/1/-63-3-Im056_1.jpg
# Rotated image written to: Model/Augmented/1/-98-4-Im056_1.jpg
# Rotated image written to: Model/Augmented/1/-5-5-Im056_1.jpg
# Rotated image written to: Model/Augmented/1/115-6-Im056_1.jpg
# Rotated image written to: Model/Augmented/1/139-7-Im056_1.jpg
# Rotated image written to: Model/Augmented/1/32-8-Im056_1.jpg
# Rotated image written to: Model/Augmented/1/59-9-Im056_1.jpg
# Total augmented files created so far 576
#
# Resized image written to: Model/Augmented/1/Im062_1.jpg
# Grayscaled image written to: Model/Augmented/1/Gray-Im062_1.jpg
# Histogram equalized image written to: Model/Augmented/1/Hist-Im062_1.jpg
# Horizontally reflected image written to: Model/Augmented/1/Hor-Im062_1.jpg
# Vertical reflected image written to: Model/Augmented/1/Ver-Im062_1.jpg
# Gaussian image written to: Model/Augmented/1/Gaus-Im062_1.jpg
# Rotated image written to: Model/Augmented/1/62-0-Im062_1.jpg
# Rotated image written to: Model/Augmented/1/-11-1-Im062_1.jpg
# Rotated image written to: Model/Augmented/1/89-2-Im062_1.jpg
# Rotated image written to: Model/Augmented/1/-123-3-Im062_1.jpg
# Rotated image written to: Model/Augmented/1/-68-4-Im062_1.jpg
# Rotated image written to: Model/Augmented/1/22-5-Im062_1.jpg
# Rotated image written to: Model/Augmented/1/-175-6-Im062_1.jpg
# Rotated image written to: Model/Augmented/1/-90-7-Im062_1.jpg
# Rotated image written to: Model/Augmented/1/92-8-Im062_1.jpg
# Rotated image written to: Model/Augmented/1/-160-9-Im062_1.jpg
# Total augmented files created so far 592
#
# Resized image written to: Model/Augmented/1/Im010_1.jpg
# Grayscaled image written to: Model/Augmented/1/Gray-Im010_1.jpg
# Histogram equalized image written to: Model/Augmented/1/Hist-Im010_1.jpg
# Horizontally reflected image written to: Model/Augmented/1/Hor-Im010_1.jpg
# Vertical reflected image written to: Model/Augmented/1/Ver-Im010_1.jpg
# Gaussian image written to: Model/Augmented/1/Gaus-Im010_1.jpg
# Rotated image written to: Model/Augmented/1/88-0-Im010_1.jpg
# Rotated image written to: Model/Augmented/1/-11-1-Im010_1.jpg
# Rotated image written to: Model/Augmented/1/84-2-Im010_1.jpg
# Rotated image written to: Model/Augmented/1/-165-3-Im010_1.jpg
# Rotated image written to: Model/Augmented/1/-171-4-Im010_1.jpg
# Rotated image written to: Model/Augmented/1/23-5-Im010_1.jpg
# Rotated image written to: Model/Augmented/1/19-6-Im010_1.jpg
# Rotated image written to: Model/Augmented/1/-57-7-Im010_1.jpg
# Rotated image written to: Model/Augmented/1/128-8-Im010_1.jpg
# Rotated image written to: Model/Augmented/1/-98-9-Im010_1.jpg
# Total augmented files created so far 608
#
# Resized image written to: Model/Augmented/1/Im025_1.jpg
# Grayscaled image written to: Model/Augmented/1/Gray-Im025_1.jpg
# Histogram equalized image written to: Model/Augmented/1/Hist-Im025_1.jpg
# Horizontally reflected image written to: Model/Augmented/1/Hor-Im025_1.jpg
# Vertical reflected image written to: Model/Augmented/1/Ver-Im025_1.jpg
# Gaussian image written to: Model/Augmented/1/Gaus-Im025_1.jpg
# Rotated image written to: Model/Augmented/1/-156-0-Im025_1.jpg
# Rotated image written to: Model/Augmented/1/53-1-Im025_1.jpg
# Rotated image written to: Model/Augmented/1/30-2-Im025_1.jpg
# Rotated image written to: Model/Augmented/1/-26-3-Im025_1.jpg
# Rotated image written to: Model/Augmented/1/180-4-Im025_1.jpg
# Rotated image written to: Model/Augmented/1/-154-5-Im025_1.jpg
# Rotated image written to: Model/Augmented/1/161-6-Im025_1.jpg
# Rotated image written to: Model/Augmented/1/180-7-Im025_1.jpg
# Rotated image written to: Model/Augmented/1/141-8-Im025_1.jpg
# Rotated image written to: Model/Augmented/1/146-9-Im025_1.jpg
# Total augmented files created so far 624
#
#  AML/ALL Augmentation: 2019-02-22 17:59:54  - Added filters to 39 files in the 1 directory, with a total of 624 augmented files created.
#
# Resized image written to: Model/Augmented/0/Im090_0.jpg
# Grayscaled image written to: Model/Augmented/0/Gray-Im090_0.jpg
# Histogram equalized image written to: Model/Augmented/0/Hist-Im090_0.jpg
# Horizontally reflected image written to: Model/Augmented/0/Hor-Im090_0.jpg
# Vertical reflected image written to: Model/Augmented/0/Ver-Im090_0.jpg
# Gaussian image written to: Model/Augmented/0/Gaus-Im090_0.jpg
# Rotated image written to: Model/Augmented/0/-19-0-Im090_0.jpg
# Rotated image written to: Model/Augmented/0/111-1-Im090_0.jpg
# Rotated image written to: Model/Augmented/0/152-2-Im090_0.jpg
# Rotated image written to: Model/Augmented/0/141-3-Im090_0.jpg
# Rotated image written to: Model/Augmented/0/46-4-Im090_0.jpg
# Rotated image written to: Model/Augmented/0/25-5-Im090_0.jpg
# Rotated image written to: Model/Augmented/0/-19-6-Im090_0.jpg
# Rotated image written to: Model/Augmented/0/92-7-Im090_0.jpg
# Rotated image written to: Model/Augmented/0/3-8-Im090_0.jpg
# Rotated image written to: Model/Augmented/0/111-9-Im090_0.jpg
# Total augmented files created so far 16
#
# Resized image written to: Model/Augmented/0/Im082_0.jpg
# Grayscaled image written to: Model/Augmented/0/Gray-Im082_0.jpg
# Histogram equalized image written to: Model/Augmented/0/Hist-Im082_0.jpg
# Horizontally reflected image written to: Model/Augmented/0/Hor-Im082_0.jpg
# Vertical reflected image written to: Model/Augmented/0/Ver-Im082_0.jpg
# Gaussian image written to: Model/Augmented/0/Gaus-Im082_0.jpg
# Rotated image written to: Model/Augmented/0/150-0-Im082_0.jpg
# Rotated image written to: Model/Augmented/0/47-1-Im082_0.jpg
# Rotated image written to: Model/Augmented/0/-159-2-Im082_0.jpg
# Rotated image written to: Model/Augmented/0/-128-3-Im082_0.jpg
# Rotated image written to: Model/Augmented/0/46-4-Im082_0.jpg
# Rotated image written to: Model/Augmented/0/24-5-Im082_0.jpg
# Rotated image written to: Model/Augmented/0/-73-6-Im082_0.jpg
# Rotated image written to: Model/Augmented/0/-95-7-Im082_0.jpg
# Rotated image written to: Model/Augmented/0/73-8-Im082_0.jpg
# Rotated image written to: Model/Augmented/0/124-9-Im082_0.jpg
# Total augmented files created so far 32
#
# Resized image written to: Model/Augmented/0/Im086_0.jpg
# Grayscaled image written to: Model/Augmented/0/Gray-Im086_0.jpg
# Histogram equalized image written to: Model/Augmented/0/Hist-Im086_0.jpg
# Horizontally reflected image written to: Model/Augmented/0/Hor-Im086_0.jpg
# Vertical reflected image written to: Model/Augmented/0/Ver-Im086_0.jpg
# Gaussian image written to: Model/Augmented/0/Gaus-Im086_0.jpg
# Rotated image written to: Model/Augmented/0/-128-0-Im086_0.jpg
# Rotated image written to: Model/Augmented/0/73-1-Im086_0.jpg
# Rotated image written to: Model/Augmented/0/44-2-Im086_0.jpg
# Rotated image written to: Model/Augmented/0/-7-3-Im086_0.jpg
# Rotated image written to: Model/Augmented/0/101-4-Im086_0.jpg
# Rotated image written to: Model/Augmented/0/-8-5-Im086_0.jpg
# Rotated image written to: Model/Augmented/0/64-6-Im086_0.jpg
# Rotated image written to: Model/Augmented/0/143-7-Im086_0.jpg
# Rotated image written to: Model/Augmented/0/-7-8-Im086_0.jpg
# Rotated image written to: Model/Augmented/0/-46-9-Im086_0.jpg
# Total augmented files created so far 48
#
# Resized image written to: Model/Augmented/0/Im070_0.jpg
# Grayscaled image written to: Model/Augmented/0/Gray-Im070_0.jpg
# Histogram equalized image written to: Model/Augmented/0/Hist-Im070_0.jpg
# Horizontally reflected image written to: Model/Augmented/0/Hor-Im070_0.jpg
# Vertical reflected image written to: Model/Augmented/0/Ver-Im070_0.jpg
# Gaussian image written to: Model/Augmented/0/Gaus-Im070_0.jpg
# Rotated image written to: Model/Augmented/0/89-0-Im070_0.jpg
# Rotated image written to: Model/Augmented/0/-123-1-Im070_0.jpg
# Rotated image written to: Model/Augmented/0/-17-2-Im070_0.jpg
# Rotated image written to: Model/Augmented/0/-124-3-Im070_0.jpg
# Rotated image written to: Model/Augmented/0/137-4-Im070_0.jpg
# Rotated image written to: Model/Augmented/0/-124-5-Im070_0.jpg
# Rotated image written to: Model/Augmented/0/87-6-Im070_0.jpg
# Rotated image written to: Model/Augmented/0/85-7-Im070_0.jpg
# Rotated image written to: Model/Augmented/0/162-8-Im070_0.jpg
# Rotated image written to: Model/Augmented/0/-125-9-Im070_0.jpg
# Total augmented files created so far 64
#
# Resized image written to: Model/Augmented/0/Im085_0.jpg
# Grayscaled image written to: Model/Augmented/0/Gray-Im085_0.jpg
# Histogram equalized image written to: Model/Augmented/0/Hist-Im085_0.jpg
# Horizontally reflected image written to: Model/Augmented/0/Hor-Im085_0.jpg
# Vertical reflected image written to: Model/Augmented/0/Ver-Im085_0.jpg
# Gaussian image written to: Model/Augmented/0/Gaus-Im085_0.jpg
# Rotated image written to: Model/Augmented/0/-63-0-Im085_0.jpg
# Rotated image written to: Model/Augmented/0/163-1-Im085_0.jpg
# Rotated image written to: Model/Augmented/0/-45-2-Im085_0.jpg
# Rotated image written to: Model/Augmented/0/137-3-Im085_0.jpg
# Rotated image written to: Model/Augmented/0/-157-4-Im085_0.jpg
# Rotated image written to: Model/Augmented/0/-130-5-Im085_0.jpg
# Rotated image written to: Model/Augmented/0/-164-6-Im085_0.jpg
# Rotated image written to: Model/Augmented/0/-171-7-Im085_0.jpg
# Rotated image written to: Model/Augmented/0/-41-8-Im085_0.jpg
# Rotated image written to: Model/Augmented/0/-58-9-Im085_0.jpg
# Total augmented files created so far 80
#
# Resized image written to: Model/Augmented/0/Im035_0.jpg
# Grayscaled image written to: Model/Augmented/0/Gray-Im035_0.jpg
# Histogram equalized image written to: Model/Augmented/0/Hist-Im035_0.jpg
# Horizontally reflected image written to: Model/Augmented/0/Hor-Im035_0.jpg
# Vertical reflected image written to: Model/Augmented/0/Ver-Im035_0.jpg
# Gaussian image written to: Model/Augmented/0/Gaus-Im035_0.jpg
# Rotated image written to: Model/Augmented/0/-80-0-Im035_0.jpg
# Rotated image written to: Model/Augmented/0/-12-1-Im035_0.jpg
# Rotated image written to: Model/Augmented/0/2-2-Im035_0.jpg
# Rotated image written to: Model/Augmented/0/49-3-Im035_0.jpg
# Rotated image written to: Model/Augmented/0/42-4-Im035_0.jpg
# Rotated image written to: Model/Augmented/0/27-5-Im035_0.jpg
# Rotated image written to: Model/Augmented/0/-92-6-Im035_0.jpg
# Rotated image written to: Model/Augmented/0/-77-7-Im035_0.jpg
# Rotated image written to: Model/Augmented/0/-102-8-Im035_0.jpg
# Rotated image written to: Model/Augmented/0/5-9-Im035_0.jpg
# Total augmented files created so far 96
#
# Resized image written to: Model/Augmented/0/Im094_0.jpg
# ...
# Histogram equalized image written to: Model/Augmented/0/Hist-Im046_0.jpg
# Horizontally reflected image written to: Model/Augmented/0/Hor-Im046_0.jpg
# Vertical reflected image written to: Model/Augmented/0/Ver-Im046_0.jpg
# Gaussian image written to: Model/Augmented/0/Gaus-Im046_0.jpg
# Rotated image written to: Model/Augmented/0/47-0-Im046_0.jpg
# Rotated image written to: Model/Augmented/0/-26-1-Im046_0.jpg
# Rotated image written to: Model/Augmented/0/161-2-Im046_0.jpg
# Rotated image written to: Model/Augmented/0/56-3-Im046_0.jpg
# Rotated image written to: Model/Augmented/0/1-4-Im046_0.jpg
# Rotated image written to: Model/Augmented/0/12-5-Im046_0.jpg
# Rotated image written to: Model/Augmented/0/-76-6-Im046_0.jpg
# Rotated image written to: Model/Augmented/0/160-7-Im046_0.jpg
# Rotated image written to: Model/Augmented/0/-63-8-Im046_0.jpg
# Rotated image written to: Model/Augmented/0/-127-9-Im046_0.jpg
# Total augmented files created so far 400
#
# Resized image written to: Model/Augmented/0/Im041_0.jpg
# Grayscaled image written to: Model/Augmented/0/Gray-Im041_0.jpg
# Histogram equalized image written to: Model/Augmented/0/Hist-Im041_0.jpg
# Horizontally reflected image written to: Model/Augmented/0/Hor-Im041_0.jpg
# Vertical reflected image written to: Model/Augmented/0/Ver-Im041_0.jpg
# Gaussian image written to: Model/Augmented/0/Gaus-Im041_0.jpg
# Rotated image written to: Model/Augmented/0/130-0-Im041_0.jpg
# Rotated image written to: Model/Augmented/0/56-1-Im041_0.jpg
# Rotated image written to: Model/Augmented/0/-163-2-Im041_0.jpg
# Rotated image written to: Model/Augmented/0/146-3-Im041_0.jpg
# Rotated image written to: Model/Augmented/0/-52-4-Im041_0.jpg
# Rotated image written to: Model/Augmented/0/88-5-Im041_0.jpg
# Rotated image written to: Model/Augmented/0/-161-6-Im041_0.jpg
# Rotated image written to: Model/Augmented/0/57-7-Im041_0.jpg
# Rotated image written to: Model/Augmented/0/95-8-Im041_0.jpg
# Rotated image written to: Model/Augmented/0/-172-9-Im041_0.jpg
# Total augmented files created so far 416
#
# Resized image written to: Model/Augmented/0/Im044_0.jpg
# Grayscaled image written to: Model/Augmented/0/Gray-Im044_0.jpg
# Histogram equalized image written to: Model/Augmented/0/Hist-Im044_0.jpg
# Horizontally reflected image written to: Model/Augmented/0/Hor-Im044_0.jpg
# Vertical reflected image written to: Model/Augmented/0/Ver-Im044_0.jpg
# Gaussian image written to: Model/Augmented/0/Gaus-Im044_0.jpg
# Rotated image written to: Model/Augmented/0/-120-0-Im044_0.jpg
# Rotated image written to: Model/Augmented/0/-38-1-Im044_0.jpg
# Rotated image written to: Model/Augmented/0/120-2-Im044_0.jpg
# Rotated image written to: Model/Augmented/0/34-3-Im044_0.jpg
# Rotated image written to: Model/Augmented/0/43-4-Im044_0.jpg
# Rotated image written to: Model/Augmented/0/156-5-Im044_0.jpg
# Rotated image written to: Model/Augmented/0/40-6-Im044_0.jpg
# Rotated image written to: Model/Augmented/0/49-7-Im044_0.jpg
# Rotated image written to: Model/Augmented/0/90-8-Im044_0.jpg
# Rotated image written to: Model/Augmented/0/97-9-Im044_0.jpg
# Total augmented files created so far 432
#
# Resized image written to: Model/Augmented/0/Im087_0.jpg
# Grayscaled image written to: Model/Augmented/0/Gray-Im087_0.jpg
# Histogram equalized image written to: Model/Augmented/0/Hist-Im087_0.jpg
# Horizontally reflected image written to: Model/Augmented/0/Hor-Im087_0.jpg
# Vertical reflected image written to: Model/Augmented/0/Ver-Im087_0.jpg
# Gaussian image written to: Model/Augmented/0/Gaus-Im087_0.jpg
# Rotated image written to: Model/Augmented/0/-137-0-Im087_0.jpg
# Rotated image written to: Model/Augmented/0/-18-1-Im087_0.jpg
# Rotated image written to: Model/Augmented/0/14-2-Im087_0.jpg
# Rotated image written to: Model/Augmented/0/136-3-Im087_0.jpg
# Rotated image written to: Model/Augmented/0/120-4-Im087_0.jpg
# Rotated image written to: Model/Augmented/0/-178-5-Im087_0.jpg
# Rotated image written to: Model/Augmented/0/-70-6-Im087_0.jpg
# Rotated image written to: Model/Augmented/0/-63-7-Im087_0.jpg
# Rotated image written to: Model/Augmented/0/-153-8-Im087_0.jpg
# Rotated image written to: Model/Augmented/0/-166-9-Im087_0.jpg
# Total augmented files created so far 448
#
# Resized image written to: Model/Augmented/0/Im081_0.jpg
# Grayscaled image written to: Model/Augmented/0/Gray-Im081_0.jpg
# Histogram equalized image written to: Model/Augmented/0/Hist-Im081_0.jpg
# Horizontally reflected image written to: Model/Augmented/0/Hor-Im081_0.jpg
# Vertical reflected image written to: Model/Augmented/0/Ver-Im081_0.jpg
# Gaussian image written to: Model/Augmented/0/Gaus-Im081_0.jpg
# Rotated image written to: Model/Augmented/0/156-0-Im081_0.jpg
# Rotated image written to: Model/Augmented/0/33-1-Im081_0.jpg
# Rotated image written to: Model/Augmented/0/-124-2-Im081_0.jpg
# Rotated image written to: Model/Augmented/0/-103-3-Im081_0.jpg
# Rotated image written to: Model/Augmented/0/-124-4-Im081_0.jpg
# Rotated image written to: Model/Augmented/0/65-5-Im081_0.jpg
# Rotated image written to: Model/Augmented/0/114-6-Im081_0.jpg
# Rotated image written to: Model/Augmented/0/-22-7-Im081_0.jpg
# Rotated image written to: Model/Augmented/0/-6-8-Im081_0.jpg
# Rotated image written to: Model/Augmented/0/114-9-Im081_0.jpg
# Total augmented files created so far 464
#
# Resized image written to: Model/Augmented/0/Im036_0.jpg
# Grayscaled image written to: Model/Augmented/0/Gray-Im036_0.jpg
# Histogram equalized image written to: Model/Augmented/0/Hist-Im036_0.jpg
# Horizontally reflected image written to: Model/Augmented/0/Hor-Im036_0.jpg
# Vertical reflected image written to: Model/Augmented/0/Ver-Im036_0.jpg
# Gaussian image written to: Model/Augmented/0/Gaus-Im036_0.jpg
# Rotated image written to: Model/Augmented/0/-33-0-Im036_0.jpg
# Rotated image written to: Model/Augmented/0/83-1-Im036_0.jpg
# Rotated image written to: Model/Augmented/0/-82-2-Im036_0.jpg
# Rotated image written to: Model/Augmented/0/-96-3-Im036_0.jpg
# Rotated image written to: Model/Augmented/0/-96-4-Im036_0.jpg
# Rotated image written to: Model/Augmented/0/-105-5-Im036_0.jpg
# Rotated image written to: Model/Augmented/0/-156-6-Im036_0.jpg
# Rotated image written to: Model/Augmented/0/122-7-Im036_0.jpg
# Rotated image written to: Model/Augmented/0/-95-8-Im036_0.jpg
# Rotated image written to: Model/Augmented/0/31-9-Im036_0.jpg
# Total augmented files created so far 480
#
# Resized image written to: Model/Augmented/0/Im079_0.jpg
# Grayscaled image written to: Model/Augmented/0/Gray-Im079_0.jpg
# Histogram equalized image written to: Model/Augmented/0/Hist-Im079_0.jpg
# Horizontally reflected image written to: Model/Augmented/0/Hor-Im079_0.jpg
# Vertical reflected image written to: Model/Augmented/0/Ver-Im079_0.jpg
# Gaussian image written to: Model/Augmented/0/Gaus-Im079_0.jpg
# Rotated image written to: Model/Augmented/0/74-0-Im079_0.jpg
# Rotated image written to: Model/Augmented/0/72-1-Im079_0.jpg
# Rotated image written to: Model/Augmented/0/176-2-Im079_0.jpg
# Rotated image written to: Model/Augmented/0/177-3-Im079_0.jpg
# Rotated image written to: Model/Augmented/0/11-4-Im079_0.jpg
# Rotated image written to: Model/Augmented/0/-68-5-Im079_0.jpg
# Rotated image written to: Model/Augmented/0/-13-6-Im079_0.jpg
# Rotated image written to: Model/Augmented/0/-142-7-Im079_0.jpg
# Rotated image written to: Model/Augmented/0/-25-8-Im079_0.jpg
# Rotated image written to: Model/Augmented/0/10-9-Im079_0.jpg
# Total augmented files created so far 496
#
# Resized image written to: Model/Augmented/0/Im075_0.jpg
# Grayscaled image written to: Model/Augmented/0/Gray-Im075_0.jpg
# Histogram equalized image written to: Model/Augmented/0/Hist-Im075_0.jpg
# Horizontally reflected image written to: Model/Augmented/0/Hor-Im075_0.jpg
# Vertical reflected image written to: Model/Augmented/0/Ver-Im075_0.jpg
# Gaussian image written to: Model/Augmented/0/Gaus-Im075_0.jpg
# Rotated image written to: Model/Augmented/0/75-0-Im075_0.jpg
# Rotated image written to: Model/Augmented/0/-138-1-Im075_0.jpg
# Rotated image written to: Model/Augmented/0/103-2-Im075_0.jpg
# Rotated image written to: Model/Augmented/0/-23-3-Im075_0.jpg
# Rotated image written to: Model/Augmented/0/-78-4-Im075_0.jpg
# Rotated image written to: Model/Augmented/0/3-5-Im075_0.jpg
# Rotated image written to: Model/Augmented/0/-64-6-Im075_0.jpg
# Rotated image written to: Model/Augmented/0/67-7-Im075_0.jpg
# Rotated image written to: Model/Augmented/0/-23-8-Im075_0.jpg
# Rotated image written to: Model/Augmented/0/-52-9-Im075_0.jpg
# Total augmented files created so far 512
#
# Resized image written to: Model/Augmented/0/Im043_0.jpg
# Grayscaled image written to: Model/Augmented/0/Gray-Im043_0.jpg
# Histogram equalized image written to: Model/Augmented/0/Hist-Im043_0.jpg
# Horizontally reflected image written to: Model/Augmented/0/Hor-Im043_0.jpg
# Vertical reflected image written to: Model/Augmented/0/Ver-Im043_0.jpg
# Gaussian image written to: Model/Augmented/0/Gaus-Im043_0.jpg
# Rotated image written to: Model/Augmented/0/-41-0-Im043_0.jpg
# Rotated image written to: Model/Augmented/0/156-1-Im043_0.jpg
# Rotated image written to: Model/Augmented/0/-11-2-Im043_0.jpg
# Rotated image written to: Model/Augmented/0/-126-3-Im043_0.jpg
# Rotated image written to: Model/Augmented/0/85-4-Im043_0.jpg
# Rotated image written to: Model/Augmented/0/105-5-Im043_0.jpg
# Rotated image written to: Model/Augmented/0/-1-6-Im043_0.jpg
# Rotated image written to: Model/Augmented/0/143-7-Im043_0.jpg
# Rotated image written to: Model/Augmented/0/32-8-Im043_0.jpg
# Rotated image written to: Model/Augmented/0/165-9-Im043_0.jpg
# Total augmented files created so far 528
#
# Resized image written to: Model/Augmented/0/Im078_0.jpg
# Grayscaled image written to: Model/Augmented/0/Gray-Im078_0.jpg
# Histogram equalized image written to: Model/Augmented/0/Hist-Im078_0.jpg
# Horizontally reflected image written to: Model/Augmented/0/Hor-Im078_0.jpg
# Vertical reflected image written to: Model/Augmented/0/Ver-Im078_0.jpg
# Gaussian image written to: Model/Augmented/0/Gaus-Im078_0.jpg
# Rotated image written to: Model/Augmented/0/-110-0-Im078_0.jpg
# Rotated image written to: Model/Augmented/0/-111-1-Im078_0.jpg
# Rotated image written to: Model/Augmented/0/-47-2-Im078_0.jpg
# Rotated image written to: Model/Augmented/0/-126-3-Im078_0.jpg
# Rotated image written to: Model/Augmented/0/-45-4-Im078_0.jpg
# Rotated image written to: Model/Augmented/0/77-5-Im078_0.jpg
# Rotated image written to: Model/Augmented/0/-14-6-Im078_0.jpg
# Rotated image written to: Model/Augmented/0/68-7-Im078_0.jpg
# Rotated image written to: Model/Augmented/0/46-8-Im078_0.jpg
# Rotated image written to: Model/Augmented/0/-86-9-Im078_0.jpg
# Total augmented files created so far 544
#
# Resized image written to: Model/Augmented/0/Im069_0.jpg
# Grayscaled image written to: Model/Augmented/0/Gray-Im069_0.jpg
# Histogram equalized image written to: Model/Augmented/0/Hist-Im069_0.jpg
# Horizontally reflected image written to: Model/Augmented/0/Hor-Im069_0.jpg
# Vertical reflected image written to: Model/Augmented/0/Ver-Im069_0.jpg
# Gaussian image written to: Model/Augmented/0/Gaus-Im069_0.jpg
# Rotated image written to: Model/Augmented/0/77-0-Im069_0.jpg
# Rotated image written to: Model/Augmented/0/-46-1-Im069_0.jpg
# Rotated image written to: Model/Augmented/0/87-2-Im069_0.jpg
# Rotated image written to: Model/Augmented/0/33-3-Im069_0.jpg
# Rotated image written to: Model/Augmented/0/-167-4-Im069_0.jpg
# Rotated image written to: Model/Augmented/0/97-5-Im069_0.jpg
# Rotated image written to: Model/Augmented/0/-26-6-Im069_0.jpg
# Rotated image written to: Model/Augmented/0/-75-7-Im069_0.jpg
# Rotated image written to: Model/Augmented/0/144-8-Im069_0.jpg
# Rotated image written to: Model/Augmented/0/129-9-Im069_0.jpg
# Total augmented files created so far 560
#
# Resized image written to: Model/Augmented/0/Im077_0.jpg
# Grayscaled image written to: Model/Augmented/0/Gray-Im077_0.jpg
# Histogram equalized image written to: Model/Augmented/0/Hist-Im077_0.jpg
# Horizontally reflected image written to: Model/Augmented/0/Hor-Im077_0.jpg
# Vertical reflected image written to: Model/Augmented/0/Ver-Im077_0.jpg
# Gaussian image written to: Model/Augmented/0/Gaus-Im077_0.jpg
# Rotated image written to: Model/Augmented/0/-154-0-Im077_0.jpg
# Rotated image written to: Model/Augmented/0/-140-1-Im077_0.jpg
# Rotated image written to: Model/Augmented/0/71-2-Im077_0.jpg
# Rotated image written to: Model/Augmented/0/20-3-Im077_0.jpg
# Rotated image written to: Model/Augmented/0/-180-4-Im077_0.jpg
# Rotated image written to: Model/Augmented/0/-2-5-Im077_0.jpg
# Rotated image written to: Model/Augmented/0/88-6-Im077_0.jpg
# Rotated image written to: Model/Augmented/0/-147-7-Im077_0.jpg
# Rotated image written to: Model/Augmented/0/-130-8-Im077_0.jpg
# Rotated image written to: Model/Augmented/0/92-9-Im077_0.jpg
# Total augmented files created so far 576
#
# Resized image written to: Model/Augmented/0/Im089_0.jpg
# Grayscaled image written to: Model/Augmented/0/Gray-Im089_0.jpg
# Histogram equalized image written to: Model/Augmented/0/Hist-Im089_0.jpg
# Horizontally reflected image written to: Model/Augmented/0/Hor-Im089_0.jpg
# Vertical reflected image written to: Model/Augmented/0/Ver-Im089_0.jpg
# Gaussian image written to: Model/Augmented/0/Gaus-Im089_0.jpg
# Rotated image written to: Model/Augmented/0/21-0-Im089_0.jpg
# Rotated image written to: Model/Augmented/0/150-1-Im089_0.jpg
# Rotated image written to: Model/Augmented/0/-5-2-Im089_0.jpg
# Rotated image written to: Model/Augmented/0/-153-3-Im089_0.jpg
# Rotated image written to: Model/Augmented/0/-179-4-Im089_0.jpg
# Rotated image written to: Model/Augmented/0/-48-5-Im089_0.jpg
# Rotated image written to: Model/Augmented/0/-92-6-Im089_0.jpg
# Rotated image written to: Model/Augmented/0/-109-7-Im089_0.jpg
# Rotated image written to: Model/Augmented/0/94-8-Im089_0.jpg
# Rotated image written to: Model/Augmented/0/-108-9-Im089_0.jpg
# Total augmented files created so far 592
#
# Resized image written to: Model/Augmented/0/Im045_0.jpg
# Grayscaled image written to: Model/Augmented/0/Gray-Im045_0.jpg
# Histogram equalized image written to: Model/Augmented/0/Hist-Im045_0.jpg
# Horizontally reflected image written to: Model/Augmented/0/Hor-Im045_0.jpg
# Vertical reflected image written to: Model/Augmented/0/Ver-Im045_0.jpg
# Gaussian image written to: Model/Augmented/0/Gaus-Im045_0.jpg
# Rotated image written to: Model/Augmented/0/-111-0-Im045_0.jpg
# Rotated image written to: Model/Augmented/0/178-1-Im045_0.jpg
# Rotated image written to: Model/Augmented/0/-35-2-Im045_0.jpg
# Rotated image written to: Model/Augmented/0/-163-3-Im045_0.jpg
# Rotated image written to: Model/Augmented/0/70-4-Im045_0.jpg
# Rotated image written to: Model/Augmented/0/167-5-Im045_0.jpg
# Rotated image written to: Model/Augmented/0/49-6-Im045_0.jpg
# Rotated image written to: Model/Augmented/0/83-7-Im045_0.jpg
# Rotated image written to: Model/Augmented/0/21-8-Im045_0.jpg
# Rotated image written to: Model/Augmented/0/-97-9-Im045_0.jpg
# Total augmented files created so far 608
#
# Resized image written to: Model/Augmented/0/Im096_0.jpg
# Grayscaled image written to: Model/Augmented/0/Gray-Im096_0.jpg
# Histogram equalized image written to: Model/Augmented/0/Hist-Im096_0.jpg
# Horizontally reflected image written to: Model/Augmented/0/Hor-Im096_0.jpg
# Vertical reflected image written to: Model/Augmented/0/Ver-Im096_0.jpg
# Gaussian image written to: Model/Augmented/0/Gaus-Im096_0.jpg
# Rotated image written to: Model/Augmented/0/-15-0-Im096_0.jpg
# Rotated image written to: Model/Augmented/0/133-1-Im096_0.jpg
# Rotated image written to: Model/Augmented/0/-121-2-Im096_0.jpg
# Rotated image written to: Model/Augmented/0/-136-3-Im096_0.jpg
# Rotated image written to: Model/Augmented/0/-54-4-Im096_0.jpg
# Rotated image written to: Model/Augmented/0/-149-5-Im096_0.jpg
# Rotated image written to: Model/Augmented/0/78-6-Im096_0.jpg
# Rotated image written to: Model/Augmented/0/174-7-Im096_0.jpg
# Rotated image written to: Model/Augmented/0/63-8-Im096_0.jpg
# Rotated image written to: Model/Augmented/0/176-9-Im096_0.jpg
# Total augmented files created so far 624
#
#  AML/ALL Augmentation: 2019-02-22 18:09:12  - Added filters to 39 files in the 0 directory, with a total of 624 augmented files created.

# %% [markdown]
# # Your augmented dataset
# If you head to your __Model/Data/__ directory you will notice the augmented directory. Inside the augmented directory you will find 0 (negative) and 1 (postive) directories including resized copies of the original along with Grayscaled, Histogram Equalized, Reflected, Gaussian Blurred and rotated copies.
#
# Using data augmentation I was able to increase the dataset from 49 images per class to 580 per class. This dataset will be used in the [AML/ALL Movidius NCS Classifier](https://github.com/AMLResearchProject/AML-Detection-System/tree/master/Classifiers/Movidius/NCS).
#
#
# # About the author
# Adam is a [Bigfinite](https://www.bigfinite.com "Bigfinite") IoT Network Engineer, part of the team that works on the core IoT software. In his spare time he is an [Intel Software Innovator](https://software.intel.com/en-us/intel-software-innovators/overview "Intel Software Innovator") in the fields of Internet of Things, Artificial Intelligence and Virtual Reality.
#
# [![Adam Milton-Barker: BigFinte IoT Network Engineer & Intel® Software Innovator](../Media/Images/Adam-Milton-Barker.jpg)](https://github.com/AdamMiltonBarker)
