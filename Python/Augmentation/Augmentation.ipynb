# %% [markdown]
# # AML/ALL Classifier Data Augmentation
#
# ![Acute Myeloid Leukemia Research Python Classifier](Media/Images/banner.png)
#
# The AML/ALL Classifier Data Augmentation program applies filters to datasets and increases the amount of training / test data available to use. The program is part of the computer vision research and development for the [Peter Moss Acute Myeloid/Lymphoblastic (AML/ALL) Leukemia AI Research Project](https://www.facebook.com/AMLResearchProject/).
#
# Before you start the tutorial on below you should complete the steps in the [Augmentation README](https://github.com/AMLResearchProject/AML-ALL-Classifiers/tree/master/Augmentation/)
#
# &nbsp;

# %% [markdown]
# # Research papers followed
# The papers that this part of the project is based on were provided by project team member, Ho Leung, Associate Professor of Biochemistry & Molecular Biophysics at Kansas State University.
#
# ## Leukemia Blood Cell Image Classification Using Convolutional Neural Network
# T. T. P. Thanh, Caleb Vununu, Sukhrob Atoev, Suk-Hwan Lee, and Ki-Ryong Kwon
# http://www.ijcte.org/vol10/1198-H0012.pdf
#
# &nbsp;

# %% [markdown]
# # Dataset
# The [Acute Lymphoblastic Leukemia Image Database for Image Processing](https://homes.di.unimi.it/scotti/all/) dataset is used for this project. The dataset was created by [Fabio Scotti, Associate Professor Dipartimento di Informatica, Università degli Studi di Milano](https://homes.di.unimi.it/scotti/). Big thanks to Fabio for his research and time put in to creating the dataset and documentation, it is one of his personal projects. You will need to follow the steps outlined [here](https://homes.di.unimi.it/scotti/all/#download) to gain access to the dataset.
#
# &nbsp;
#
# # Data augmentation
#
# ![Acute Myeloid Leukemia Research Python Classifier](Media/Images/slides.png)
#
# I decided to use some augmentation proposals outlined in Leukemia Blood Cell Image Classification Using Convolutional Neural Network by T. T. P. Thanh, Caleb Vununu, Sukhrob Atoev, Suk-Hwan Lee, and Ki-Ryong Kwon. The augmentations I chose were grayscaling, histogram equalization, horizontal and vertical reflection, translation and gaussian blur to start with.
#
# In this dataset there were 49 negative and 59 positive. To make this even I removed 10 images from the positive dataset. From here I removed a further 10 images per class for testing further on in the tutorial and for the purpose of demos etc. In my case I ended up with 20 test images (10 pos/10 neg) and 39 images per class ready for augmentation. Place the original images that you wish to augment into the __Model/Data/0__ & __Model/Data/1__. Using this program I was able to create a dataset of __1053__ positive and __1053__ negative augmented images.
#
# The full Python class that holds the functions mentioned below can be found in [Classes/Data.py](Classes/Data.py), The Data class is a wrapper class around releated functions provided in popular computer vision libraries including as OpenCV and Scipy.
#
# &nbsp;
#
# ## Resizing
#
# The first step is to resize the image this is done with the following function:
#
#     def resize(self, filePath, savePath, show = False):
#
#         """
#         Writes an image based on the filepath and the image provided.
#         """
#
#         image = cv2.resize(cv2.imread(filePath), self.fixed)
#         self.writeImage(savePath, image)
#         self.filesMade += 1
#         print("Resized image written to: " + savePath)
#
#         if show is True:
#             plt.imshow(image)
#             plt.show()
#
#         return image
#
# &nbsp;
#
# ## Grayscaling
#
# In general grayscaled images are not as complex as color images and result in a less complex model. In the paper the authors described using grayscaling to create more data easily. To create a greyscale copy of each image I wrapped the built in OpenCV function, [cv2.cvtColor()](https://opencv-python-tutroals.readthedocs.io/en/latest/py_tutorials/py_imgproc/py_colorspaces/py_colorspaces.html). The created images will be saved to the relevant directories in the default configuration.
#
#     def grayScale(self, image, grayPath, show = False):
#
#         """
#         Writes a grayscale copy of the image to the filepath provided.
#         """
#
#         gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
#         self.writeImage(grayPath, gray)
#         self.filesMade += 1
#         print("Grayscaled image written to: " + grayPath)
#
#         if show is True:
#             plt.imshow(gray)
#             plt.show()
#
#         return image, gray
#
# &nbsp;
#
# ## Histogram Equalization
#
# Histogram equalization is basically stretching the histogram horizontally on both sides, increasing the intensity/contrast. Histogram equalization is described in the paper to enhance the contrast.
#
# In the case of this dataset, it makes both the white and red blood cells more distinguishable. The created images will be saved to the relevant directories in the default configuration.
#
#     def equalizeHist(self, gray, histPath, show = False):
#
#         """
#         Writes histogram equalized copy of the image to the filepath provided.
#         """
#
#         hist = cv2.equalizeHist(gray)
#         self.writeImage(histPath, cv2.equalizeHist(gray))
#         self.filesMade += 1
#         print("Histogram equalized image written to: " + histPath)
#
#         if show is True:
#             plt.imshow(hist)
#             plt.show()
#
#         return hist
#
# &nbsp;
#
# ## Reflection
#
# Reflection is a way of increasing your dataset by creating a copy that is fliped on its X axis, and a copy that is flipped on its Y axis. The reflection function below uses the built in OpenCV function, cv2.flip, to flip the image on the mentioned axis.  The created images will be saved to the relevant directories in the default configuration.
#
#     def reflection(self, image, horPath, verPath, show = False):
#
#         """
#         Writes reflected copies of the image to the filepath provided.
#         """
#
#         horImg = cv2.flip(image, 0)
#         self.writeImage(horPath, horImg)
#         self.filesMade += 1
#         print("Horizontally reflected image written to: " + horPath)
#
#         if show is True:
#             plt.imshow(horImg)
#             plt.show()
#
#         verImg = cv2.flip(image, 1)
#         self.writeImage(verPath, verImg)
#         self.filesMade += 1
#         print("Vertical reflected image written to: " + verPath)
#
#         if show is True:
#             plt.imshow(verImg)
#             plt.show()
#
#         return horImg, verImg
#
# &nbsp;
#
# ## Gaussian Blur
#
# Gaussian Blur is a popular technique used on images and is especially popular in the computer vision world. The function below uses the ndimage.gaussian_filter function. The created images will be saved to the relevant directories in the default configuration.
#
#     def gaussian(self, filePath, gaussianPath, show = False):
#
#         """
#         Writes gaussian blurred copy of the image to the filepath provided.
#         """
#
#         gaussianBlur = ndimage.gaussian_filter(plt.imread(filePath), sigma=5.11)
#         self.writeImage(gaussianPath, gaussianBlur)
#         self.filesMade += 1
#         print("Gaussian image written to: " + gaussianPath)
#
#         if show is True:
#             plt.imshow(gaussianBlur)
#             plt.show()
#
#         return gaussianBlur
#
# &nbsp;
#
# ## Translation
#
# Translation is a type of Affine Transformation and basically repositions the image within itself. The function below uses the cv2.warpAffine function. The created images will be saved to the relevant directories in the default configuration.
#
#     def translate(self, image, translatedPath, show = False):
#
#         """
#         Writes transformed copy of the image to the filepath provided.
#         """
#
#         cols, rows, chs = image.shape
#
#         translated = cv2.warpAffine(image, np.float32([[1, 0, 84], [0, 1, 56]]), (rows, cols),
#                                     borderMode=cv2.BORDER_CONSTANT, borderValue=(144, 159, 162))
#
#         self.writeImage(filePath, translated)
#         self.filesMade += 1
#         print("Translated image written to: " + filePath)
#
#         if show is True:
#             plt.imshow(translated)
#             plt.show()
#
#         return translated
#
# &nbsp;
#
# ## Rotation
#
# Gaussian Blur is a popular technique used on images and is especially popular in the computer vision world. The function below uses the ndimage.gaussian_filter function. The created images will be saved to the relevant directories in the default configuration.
#
#     def rotation(self, path, filePath, filename, show = False):
#
#         """
#         Writes rotated copies of the image to the filepath provided.
#         """
#
#         img = Image.open(filePath)
#
#         image = cv2.imread(filePath)
#         cols, rows, chs = image.shape
#
#         for i in range(0, 20):
#             randDeg = random.randint(-180, 180)
#             matrix = cv2.getRotationMatrix2D((cols/2, rows/2), randDeg, 0.70)
#             rotated = cv2.warpAffine(image, matrix, (rows, cols), borderMode=cv2.BORDER_CONSTANT,
#                                          borderValue=(144, 159, 162))
#             fullPath = os.path.join(path, str(randDeg) + '-' + str(i) + '-' + filename)
#
#             self.writeImage(fullPath, rotated)
#             self.filesMade += 1
#             print("Rotated image written to: " + fullPath)
#
#             if show is True:
#                 plt.imshow(rotated)
#                 plt.show()
#
# &nbsp;
#
# # Augment your data
# You can use the code below to augment your data. The full Python class that holds the core data functions can be found in [Classes/Data.py](Classes/Data.py). The AMLDnnData class below is a wrapper class around the Data class that allows you to run the code in this Notebook. Follow the steps below and execute the code blocks using __SHIFT + ENTER__.
#
#
# ## Sort your dataset
# The ALL IDB_1 dataset is the one used in this tutorial. In this dataset there were 49 negative and 59 positive. To make this even I removed 10 images from the positive dataset. From here I removed a further 10 images per class for testing further on in the tutorial and for the purpose of demos etc. In my case I ended up with 20 test images (10 pos/10 neg) and 39 images per class ready for augmentation. Place the original images that you wish to augment into the __Model/Data/0__ & __Model/Data/1__. Using this program I was able to create a dataset of __1053__ positive and __1053__ negative augmented images.
#
# &nbsp;
#
#
# ## Import required libraries
# We are going to run the above code in the browser, to do this you need to run the following code. Execute the code block by placing your cursor inside and clicking __shift__ & __enter__.

# %%
import matplotlib.pyplot as plt

# %matplotlib inline
plt.rcParams['figure.figsize'] = (5.0, 4.0) 
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

from Classes.Data import Data

# %% [markdown]
# &nbsp;
#
# ## Initiate the data wrapper
# The following Python class is a wrapper for the [Data (Classes/Data.py)](Classes/Data.py) class.

# %%
class AMLDnnData():
    
    def __init__(self):
        
        ###############################################################
        #
        # Sets up all default requirements and placeholders 
        # needed for the Acute Myeloid Leukemia Classifier. 
        #
        ###############################################################

        self.Data = Data()
        
    def processDataset(self):
        
        ###############################################################
        #
        # Make sure you have your equal amounts of positive and negative
        # samples in the Model/Data directories.
        # 
        # Only run this function once! it will continually make copies 
        # of all images in the Settings->TrainDir directory specified 
        # in Required/confs.json        
        #
        ###############################################################
        
        self.Data.processDataset() 
        
AMLDnnData = AMLDnnData()

# %% [markdown]
# &nbsp;
#
# ## Augment the dataset
#
# Make sure you have your equal amounts of positive and negative samples in the Model/Data directories, in my program I use the directories 0 and 1, but you can name them what you like as long as they are integers.
#
# __Only run this function once! it will continually make copies of all images in the Settings->TrainDir directory specified in Required/confs.json__
#
# &nbsp;
#
# Execute the following code block to process the dataset by running all of the functions shown above. You may see slides that are a strange color or not square, you can ignore this as the actual saved image is correct.

# %%
# Uncomment the code, only run once!
AMLDnnData.processDataset()
# Out:
# Resized image written to: Model/Augmented/1/Im029_1.jpg
# Grayscaled image written to: Model/Augmented/1/Gray-Im029_1.jpg
# Histogram equalized image written to: Model/Augmented/1/Hist-Im029_1.jpg
# Horizontally reflected image written to: Model/Augmented/1/Hor-Im029_1.jpg
# Vertical reflected image written to: Model/Augmented/1/Ver-Im029_1.jpg
# Gaussian image written to: Model/Augmented/1/Gaus-Im029_1.jpg
# Rotated image written to: Model/Augmented/1/-9-0-Im029_1.jpg
# Rotated image written to: Model/Augmented/1/28-1-Im029_1.jpg
# Rotated image written to: Model/Augmented/1/-6-2-Im029_1.jpg
# Rotated image written to: Model/Augmented/1/-123-3-Im029_1.jpg
# Rotated image written to: Model/Augmented/1/165-4-Im029_1.jpg
# Rotated image written to: Model/Augmented/1/49-5-Im029_1.jpg
# Rotated image written to: Model/Augmented/1/119-6-Im029_1.jpg
# Rotated image written to: Model/Augmented/1/109-7-Im029_1.jpg
# Rotated image written to: Model/Augmented/1/36-8-Im029_1.jpg
# Rotated image written to: Model/Augmented/1/-43-9-Im029_1.jpg
# Rotated image written to: Model/Augmented/1/6-10-Im029_1.jpg
# Rotated image written to: Model/Augmented/1/-127-11-Im029_1.jpg
# Rotated image written to: Model/Augmented/1/3-12-Im029_1.jpg
# Rotated image written to: Model/Augmented/1/-10-13-Im029_1.jpg
# Rotated image written to: Model/Augmented/1/178-14-Im029_1.jpg
# Rotated image written to: Model/Augmented/1/24-15-Im029_1.jpg
# Rotated image written to: Model/Augmented/1/-56-16-Im029_1.jpg
# Rotated image written to: Model/Augmented/1/-13-17-Im029_1.jpg
# Rotated image written to: Model/Augmented/1/-57-18-Im029_1.jpg
# Rotated image written to: Model/Augmented/1/160-19-Im029_1.jpg
# Total augmented files created so far 26
#
# Resized image written to: Model/Augmented/1/Im030_1.jpg
# Grayscaled image written to: Model/Augmented/1/Gray-Im030_1.jpg
# Histogram equalized image written to: Model/Augmented/1/Hist-Im030_1.jpg
# Horizontally reflected image written to: Model/Augmented/1/Hor-Im030_1.jpg
# Vertical reflected image written to: Model/Augmented/1/Ver-Im030_1.jpg
# Gaussian image written to: Model/Augmented/1/Gaus-Im030_1.jpg
# Rotated image written to: Model/Augmented/1/-142-0-Im030_1.jpg
# Rotated image written to: Model/Augmented/1/113-1-Im030_1.jpg
# Rotated image written to: Model/Augmented/1/-112-2-Im030_1.jpg
# Rotated image written to: Model/Augmented/1/-126-3-Im030_1.jpg
# Rotated image written to: Model/Augmented/1/57-4-Im030_1.jpg
# Rotated image written to: Model/Augmented/1/-156-5-Im030_1.jpg
# Rotated image written to: Model/Augmented/1/-83-6-Im030_1.jpg
# Rotated image written to: Model/Augmented/1/105-7-Im030_1.jpg
# Rotated image written to: Model/Augmented/1/153-8-Im030_1.jpg
# Rotated image written to: Model/Augmented/1/141-9-Im030_1.jpg
# Rotated image written to: Model/Augmented/1/-9-10-Im030_1.jpg
# Rotated image written to: Model/Augmented/1/-143-11-Im030_1.jpg
# Rotated image written to: Model/Augmented/1/-131-12-Im030_1.jpg
# Rotated image written to: Model/Augmented/1/-98-13-Im030_1.jpg
# Rotated image written to: Model/Augmented/1/147-14-Im030_1.jpg
# Rotated image written to: Model/Augmented/1/-156-15-Im030_1.jpg
# Rotated image written to: Model/Augmented/1/79-16-Im030_1.jpg
# Rotated image written to: Model/Augmented/1/-54-17-Im030_1.jpg
# Rotated image written to: Model/Augmented/1/37-18-Im030_1.jpg
# Rotated image written to: Model/Augmented/1/-119-19-Im030_1.jpg
# Total augmented files created so far 52
#
# Resized image written to: Model/Augmented/1/Im055_1.jpg
# Grayscaled image written to: Model/Augmented/1/Gray-Im055_1.jpg
# Histogram equalized image written to: Model/Augmented/1/Hist-Im055_1.jpg
# Horizontally reflected image written to: Model/Augmented/1/Hor-Im055_1.jpg
# Vertical reflected image written to: Model/Augmented/1/Ver-Im055_1.jpg
# Gaussian image written to: Model/Augmented/1/Gaus-Im055_1.jpg
# Rotated image written to: Model/Augmented/1/-31-0-Im055_1.jpg
# Rotated image written to: Model/Augmented/1/-152-1-Im055_1.jpg
# Rotated image written to: Model/Augmented/1/-13-2-Im055_1.jpg
# Rotated image written to: Model/Augmented/1/58-3-Im055_1.jpg
# Rotated image written to: Model/Augmented/1/165-4-Im055_1.jpg
# Rotated image written to: Model/Augmented/1/-65-5-Im055_1.jpg
# Rotated image written to: Model/Augmented/1/-69-6-Im055_1.jpg
# Rotated image written to: Model/Augmented/1/21-7-Im055_1.jpg
# Rotated image written to: Model/Augmented/1/123-8-Im055_1.jpg
# Rotated image written to: Model/Augmented/1/-30-9-Im055_1.jpg
# Rotated image written to: Model/Augmented/1/-123-10-Im055_1.jpg
# Rotated image written to: Model/Augmented/1/-73-11-Im055_1.jpg
# Rotated image written to: Model/Augmented/1/-127-12-Im055_1.jpg
# Rotated image written to: Model/Augmented/1/-59-13-Im055_1.jpg
# Rotated image written to: Model/Augmented/1/23-14-Im055_1.jpg
# Rotated image written to: Model/Augmented/1/44-15-Im055_1.jpg
# Rotated image written to: Model/Augmented/1/-148-16-Im055_1.jpg
# Rotated image written to: Model/Augmented/1/-60-17-Im055_1.jpg
# Rotated image written to: Model/Augmented/1/-72-18-Im055_1.jpg
# Rotated image written to: Model/Augmented/1/-125-19-Im055_1.jpg
# Total augmented files created so far 78
#
# Resized image written to: Model/Augmented/1/Im026_1.jpg
# Grayscaled image written to: Model/Augmented/1/Gray-Im026_1.jpg
# Histogram equalized image written to: Model/Augmented/1/Hist-Im026_1.jpg
# Horizontally reflected image written to: Model/Augmented/1/Hor-Im026_1.jpg
# Vertical reflected image written to: Model/Augmented/1/Ver-Im026_1.jpg
# Gaussian image written to: Model/Augmented/1/Gaus-Im026_1.jpg
# Rotated image written to: Model/Augmented/1/175-0-Im026_1.jpg
# Rotated image written to: Model/Augmented/1/85-1-Im026_1.jpg
# Rotated image written to: Model/Augmented/1/129-2-Im026_1.jpg
# Rotated image written to: Model/Augmented/1/99-3-Im026_1.jpg
# Rotated image written to: Model/Augmented/1/151-4-Im026_1.jpg
# Rotated image written to: Model/Augmented/1/165-5-Im026_1.jpg
# Rotated image written to: Model/Augmented/1/74-6-Im026_1.jpg
# Rotated image written to: Model/Augmented/1/132-7-Im026_1.jpg
# Rotated image written to: Model/Augmented/1/-31-8-Im026_1.jpg
# Rotated image written to: Model/Augmented/1/134-9-Im026_1.jpg
# Rotated image written to: Model/Augmented/1/-146-10-Im026_1.jpg
# Rotated image written to: Model/Augmented/1/22-11-Im026_1.jpg
# Rotated image written to: Model/Augmented/1/-10-12-Im026_1.jpg
# Rotated image written to: Model/Augmented/1/61-13-Im026_1.jpg
# Rotated image written to: Model/Augmented/1/-107-14-Im026_1.jpg
# Rotated image written to: Model/Augmented/1/83-15-Im026_1.jpg
# Rotated image written to: Model/Augmented/1/179-16-Im026_1.jpg
# Rotated image written to: Model/Augmented/1/-126-17-Im026_1.jpg
# Rotated image written to: Model/Augmented/1/-8-18-Im026_1.jpg
# Rotated image written to: Model/Augmented/1/7-19-Im026_1.jpg
# Total augmented files created so far 104
#
# Resized image written to: Model/Augmented/1/Im019_1.jpg
# Grayscaled image written to: Model/Augmented/1/Gray-Im019_1.jpg
# Histogram equalized image written to: Model/Augmented/1/Hist-Im019_1.jpg
# Horizontally reflected image written to: Model/Augmented/1/Hor-Im019_1.jpg
# Vertical reflected image written to: Model/Augmented/1/Ver-Im019_1.jpg
# Gaussian image written to: Model/Augmented/1/Gaus-Im019_1.jpg
# Rotated image written to: Model/Augmented/1/-119-0-Im019_1.jpg
# Rotated image written to: Model/Augmented/1/-15-1-Im019_1.jpg
# Rotated image written to: Model/Augmented/1/110-2-Im019_1.jpg
# Rotated image written to: Model/Augmented/1/81-3-Im019_1.jpg
# Rotated image written to: Model/Augmented/1/20-4-Im019_1.jpg
# Rotated image written to: Model/Augmented/1/178-5-Im019_1.jpg
# Rotated image written to: Model/Augmented/1/20-6-Im019_1.jpg
# Rotated image written to: Model/Augmented/1/-73-7-Im019_1.jpg
# Rotated image written to: Model/Augmented/1/108-8-Im019_1.jpg
# Rotated image written to: Model/Augmented/1/131-9-Im019_1.jpg
# Rotated image written to: Model/Augmented/1/64-10-Im019_1.jpg
# Rotated image written to: Model/Augmented/1/35-11-Im019_1.jpg
# Rotated image written to: Model/Augmented/1/124-12-Im019_1.jpg
# Rotated image written to: Model/Augmented/1/-80-13-Im019_1.jpg
# Rotated image written to: Model/Augmented/1/-168-14-Im019_1.jpg
# Rotated image written to: Model/Augmented/1/-45-15-Im019_1.jpg
# Rotated image written to: Model/Augmented/1/-99-16-Im019_1.jpg
# Rotated image written to: Model/Augmented/1/99-17-Im019_1.jpg
# Rotated image written to: Model/Augmented/1/178-18-Im019_1.jpg
# Rotated image written to: Model/Augmented/1/105-19-Im019_1.jpg
# Total augmented files created so far 130
#
# Resized image written to: Model/Augmented/1/Im052_1.jpg
# Grayscaled image written to: Model/Augmented/1/Gray-Im052_1.jpg
# Histogram equalized image written to: Model/Augmented/1/Hist-Im052_1.jpg
# Horizontally reflected image written to: Model/Augmented/1/Hor-Im052_1.jpg
# Vertical reflected image written to: Model/Augmented/1/Ver-Im052_1.jpg
# Gaussian image written to: Model/Augmented/1/Gaus-Im052_1.jpg
# Rotated image written to: Model/Augmented/1/-116-0-Im052_1.jpg
# Rotated image written to: Model/Augmented/1/40-1-Im052_1.jpg
# Rotated image written to: Model/Augmented/1/-166-2-Im052_1.jpg
# Rotated image written to: Model/Augmented/1/-102-3-Im052_1.jpg
# Rotated image written to: Model/Augmented/1/122-4-Im052_1.jpg
# Rotated image written to: Model/Augmented/1/-180-5-Im052_1.jpg
# Rotated image written to: Model/Augmented/1/-13-6-Im052_1.jpg
# Rotated image written to: Model/Augmented/1/119-7-Im052_1.jpg
# Rotated image written to: Model/Augmented/1/-72-8-Im052_1.jpg
# Rotated image written to: Model/Augmented/1/-101-9-Im052_1.jpg
# Rotated image written to: Model/Augmented/1/78-10-Im052_1.jpg
# Rotated image written to: Model/Augmented/1/-96-11-Im052_1.jpg
# Rotated image written to: Model/Augmented/1/-141-12-Im052_1.jpg
# Rotated image written to: Model/Augmented/1/-60-13-Im052_1.jpg
# Rotated image written to: Model/Augmented/1/101-14-Im052_1.jpg
# Rotated image written to: Model/Augmented/1/142-15-Im052_1.jpg
# Rotated image written to: Model/Augmented/1/-14-16-Im052_1.jpg
# Rotated image written to: Model/Augmented/1/-94-17-Im052_1.jpg
# Rotated image written to: Model/Augmented/1/2-18-Im052_1.jpg
# Rotated image written to: Model/Augmented/1/-110-19-Im052_1.jpg
# Total augmented files created so far 156
#
# Resized image written to: Model/Augmented/1/Im015_1.jpg
# Grayscaled image written to: Model/Augmented/1/Gray-Im015_1.jpg
# Histogram equalized image written to: Model/Augmented/1/Hist-Im015_1.jpg
# Horizontally reflected image written to: Model/Augmented/1/Hor-Im015_1.jpg
# Vertical reflected image written to: Model/Augmented/1/Ver-Im015_1.jpg
# Gaussian image written to: Model/Augmented/1/Gaus-Im015_1.jpg
# Rotated image written to: Model/Augmented/1/9-0-Im015_1.jpg
# Rotated image written to: Model/Augmented/1/-16-1-Im015_1.jpg
# Rotated image written to: Model/Augmented/1/174-2-Im015_1.jpg
# Rotated image written to: Model/Augmented/1/-49-3-Im015_1.jpg
# Rotated image written to: Model/Augmented/1/19-4-Im015_1.jpg
# Rotated image written to: Model/Augmented/1/-141-5-Im015_1.jpg
# Rotated image written to: Model/Augmented/1/155-6-Im015_1.jpg
# Rotated image written to: Model/Augmented/1/-179-7-Im015_1.jpg
# Rotated image written to: Model/Augmented/1/-4-8-Im015_1.jpg
# Rotated image written to: Model/Augmented/1/-58-9-Im015_1.jpg
# Rotated image written to: Model/Augmented/1/151-10-Im015_1.jpg
# Rotated image written to: Model/Augmented/1/121-11-Im015_1.jpg
# Rotated image written to: Model/Augmented/1/13-12-Im015_1.jpg
# Rotated image written to: Model/Augmented/1/115-13-Im015_1.jpg
# Rotated image written to: Model/Augmented/1/62-14-Im015_1.jpg
# Rotated image written to: Model/Augmented/1/130-15-Im015_1.jpg
# Rotated image written to: Model/Augmented/1/-61-16-Im015_1.jpg
# Rotated image written to: Model/Augmented/1/58-17-Im015_1.jpg
# Rotated image written to: Model/Augmented/1/68-18-Im015_1.jpg
# Rotated image written to: Model/Augmented/1/-170-19-Im015_1.jpg
# Total augmented files created so far 182
#
# Resized image written to: Model/Augmented/1/Im018_1.jpg
# Grayscaled image written to: Model/Augmented/1/Gray-Im018_1.jpg
# Histogram equalized image written to: Model/Augmented/1/Hist-Im018_1.jpg
# Horizontally reflected image written to: Model/Augmented/1/Hor-Im018_1.jpg
# Vertical reflected image written to: Model/Augmented/1/Ver-Im018_1.jpg
# Gaussian image written to: Model/Augmented/1/Gaus-Im018_1.jpg
# Rotated image written to: Model/Augmented/1/-33-0-Im018_1.jpg
# Rotated image written to: Model/Augmented/1/-143-1-Im018_1.jpg
# Rotated image written to: Model/Augmented/1/-17-2-Im018_1.jpg
# Rotated image written to: Model/Augmented/1/-92-3-Im018_1.jpg
# Rotated image written to: Model/Augmented/1/12-4-Im018_1.jpg
# Rotated image written to: Model/Augmented/1/110-5-Im018_1.jpg
# Rotated image written to: Model/Augmented/1/178-6-Im018_1.jpg
# Rotated image written to: Model/Augmented/1/-67-7-Im018_1.jpg
# Rotated image written to: Model/Augmented/1/-21-8-Im018_1.jpg
# Rotated image written to: Model/Augmented/1/121-9-Im018_1.jpg
# Rotated image written to: Model/Augmented/1/-127-10-Im018_1.jpg
# Rotated image written to: Model/Augmented/1/-99-11-Im018_1.jpg
# Rotated image written to: Model/Augmented/1/-45-12-Im018_1.jpg
# Rotated image written to: Model/Augmented/1/-4-13-Im018_1.jpg
# Rotated image written to: Model/Augmented/1/-120-14-Im018_1.jpg
# Rotated image written to: Model/Augmented/1/-75-15-Im018_1.jpg
# Rotated image written to: Model/Augmented/1/72-16-Im018_1.jpg
# Rotated image written to: Model/Augmented/1/-77-17-Im018_1.jpg
# Rotated image written to: Model/Augmented/1/-78-18-Im018_1.jpg
# Rotated image written to: Model/Augmented/1/25-19-Im018_1.jpg
# Total augmented files created so far 208
#
# Resized image written to: Model/Augmented/1/Im063_1.jpg
# Grayscaled image written to: Model/Augmented/1/Gray-
Im024_1.jpg
# Rotated image written to: Model/Augmented/1/106-15-Im024_1.jpg
# Rotated image written to: Model/Augmented/1/68-16-Im024_1.jpg
# Rotated image written to: Model/Augmented/1/41-17-Im024_1.jpg
# Rotated image written to: Model/Augmented/1/-96-18-Im024_1.jpg
# Rotated image written to: Model/Augmented/1/13-19-Im024_1.jpg
# Total augmented files created so far 598
#
# Resized image written to: Model/Augmented/1/Im059_1.jpg
# Grayscaled image written to: Model/Augmented/1/Gray-Im059_1.jpg
# Histogram equalized image written to: Model/Augmented/1/Hist-Im059_1.jpg
# Horizontally reflected image written to: Model/Augmented/1/Hor-Im059_1.jpg
# Vertical reflected image written to: Model/Augmented/1/Ver-Im059_1.jpg
# Gaussian image written to: Model/Augmented/1/Gaus-Im059_1.jpg
# Rotated image written to: Model/Augmented/1/106-0-Im059_1.jpg
# Rotated image written to: Model/Augmented/1/94-1-Im059_1.jpg
# Rotated image written to: Model/Augmented/1/-59-2-Im059_1.jpg
# Rotated image written to: Model/Augmented/1/84-3-Im059_1.jpg
# Rotated image written to: Model/Augmented/1/-171-4-Im059_1.jpg
# Rotated image written to: Model/Augmented/1/-96-5-Im059_1.jpg
# Rotated image written to: Model/Augmented/1/178-6-Im059_1.jpg
# Rotated image written to: Model/Augmented/1/111-7-Im059_1.jpg
# Rotated image written to: Model/Augmented/1/56-8-Im059_1.jpg
# Rotated image written to: Model/Augmented/1/-144-9-Im059_1.jpg
# Rotated image written to: Model/Augmented/1/-149-10-Im059_1.jpg
# Rotated image written to: Model/Augmented/1/17-11-Im059_1.jpg
# Rotated image written to: Model/Augmented/1/-47-12-Im059_1.jpg
# Rotated image written to: Model/Augmented/1/-176-13-Im059_1.jpg
# Rotated image written to: Model/Augmented/1/91-14-Im059_1.jpg
# Rotated image written to: Model/Augmented/1/-25-15-Im059_1.jpg
# Rotated image written to: Model/Augmented/1/35-16-Im059_1.jpg
# Rotated image written to: Model/Augmented/1/-108-17-Im059_1.jpg
# Rotated image written to: Model/Augmented/1/-30-18-Im059_1.jpg
# Rotated image written to: Model/Augmented/1/2-19-Im059_1.jpg
# Total augmented files created so far 624
#
# Resized image written to: Model/Augmented/1/Im016_1.jpg
# Grayscaled image written to: Model/Augmented/1/Gray-Im016_1.jpg
# Histogram equalized image written to: Model/Augmented/1/Hist-Im016_1.jpg
# Horizontally reflected image written to: Model/Augmented/1/Hor-Im016_1.jpg
# Vertical reflected image written to: Model/Augmented/1/Ver-Im016_1.jpg
# Gaussian image written to: Model/Augmented/1/Gaus-Im016_1.jpg
# Rotated image written to: Model/Augmented/1/136-0-Im016_1.jpg
# Rotated image written to: Model/Augmented/1/-17-1-Im016_1.jpg
# Rotated image written to: Model/Augmented/1/15-2-Im016_1.jpg
# Rotated image written to: Model/Augmented/1/144-3-Im016_1.jpg
# Rotated image written to: Model/Augmented/1/-33-4-Im016_1.jpg
# Rotated image written to: Model/Augmented/1/78-5-Im016_1.jpg
# Rotated image written to: Model/Augmented/1/97-6-Im016_1.jpg
# Rotated image written to: Model/Augmented/1/-19-7-Im016_1.jpg
# Rotated image written to: Model/Augmented/1/137-8-Im016_1.jpg
# Rotated image written to: Model/Augmented/1/-120-9-Im016_1.jpg
# Rotated image written to: Model/Augmented/1/-177-10-Im016_1.jpg
# Rotated image written to: Model/Augmented/1/130-11-Im016_1.jpg
# Rotated image written to: Model/Augmented/1/-89-12-Im016_1.jpg
# Rotated image written to: Model/Augmented/1/-39-13-Im016_1.jpg
# Rotated image written to: Model/Augmented/1/163-14-Im016_1.jpg
# Rotated image written to: Model/Augmented/1/84-15-Im016_1.jpg
# Rotated image written to: Model/Augmented/1/100-16-Im016_1.jpg
# Rotated image written to: Model/Augmented/1/155-17-Im016_1.jpg
# Rotated image written to: Model/Augmented/1/119-18-Im016_1.jpg
# Rotated image written to: Model/Augmented/1/58-19-Im016_1.jpg
# Total augmented files created so far 650
#
# Resized image written to: Model/Augmented/1/Im007_1.jpg
# Grayscaled image written to: Model/Augmented/1/Gray-Im007_1.jpg
# Histogram equalized image written to: Model/Augmented/1/Hist-Im007_1.jpg
# Horizontally reflected image written to: Model/Augmented/1/Hor-Im007_1.jpg
# Vertical reflected image written to: Model/Augmented/1/Ver-Im007_1.jpg
# Gaussian image written to: Model/Augmented/1/Gaus-Im007_1.jpg
# Rotated image written to: Model/Augmented/1/18-0-Im007_1.jpg
# Rotated image written to: Model/Augmented/1/-18-1-Im007_1.jpg
# Rotated image written to: Model/Augmented/1/-41-2-Im007_1.jpg
# Rotated image written to: Model/Augmented/1/-49-3-Im007_1.jpg
# Rotated image written to: Model/Augmented/1/76-4-Im007_1.jpg
# Rotated image written to: Model/Augmented/1/44-5-Im007_1.jpg
# Rotated image written to: Model/Augmented/1/-129-6-Im007_1.jpg
# Rotated image written to: Model/Augmented/1/-76-7-Im007_1.jpg
# Rotated image written to: Model/Augmented/1/-18-8-Im007_1.jpg
# Rotated image written to: Model/Augmented/1/50-9-Im007_1.jpg
# Rotated image written to: Model/Augmented/1/-122-10-Im007_1.jpg
# Rotated image written to: Model/Augmented/1/13-11-Im007_1.jpg
# Rotated image written to: Model/Augmented/1/142-12-Im007_1.jpg
# Rotated image written to: Model/Augmented/1/147-13-Im007_1.jpg
# Rotated image written to: Model/Augmented/1/47-14-Im007_1.jpg
# Rotated image written to: Model/Augmented/1/-106-15-Im007_1.jpg
# Rotated image written to: Model/Augmented/1/109-16-Im007_1.jpg
# Rotated image written to: Model/Augmented/1/-122-17-Im007_1.jpg
# Rotated image written to: Model/Augmented/1/-145-18-Im007_1.jpg
# Rotated image written to: Model/Augmented/1/86-19-Im007_1.jpg
# Total augmented files created so far 676
#
# Resized image written to: Model/Augmented/1/Im054_1.jpg
# Grayscaled image written to: Model/Augmented/1/Gray-Im054_1.jpg
# Histogram equalized image written to: Model/Augmented/1/Hist-Im054_1.jpg
# Horizontally reflected image written to: Model/Augmented/1/Hor-Im054_1.jpg
# Vertical reflected image written to: Model/Augmented/1/Ver-Im054_1.jpg
# Gaussian image written to: Model/Augmented/1/Gaus-Im054_1.jpg
# Rotated image written to: Model/Augmented/1/-83-0-Im054_1.jpg
# Rotated image written to: Model/Augmented/1/118-1-Im054_1.jpg
# Rotated image written to: Model/Augmented/1/-121-2-Im054_1.jpg
# Rotated image written to: Model/Augmented/1/155-3-Im054_1.jpg
# Rotated image written to: Model/Augmented/1/131-4-Im054_1.jpg
# Rotated image written to: Model/Augmented/1/-29-5-Im054_1.jpg
# Rotated image written to: Model/Augmented/1/168-6-Im054_1.jpg
# Rotated image written to: Model/Augmented/1/64-7-Im054_1.jpg
# Rotated image written to: Model/Augmented/1/-58-8-Im054_1.jpg
# Rotated image written to: Model/Augmented/1/-142-9-Im054_1.jpg
# Rotated image written to: Model/Augmented/1/-16-10-Im054_1.jpg
# Rotated image written to: Model/Augmented/1/-5-11-Im054_1.jpg
# Rotated image written to: Model/Augmented/1/36-12-Im054_1.jpg
# Rotated image written to: Model/Augmented/1/107-13-Im054_1.jpg
# Rotated image written to: Model/Augmented/1/-162-14-Im054_1.jpg
# Rotated image written to: Model/Augmented/1/8-15-Im054_1.jpg
# Rotated image written to: Model/Augmented/1/128-16-Im054_1.jpg
# Rotated image written to: Model/Augmented/1/-135-17-Im054_1.jpg
# Rotated image written to: Model/Augmented/1/170-18-Im054_1.jpg
# Rotated image written to: Model/Augmented/1/132-19-Im054_1.jpg
# Total augmented files created so far 702
#
# Resized image written to: Model/Augmented/1/Im012_1.jpg
# Grayscaled image written to: Model/Augmented/1/Gray-Im012_1.jpg
# Histogram equalized image written to: Model/Augmented/1/Hist-Im012_1.jpg
# Horizontally reflected image written to: Model/Augmented/1/Hor-Im012_1.jpg
# Vertical reflected image written to: Model/Augmented/1/Ver-Im012_1.jpg
# Gaussian image written to: Model/Augmented/1/Gaus-Im012_1.jpg
# Rotated image written to: Model/Augmented/1/-134-0-Im012_1.jpg
# Rotated image written to: Model/Augmented/1/-1-1-Im012_1.jpg
# Rotated image written to: Model/Augmented/1/17-2-Im012_1.jpg
# Rotated image written to: Model/Augmented/1/127-3-Im012_1.jpg
# Rotated image written to: Model/Augmented/1/98-4-Im012_1.jpg
# Rotated image written to: Model/Augmented/1/45-5-Im012_1.jpg
# Rotated image written to: Model/Augmented/1/20-6-Im012_1.jpg
# Rotated image written to: Model/Augmented/1/134-7-Im012_1.jpg
# Rotated image written to: Model/Augmented/1/-123-8-Im012_1.jpg
# Rotated image written to: Model/Augmented/1/82-9-Im012_1.jpg
# Rotated image written to: Model/Augmented/1/-69-10-Im012_1.jpg
# Rotated image written to: Model/Augmented/1/51-11-Im012_1.jpg
# Rotated image written to: Model/Augmented/1/-92-12-Im012_1.jpg
# Rotated image written to: Model/Augmented/1/-5-13-Im012_1.jpg
# Rotated image written to: Model/Augmented/1/15-14-Im012_1.jpg
# Rotated image written to: Model/Augmented/1/-29-15-Im012_1.jpg
# Rotated image written to: Model/Augmented/1/33-16-Im012_1.jpg
# Rotated image written to: Model/Augmented/1/-39-17-Im012_1.jpg
# Rotated image written to: Model/Augmented/1/156-18-Im012_1.jpg
# Rotated image written to: Model/Augmented/1/139-19-Im012_1.jpg
# Total augmented files created so far 728
#
# Resized image written to: Model/Augmented/1/Im023_1.jpg
# Grayscaled image written to: Model/Augmented/1/Gray-Im023_1.jpg
# Histogram equalized image written to: Model/Augmented/1/Hist-Im023_1.jpg
# Horizontally reflected image written to: Model/Augmented/1/Hor-Im023_1.jpg
# Vertical reflected image written to: Model/Augmented/1/Ver-Im023_1.jpg
# Gaussian image written to: Model/Augmented/1/Gaus-Im023_1.jpg
# Rotated image written to: Model/Augmented/1/-121-0-Im023_1.jpg
# Rotated image written to: Model/Augmented/1/153-1-Im023_1.jpg
# Rotated image written to: Model/Augmented/1/31-2-Im023_1.jpg
# Rotated image written to: Model/Augmented/1/116-3-Im023_1.jpg
# ...
# Rotated image written to: Model/Augmented/0/-72-11-Im036_0.jpg
# Rotated image written to: Model/Augmented/0/117-12-Im036_0.jpg
# Rotated image written to: Model/Augmented/0/-25-13-Im036_0.jpg
# Rotated image written to: Model/Augmented/0/66-14-Im036_0.jpg
# Rotated image written to: Model/Augmented/0/49-15-Im036_0.jpg
# Rotated image written to: Model/Augmented/0/150-16-Im036_0.jpg
# Rotated image written to: Model/Augmented/0/-51-17-Im036_0.jpg
# Rotated image written to: Model/Augmented/0/-43-18-Im036_0.jpg
# Rotated image written to: Model/Augmented/0/99-19-Im036_0.jpg
# Total augmented files created so far 780
#
# Resized image written to: Model/Augmented/0/Im079_0.jpg
# Grayscaled image written to: Model/Augmented/0/Gray-
Im045_0.jpg
# Rotated image written to: Model/Augmented/0/-92-5-Im045_0.jpg
# Rotated image written to: Model/Augmented/0/118-6-Im045_0.jpg
# Rotated image written to: Model/Augmented/0/-147-7-Im045_0.jpg
# Rotated image written to: Model/Augmented/0/-104-8-Im045_0.jpg
# Rotated image written to: Model/Augmented/0/166-9-Im045_0.jpg
# Rotated image written to: Model/Augmented/0/-146-10-Im045_0.jpg
# Rotated image written to: Model/Augmented/0/65-11-Im045_0.jpg
# Rotated image written to: Model/Augmented/0/-123-12-Im045_0.jpg
# Rotated image written to: Model/Augmented/0/-95-13-Im045_0.jpg
# Rotated image written to: Model/Augmented/0/100-14-Im045_0.jpg
# Rotated image written to: Model/Augmented/0/120-15-Im045_0.jpg
# Rotated image written to: Model/Augmented/0/-105-16-Im045_0.jpg
# Rotated image written to: Model/Augmented/0/60-17-Im045_0.jpg
# Rotated image written to: Model/Augmented/0/-117-18-Im045_0.jpg
# Rotated image written to: Model/Augmented/0/-121-19-Im045_0.jpg
# Total augmented files created so far 988
#
# Resized image written to: Model/Augmented/0/Im096_0.jpg
# Grayscaled image written to: Model/Augmented/0/Gray-Im096_0.jpg
# Histogram equalized image written to: Model/Augmented/0/Hist-Im096_0.jpg
# Horizontally reflected image written to: Model/Augmented/0/Hor-Im096_0.jpg
# Vertical reflected image written to: Model/Augmented/0/Ver-Im096_0.jpg
# Gaussian image written to: Model/Augmented/0/Gaus-Im096_0.jpg
# Rotated image written to: Model/Augmented/0/137-0-Im096_0.jpg
# Rotated image written to: Model/Augmented/0/54-1-Im096_0.jpg
# Rotated image written to: Model/Augmented/0/115-2-Im096_0.jpg
# Rotated image written to: Model/Augmented/0/62-3-Im096_0.jpg
# Rotated image written to: Model/Augmented/0/-24-4-Im096_0.jpg
# Rotated image written to: Model/Augmented/0/156-5-Im096_0.jpg
# Rotated image written to: Model/Augmented/0/40-6-Im096_0.jpg
# Rotated image written to: Model/Augmented/0/118-7-Im096_0.jpg
# Rotated image written to: Model/Augmented/0/60-8-Im096_0.jpg
# Rotated image written to: Model/Augmented/0/177-9-Im096_0.jpg
# Rotated image written to: Model/Augmented/0/-2-10-Im096_0.jpg
# Rotated image written to: Model/Augmented/0/-124-11-Im096_0.jpg
# Rotated image written to: Model/Augmented/0/124-12-Im096_0.jpg
# Rotated image written to: Model/Augmented/0/58-13-Im096_0.jpg
# Rotated image written to: Model/Augmented/0/117-14-Im096_0.jpg
# Rotated image written to: Model/Augmented/0/106-15-Im096_0.jpg
# Rotated image written to: Model/Augmented/0/-136-16-Im096_0.jpg
# Rotated image written to: Model/Augmented/0/92-17-Im096_0.jpg
# Rotated image written to: Model/Augmented/0/-46-18-Im096_0.jpg
# Rotated image written to: Model/Augmented/0/107-19-Im096_0.jpg
# Total augmented files created so far 1014
#
#  AML/ALL Augmentation: 2019-02-23 11:02:37  - Added filters to 39 files in the 0 directory, with a total of 1014 augmented files created.

# %% [markdown]
# &nbsp;
#
#
# # Your augmented dataset
# If you head to your __Model/Data/__ directory you will notice the augmented directory. Inside the augmented directory you will find 0 (negative) and 1 (postive) directories including resized copies of the original along with Grayscaled, Histogram Equalized, Reflected, Gaussian Blurred and rotated copies.
#
# Using data augmentation I was able to increase the dataset from 39 images per class to 1053 per class.
#
# &nbsp;
#
# # Contributing
# The Peter Moss Acute Myeloid/Lymphoblastic Leukemia AI Research project encourages and welcomes code contributions, bug fixes and enhancements from the community to the Github repositories. Please read the [CONTRIBUTING](https://github.com/AMLResearchProject/AML-ALL-Classifiers/blob/master/CONTRIBUTING.md "CONTRIBUTING") document for a full guide to forking our repositories and submitting your pull request. You will also find information about our code of conduct on this page.
#
# ## Acute Lymphoblastic Leukemia Convolutional Neural Network Contributors
#
# - [Adam Milton-Barker](https://github.com/AdamMiltonBarker "Adam Milton-Barker") - Bigfinite IoT Network Engineer & Intel Software Innovator, Barcelona, Spain
#
# &nbsp;
#
# # Versioning
# We use SemVer for versioning. For the versions available, see [Releases](https://github.com/AMLResearchProject/AML-ALL-Classifiers/releases "Releases").
#
# # License
# This project is licensed under the **MIT License** - see the [LICENSE](https://github.com/AMLResearchProject/AML-ALL-Classifiers/blob/master/LICENSE "LICENSE") file for details.
#
# # Bugs/Issues
# We use the [repo issues](https://github.com/AMLResearchProject/AML-ALL-Classifiers/issues "repo issues") to track bugs and general requests related to using this project.
#
# &nbsp;
#
# # Project Author
# Adam is a [BigFinite](https://www.bigfinite.com "BigFinite") IoT Network Engineer, part of the team that works on the core IoT software. In his spare time he is an [Intel Software Innovator](https://software.intel.com/en-us/intel-software-innovators/overview "Intel Software Innovator") in the fields of Internet of Things, Artificial Intelligence and Virtual Reality.
#
# [![Adam Milton-Barker: BigFinte IoT Network Engineer & Intel® Software Innovator](../../Media/Images/Adam-Milton-Barker.jpg)](https://github.com/AdamMiltonBarker)
