# %% [markdown]
# # AML/ALL Classifier Data Augmentation
#
# ![Acute Myeloid Leukemia Research Python Classifier](Media/Images/banner.png)
#
# The AML/ALL Classifier Data Augmentation program applies filters to datasets and increases the amount of training / test data available to use. The program is part of the computer vision research and development for the [Peter Moss Acute Myeloid/Lymphoblastic (AML/ALL) Leukemia AI Research Project](https://www.facebook.com/AMLResearchProject/).
#
# Before you start the tutorial on below you should complete the steps in the [Augmentation README](https://github.com/AMLResearchProject/AML-ALL-Classifiers/tree/master/Augmentation/)
#
# &nbsp;

# %% [markdown]
# # Research papers followed
# The papers that this part of the project is based on were provided by project team member, Ho Leung, Associate Professor of Biochemistry & Molecular Biophysics at Kansas State University.
#
# ## Leukemia Blood Cell Image Classification Using Convolutional Neural Network
# T. T. P. Thanh, Caleb Vununu, Sukhrob Atoev, Suk-Hwan Lee, and Ki-Ryong Kwon
# http://www.ijcte.org/vol10/1198-H0012.pdf
#
# &nbsp;

# %% [markdown]
# # Dataset
# The [Acute Lymphoblastic Leukemia Image Database for Image Processing](https://homes.di.unimi.it/scotti/all/) dataset is used for this project. The dataset was created by [Fabio Scotti, Associate Professor Dipartimento di Informatica, Università degli Studi di Milano](https://homes.di.unimi.it/scotti/). Big thanks to Fabio for his research and time put in to creating the dataset and documentation, it is one of his personal projects. You will need to follow the steps outlined [here](https://homes.di.unimi.it/scotti/all/#download) to gain access to the dataset.
#
# &nbsp;
#
# # Data augmentation
#
# ![Acute Myeloid Leukemia Research Python Classifier](Media/Images/slides.png)
#
# I decided to use some augmentation proposals outlined in Leukemia Blood Cell Image Classification Using Convolutional Neural Network by T. T. P. Thanh, Caleb Vununu, Sukhrob Atoev, Suk-Hwan Lee, and Ki-Ryong Kwon. The augmentations I chose were grayscaling, histogram equalization, horizontal and vertical reflection, translation and gaussian blur to start with.
#
# In this dataset there were 49 negative and 59 positive. To make this even I removed 10 images from the positive dataset. From here I removed a further 10 images per class for testing further on in the tutorial and for the purpose of demos etc. In my case I ended up with 20 test images (10 pos/10 neg) and 39 images per class ready for augmentation. Place the original images that you wish to augment into the __Model/Data/0__ & __Model/Data/1__. Using this program I was able to create a dataset of __1053__ positive and __1053__ negative augmented images.
#
# The full Python class that holds the functions mentioned below can be found in [Classes/Data.py](Classes/Data.py), The Data class is a wrapper class around releated functions provided in popular computer vision libraries including as OpenCV and Scipy.
#
# &nbsp;
#
# ## Resizing
#
# The first step is to resize the image this is done with the following function:
#
#     def resize(self, filePath, savePath, show = False):
#
#         """
#         Writes an image based on the filepath and the image provided.
#         """
#
#         image = cv2.resize(cv2.imread(filePath), self.fixed)
#         self.writeImage(savePath, image)
#         self.filesMade += 1
#         print("Resized image written to: " + savePath)
#
#         if show is True:
#             plt.imshow(image)
#             plt.show()
#
#         return image
#
# &nbsp;
#
# ## Grayscaling
#
# In general grayscaled images are not as complex as color images and result in a less complex model. In the paper the authors described using grayscaling to create more data easily. To create a greyscale copy of each image I wrapped the built in OpenCV function, [cv2.cvtColor()](https://opencv-python-tutroals.readthedocs.io/en/latest/py_tutorials/py_imgproc/py_colorspaces/py_colorspaces.html). The created images will be saved to the relevant directories in the default configuration.
#
#     def grayScale(self, image, grayPath, show = False):
#
#         """
#         Writes a grayscale copy of the image to the filepath provided.
#         """
#
#         gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
#         self.writeImage(grayPath, gray)
#         self.filesMade += 1
#         print("Grayscaled image written to: " + grayPath)
#
#         if show is True:
#             plt.imshow(gray)
#             plt.show()
#
#         return image, gray
#
# &nbsp;
#
# ## Histogram Equalization
#
# Histogram equalization is basically stretching the histogram horizontally on both sides, increasing the intensity/contrast. Histogram equalization is described in the paper to enhance the contrast.
#
# In the case of this dataset, it makes both the white and red blood cells more distinguishable. The created images will be saved to the relevant directories in the default configuration.
#
#     def equalizeHist(self, gray, histPath, show = False):
#
#         """
#         Writes histogram equalized copy of the image to the filepath provided.
#         """
#
#         hist = cv2.equalizeHist(gray)
#         self.writeImage(histPath, cv2.equalizeHist(gray))
#         self.filesMade += 1
#         print("Histogram equalized image written to: " + histPath)
#
#         if show is True:
#             plt.imshow(hist)
#             plt.show()
#
#         return hist
#
# &nbsp;
#
# ## Reflection
#
# Reflection is a way of increasing your dataset by creating a copy that is fliped on its X axis, and a copy that is flipped on its Y axis. The reflection function below uses the built in OpenCV function, cv2.flip, to flip the image on the mentioned axis.  The created images will be saved to the relevant directories in the default configuration.
#
#     def reflection(self, image, horPath, verPath, show = False):
#
#         """
#         Writes reflected copies of the image to the filepath provided.
#         """
#
#         horImg = cv2.flip(image, 0)
#         self.writeImage(horPath, horImg)
#         self.filesMade += 1
#         print("Horizontally reflected image written to: " + horPath)
#
#         if show is True:
#             plt.imshow(horImg)
#             plt.show()
#
#         verImg = cv2.flip(image, 1)
#         self.writeImage(verPath, verImg)
#         self.filesMade += 1
#         print("Vertical reflected image written to: " + verPath)
#
#         if show is True:
#             plt.imshow(verImg)
#             plt.show()
#
#         return horImg, verImg
#
# &nbsp;
#
# ## Gaussian Blur
#
# Gaussian Blur is a popular technique used on images and is especially popular in the computer vision world. The function below uses the ndimage.gaussian_filter function. The created images will be saved to the relevant directories in the default configuration.
#
#     def gaussian(self, filePath, gaussianPath, show = False):
#
#         """
#         Writes gaussian blurred copy of the image to the filepath provided.
#         """
#
#         gaussianBlur = ndimage.gaussian_filter(plt.imread(filePath), sigma=5.11)
#         self.writeImage(gaussianPath, gaussianBlur)
#         self.filesMade += 1
#         print("Gaussian image written to: " + gaussianPath)
#
#         if show is True:
#             plt.imshow(gaussianBlur)
#             plt.show()
#
#         return gaussianBlur
#
# &nbsp;
#
# ## Translation
#
# Translation is a type of Affine Transformation and basically repositions the image within itself. The function below uses the cv2.warpAffine function. The created images will be saved to the relevant directories in the default configuration.
#
#     def translate(self, image, translatedPath, show = False):
#
#         """
#         Writes transformed copy of the image to the filepath provided.
#         """
#
#         cols, rows, chs = image.shape
#
#         translated = cv2.warpAffine(image, np.float32([[1, 0, 84], [0, 1, 56]]), (rows, cols),
#                                     borderMode=cv2.BORDER_CONSTANT, borderValue=(144, 159, 162))
#
#         self.writeImage(filePath, translated)
#         self.filesMade += 1
#         print("Translated image written to: " + filePath)
#
#         if show is True:
#             plt.imshow(translated)
#             plt.show()
#
#         return translated
#
# &nbsp;
#
# ## Rotation
#
# Gaussian Blur is a popular technique used on images and is especially popular in the computer vision world. The function below uses the ndimage.gaussian_filter function. The created images will be saved to the relevant directories in the default configuration.
#
#     def rotation(self, path, filePath, filename, show = False):
#
#         """
#         Writes rotated copies of the image to the filepath provided.
#         """
#
#         img = Image.open(filePath)
#
#         image = cv2.imread(filePath)
#         cols, rows, chs = image.shape
#
#         for i in range(0, 20):
#             randDeg = random.randint(-180, 180)
#             matrix = cv2.getRotationMatrix2D((cols/2, rows/2), randDeg, 0.70)
#             rotated = cv2.warpAffine(image, matrix, (rows, cols), borderMode=cv2.BORDER_CONSTANT,
#                                          borderValue=(144, 159, 162))
#             fullPath = os.path.join(path, str(randDeg) + '-' + str(i) + '-' + filename)
#
#             self.writeImage(fullPath, rotated)
#             self.filesMade += 1
#             print("Rotated image written to: " + fullPath)
#
#             if show is True:
#                 plt.imshow(rotated)
#                 plt.show()
#
# &nbsp;
#
# # Augment your data
# You can use the code below to augment your data. The full Python class that holds the core data functions can be found in [Classes/Data.py](Classes/Data.py). The AMLDnnData class below is a wrapper class around the Data class that allows you to run the code in this Notebook. Follow the steps below and execute the code blocks using __SHIFT + ENTER__.
#
#
# ## Sort your dataset
# The ALL IDB_1 dataset is the one used in this tutorial. In this dataset there were 49 negative and 59 positive. To make this even I removed 10 images from the positive dataset. From here I removed a further 10 images per class for testing further on in the tutorial and for the purpose of demos etc. In my case I ended up with 20 test images (10 pos/10 neg) and 39 images per class ready for augmentation. Place the original images that you wish to augment into the __Model/Data/0__ & __Model/Data/1__. Using this program I was able to create a dataset of __1053__ positive and __1053__ negative augmented images.
#
# &nbsp;
#
#
# ## Import required libraries
# We are going to run the above code in the browser, to do this you need to run the following code. Execute the code block by placing your cursor inside and clicking __shift__ & __enter__.

# %%
import matplotlib.pyplot as plt

# %matplotlib inline
plt.rcParams['figure.figsize'] = (5.0, 4.0) 
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

from Classes.Data import Data

# %% [markdown]
# &nbsp;
#
# ## Initiate the data wrapper
# The following Python class is a wrapper for the [Data (Classes/Data.py)](Classes/Data.py) class.

# %%
class AMLDnnData():
    
    def __init__(self):
        
        """
        Sets up all default requirements and placeholders
        needed for the augmentation program. 
        """

        self.Data = Data()
        
    def processDataset(self):
        
        """
        Make sure you have your equal amounts of positive and negative
        samples in the Model/Data directories.
         
        Only run this function once! it will continually make copies 
        of all images in the Settings->TrainDir directory specified 
        in Required/confs.json      
        """
        
        self.Data.processDataset() 
        
AMLDnnData = AMLDnnData()

# %% [markdown]
# &nbsp;
#
# ## Augment the dataset
#
# Make sure you have your equal amounts of positive and negative samples in the Model/Data directories, in my program I use the directories 0 and 1, but you can name them what you like as long as they are integers.
#
# __Only run this function once! it will continually make copies of all images in the Settings->TrainDir directory specified in Required/confs.json__
#
# &nbsp;
#
# Execute the following code block to process the dataset by running all of the functions shown above. You may see slides that are a strange color or not square, you can ignore this as the actual saved image is correct.

# %%
# Uncomment the code, only run once!
AMLDnnData.processDataset()
# Out:
# Resized image written to: Model/Augmented/1/Im029_1.jpg
# Grayscaled image written to: Model/Augmented/1/Gray-Im029_1.jpg
# Histogram equalized image written to: Model/Augmented/1/Hist-Im029_1.jpg
# Horizontally reflected image written to: Model/Augmented/1/Hor-Im029_1.jpg
# Vertical reflected image written to: Model/Augmented/1/Ver-Im029_1.jpg
# Gaussian image written to: Model/Augmented/1/Gaus-Im029_1.jpg
# Translated image written to: Model/Augmented/1/Trans-Im029_1.jpg
# Rotated image written to: Model/Augmented/1/-22-0-Im029_1.jpg
# Rotated image written to: Model/Augmented/1/37-1-Im029_1.jpg
# Rotated image written to: Model/Augmented/1/-128-2-Im029_1.jpg
# Rotated image written to: Model/Augmented/1/65-3-Im029_1.jpg
# Rotated image written to: Model/Augmented/1/-118-4-Im029_1.jpg
# Rotated image written to: Model/Augmented/1/63-5-Im029_1.jpg
# Rotated image written to: Model/Augmented/1/79-6-Im029_1.jpg
# Rotated image written to: Model/Augmented/1/177-7-Im029_1.jpg
# Rotated image written to: Model/Augmented/1/-27-8-Im029_1.jpg
# Rotated image written to: Model/Augmented/1/-51-9-Im029_1.jpg
# Rotated image written to: Model/Augmented/1/149-10-Im029_1.jpg
# Rotated image written to: Model/Augmented/1/63-11-Im029_1.jpg
# Rotated image written to: Model/Augmented/1/7-12-Im029_1.jpg
# Rotated image written to: Model/Augmented/1/157-13-Im029_1.jpg
# Rotated image written to: Model/Augmented/1/-55-14-Im029_1.jpg
# Rotated image written to: Model/Augmented/1/4-15-Im029_1.jpg
# Rotated image written to: Model/Augmented/1/64-16-Im029_1.jpg
# Rotated image written to: Model/Augmented/1/-133-17-Im029_1.jpg
# Rotated image written to: Model/Augmented/1/-98-18-Im029_1.jpg
# Rotated image written to: Model/Augmented/1/153-19-Im029_1.jpg
# Total augmented files created so far 27
#
# Resized image written to: Model/Augmented/1/Im030_1.jpg
# Grayscaled image written to: Model/Augmented/1/Gray-Im030_1.jpg
# Histogram equalized image written to: Model/Augmented/1/Hist-Im030_1.jpg
# Horizontally reflected image written to: Model/Augmented/1/Hor-Im030_1.jpg
# Vertical reflected image written to: Model/Augmented/1/Ver-Im030_1.jpg
# Gaussian image written to: Model/Augmented/1/Gaus-Im030_1.jpg
# Translated image written to: Model/Augmented/1/Trans-Im030_1.jpg
# Rotated image written to: Model/Augmented/1/104-0-Im030_1.jpg
# Rotated image written to: Model/Augmented/1/44-1-Im030_1.jpg
# Rotated image written to: Model/Augmented/1/-60-2-Im030_1.jpg
# Rotated image written to: Model/Augmented/1/-24-3-Im030_1.jpg
# Rotated image written to: Model/Augmented/1/-86-4-Im030_1.jpg
# Rotated image written to: Model/Augmented/1/-54-5-Im030_1.jpg
# Rotated image written to: Model/Augmented/1/-104-6-Im030_1.jpg
# Rotated image written to: Model/Augmented/1/-145-7-Im030_1.jpg
# Rotated image written to: Model/Augmented/1/1-8-Im030_1.jpg
# Rotated image written to: Model/Augmented/1/-81-9-Im030_1.jpg
# Rotated image written to: Model/Augmented/1/-143-10-Im030_1.jpg
# Rotated image written to: Model/Augmented/1/172-11-Im030_1.jpg
# Rotated image written to: Model/Augmented/1/13-12-Im030_1.jpg
# Rotated image written to: Model/Augmented/1/-59-13-Im030_1.jpg
# Rotated image written to: Model/Augmented/1/44-14-Im030_1.jpg
# Rotated image written to: Model/Augmented/1/102-15-Im030_1.jpg
# Rotated image written to: Model/Augmented/1/-118-16-Im030_1.jpg
# Rotated image written to: Model/Augmented/1/-102-17-Im030_1.jpg
# Rotated image written to: Model/Augmented/1/-25-18-Im030_1.jpg
# Rotated image written to: Model/Augmented/1/-81-19-Im030_1.jpg
# Total augmented files created so far 54
#
# Resized image written to: Model/Augmented/1/Im055_1.jpg
# Grayscaled image written to: Model/Augmented/1/Gray-Im055_1.jpg
# Histogram equalized image written to: Model/Augmented/1/Hist-Im055_1.jpg
# Horizontally reflected image written to: Model/Augmented/1/Hor-Im055_1.jpg
# Vertical reflected image written to: Model/Augmented/1/Ver-Im055_1.jpg
# Gaussian image written to: Model/Augmented/1/Gaus-Im055_1.jpg
# Translated image written to: Model/Augmented/1/Trans-Im055_1.jpg
# Rotated image written to: Model/Augmented/1/170-0-Im055_1.jpg
# Rotated image written to: Model/Augmented/1/71-1-Im055_1.jpg
# Rotated image written to: Model/Augmented/1/25-2-Im055_1.jpg
# Rotated image written to: Model/Augmented/1/9-3-Im055_1.jpg
# Rotated image written to: Model/Augmented/1/4-4-Im055_1.jpg
# Rotated image written to: Model/Augmented/1/-50-5-Im055_1.jpg
# Rotated image written to: Model/Augmented/1/9-6-Im055_1.jpg
# Rotated image written to: Model/Augmented/1/125-7-Im055_1.jpg
# Rotated image written to: Model/Augmented/1/129-8-Im055_1.jpg
# Rotated image written to: Model/Augmented/1/46-9-Im055_1.jpg
# Rotated image written to: Model/Augmented/1/78-10-Im055_1.jpg
# Rotated image written to: Model/Augmented/1/25-11-Im055_1.jpg
# Rotated image written to: Model/Augmented/1/-117-12-Im055_1.jpg
# Rotated image written to: Model/Augmented/1/-8-13-Im055_1.jpg
# Rotated image written to: Model/Augmented/1/75-14-Im055_1.jpg
# Rotated image written to: Model/Augmented/1/119-15-Im055_1.jpg
# Rotated image written to: Model/Augmented/1/-150-16-Im055_1.jpg
# Rotated image written to: Model/Augmented/1/-15-17-Im055_1.jpg
# Rotated image written to: Model/Augmented/1/-71-18-Im055_1.jpg
# Rotated image written to: Model/Augmented/1/47-19-Im055_1.jpg
# Total augmented files created so far 81
#
# Resized image written to: Model/Augmented/1/Im026_1.jpg
# Grayscaled image written to: Model/Augmented/1/Gray-Im026_1.jpg
# Histogram equalized image written to: Model/Augmented/1/Hist-Im026_1.jpg
# Horizontally reflected image written to: Model/Augmented/1/Hor-Im026_1.jpg
# Vertical reflected image written to: Model/Augmented/1/Ver-Im026_1.jpg
# Gaussian image written to: Model/Augmented/1/Gaus-Im026_1.jpg
# Translated image written to: Model/Augmented/1/Trans-Im026_1.jpg
# Rotated image written to: Model/Augmented/1/157-0-Im026_1.jpg
# Rotated image written to: Model/Augmented/1/-105-1-Im026_1.jpg
# Rotated image written to: Model/Augmented/1/-176-2-Im026_1.jpg
# Rotated image written to: Model/Augmented/1/-134-3-Im026_1.jpg
# Rotated image written to: Model/Augmented/1/9-4-Im026_1.jpg
# Rotated image written to: Model/Augmented/1/-82-5-Im026_1.jpg
# Rotated image written to: Model/Augmented/1/145-6-Im026_1.jpg
# Rotated image written to: Model/Augmented/1/-15-7-Im026_1.jpg
# Rotated image written to: Model/Augmented/1/150-8-Im026_1.jpg
# Rotated image written to: Model/Augmented/1/-93-9-Im026_1.jpg
# Rotated image written to: Model/Augmented/1/-112-10-Im026_1.jpg
# Rotated image written to: Model/Augmented/1/-18-11-Im026_1.jpg
# Rotated image written to: Model/Augmented/1/37-12-Im026_1.jpg
# Rotated image written to: Model/Augmented/1/21-13-Im026_1.jpg
# Rotated image written to: Model/Augmented/1/-135-14-Im026_1.jpg
# Rotated image written to: Model/Augmented/1/-53-15-Im026_1.jpg
# Rotated image written to: Model/Augmented/1/-95-16-Im026_1.jpg
# Rotated image written to: Model/Augmented/1/-99-17-Im026_1.jpg
# Rotated image written to: Model/Augmented/1/107-18-Im026_1.jpg
# Rotated image written to: Model/Augmented/1/62-19-Im026_1.jpg
# Total augmented files created so far 108
#
# Resized image written to: Model/Augmented/1/Im019_1.jpg
# Grayscaled image written to: Model/Augmented/1/Gray-Im019_1.jpg
# Histogram equalized image written to: Model/Augmented/1/Hist-Im019_1.jpg
# Horizontally reflected image written to: Model/Augmented/1/Hor-Im019_1.jpg
# Vertical reflected image written to: Model/Augmented/1/Ver-Im019_1.jpg
# Gaussian image written to: Model/Augmented/1/Gaus-Im019_1.jpg
# Translated image written to: Model/Augmented/1/Trans-Im019_1.jpg
# Rotated image written to: Model/Augmented/1/-150-0-Im019_1.jpg
# Rotated image written to: Model/Augmented/1/-175-1-Im019_1.jpg
# Rotated image written to: Model/Augmented/1/58-2-Im019_1.jpg
# Rotated image written to: Model/Augmented/1/16-3-Im019_1.jpg
# Rotated image written to: Model/Augmented/1/-164-4-Im019_1.jpg
# Rotated image written to: Model/Augmented/1/-82-5-Im019_1.jpg
# Rotated image written to: Model/Augmented/1/-49-6-Im019_1.jpg
# Rotated image written to: Model/Augmented/1/-161-7-Im019_1.jpg
# Rotated image written to: Model/Augmented/1/-39-8-Im019_1.jpg
# Rotated image written to: Model/Augmented/1/-170-9-Im019_1.jpg
# Rotated image written to: Model/Augmented/1/120-10-Im019_1.jpg
# Rotated image written to: Model/Augmented/1/-116-11-Im019_1.jpg
# Rotated image written to: Model/Augmented/1/-16-12-Im019_1.jpg
# Rotated image written to: Model/Augmented/1/-102-13-Im019_1.jpg
# Rotated image written to: Model/Augmented/1/-63-14-Im019_1.jpg
# Rotated image written to: Model/Augmented/1/47-15-Im019_1.jpg
# Rotated image written to: Model/Augmented/1/-77-16-Im019_1.jpg
# Rotated image written to: Model/Augmented/1/-17-17-Im019_1.jpg
# Rotated image written to: Model/Augmented/1/-101-18-Im019_1.jpg
# Rotated image written to: Model/Augmented/1/37-19-Im019_1.jpg
# Total augmented files created so far 135
#
# Resized image written to: Model/Augmented/1/Im052_1.jpg
# Grayscaled image written to: Model/Augmented/1/Gray-Im052_1.jpg
# Histogram equalized image written to: Model/Augmented/1/Hist-Im052_1.jpg
# Horizontally reflected image written to: Model/Augmented/1/Hor-Im052_1.jpg
# Vertical reflected image written to: Model/Augmented/1/Ver-Im052_1.jpg
# Gaussian image written to: Model/Augmented/1/Gaus-Im052_1.jpg
# Translated image written to: Model/Augmented/1/Trans-Im052_1.jpg
# Rotated image written to: Model/Augmented/1/60-0-Im052_1.jpg
# Rotated image written to: Model/Augmented/1/142-1-Im052_1.jpg
# Rotated image written to: Model/Augmented/1/-121-2-Im052_1.jpg
# Rotated image written to: Model/Augmented/1/-38-3-Im052_1.jpg
# Rotated image written to: Model/Augmented/1/156-4-Im052_1.jpg
# Rotated image written to: Model/Augmented/1/-69-5-Im052_1.jpg
# Rotated image written to: Model/Augmented/1/-22-6-Im052_1.jpg
# Rotated image written to: Model/Augmented/1/130-7-Im052_1.jpg
# Rotated image written to: Model/Augmented/1/18-8-Im052_1.jpg
# Rotated image written to: Model/Augmented/1/-145-9-Im052_1.jpg
# Rotated image written to: Model/Augmented/1/-38-10-Im052_1.jpg
# Rotated image written to: Model/Augmented/1/-41-11-Im052_1.jpg
# Rotated image written to: Model/Augmented/1/32-12-Im052_1.jpg
# Rotated image written to: Model/Augmented/1/-171-13-Im052_1.jpg
# Rotated image written to: Model/Augmented/1/-14-14-Im052_1.jpg
# Rotated image written to: Model/Augmented/1/107-15-Im052_1.jpg
# Rotated image written to: Model/Augmented/1/151-16-Im052_1.jpg
# Rotated image written to: Model/Augmented/1/79-17-Im052_1.jpg
# Rotated image written to: Model/Augmented/1/75-18-Im052_1.jpg
# Rotated image written to: Model/Augmented/1/139-19-Im052_1.jpg
# Total augmented files created so far 162
#
# Resized image written to: Model/Augmented/1/Im015_1.jpg
# Grayscaled image written to: Model/Augmented/1/Gray-Im015_1.jpg
# Histogram equalized image written to: Model/Augmented/1/Hist-Im015_1.jpg
# Horizontally reflected image written to: Model/Augmented/1/Hor-Im015_1.jpg
# Vertical reflected image written to: Model/Augmented/1/Ver-Im015_1.jpg
# Gaussian image written to: Model/Augmented/1/Gaus-Im015_1.jpg
# Translated image written to: Model/Augmented/1/Trans-Im015_1.jpg
# Rotated image written to: Model/Augmented/1/-52-0-Im015_1.jpg
# Rotated image written to: Model/Augmented/1/179-1-Im015_1.jpg
# Rotated image written to: Model/Augmented/1/149-2-Im015_1.jpg
# Rotated image written to: Model/Augmented/1/-164-3-Im015_1.jpg
# Rotated image written to: Model/Augmented/1/-117-4-Im015_1.jpg
# Rotated image written to: Model/Augmented/1/88-5-Im015_1.jpg
# Rotated image written to: Model/Augmented/1/-99-6-Im015_1.jpg
# Rotated image written to: Model/Augmented/1/30-7-Im015_1.jpg
# Rotated image written to: Model/Augmented/1/-148-8-Im015_1.jpg
# Rotated image written to: Model/Augmented/1/-133-9-Im015_1.jpg
# Rotated image written to: Model/Augmented/1/-28-10-Im015_1.jpg
# Rotated image written to: Model/Augmented/1/157-11-Im015_1.jpg
# Rotated image written to: Model/Augmented/1/-135-12-Im015_1.jpg
# Rotated image written to: Model/Augmented/1/-11-13-Im015_1.jpg
# Rotated image written to: Model/Augmented/1/-135-14-Im015_1.jpg
# Rotated image written to: Model/Augmented/1/-55-15-Im015_1.jpg
# Rotated image written to: Model/Augmented/1/60-16-Im015_1.jpg
# Rotated image written to: Model/Augmented/1/80-17-Im015_1.jpg
# Rotated image written to: Model/Augmented/1/-127-18-Im015_1.jpg
# Rotated image written to: Model/Augmented/1/0-19-Im015_1.jpg
# Total augmented files created so far 189
#
# Resized image written to: Model/Augmented/1/Im018_1.jpg
# Grayscaled image written to: Model/Augmented/1/Gray-Im018_1.jpg
# Histogram equalized image written to: Model/Augmented/1/Hist-Im018_1.jpg
# Horizontally reflected image written to: Model/Augmented/1/Hor-Im018_1.jpg
# Vertical reflected image written to: Model/Augmented/1/Ver-Im018_1.jpg
# Gaussian image written to: Model/Augmented/1/Gaus-Im018_1.jpg
# Translated image written to: Model/Augmented/1/Trans-Im018_1.jpg
# Rotated image written to: Model/Augmented/1/-142-0-Im018_1.jpg
# Rotated image written to: Model/Augmented/1/146-1-Im018_1.jpg
# Rotated image written to: Model/Augmented/1/62-2-Im018_1.jpg
# Rotated image written to: Model/Augmented/1/68-3-Im018_1.jpg
# Rotated image written to: Model/Augmented/1/-145-4-Im018_1.jpg
# Rotated image written to: Model/Augmented/1/134-5-Im018_1.jpg
# Rotated image written to: Model/Augmented/1/-75-6-Im018_1.jpg
# Rotated image written to: Model/Augmented/1/-51-7-Im018_1.jpg
# Rotated image written to: Model/Augmented/1/92-8-Im018_1.jpg
# Rotated image written to: Model/Augmented/1/167-9-Im018_1.jpg
# Rotated image written to: Model/Augmented/1/-148-10-Im018_1.jpg
# Rotated image written to: Model/Augmented/1/69-11-Im018_1.jpg
# Rotated image written to: Model/Augmented/1/24-12-Im018_1.jpg
# Rotated image written to: Model/Augmented/1/14-13-Im018_1.jpg
# Rotated image written to: Model/Augmented/1/154-14-Im018_1.jpg
# Rotated image written to: Model/Augmented/1/159-15-Im018_1.jpg
# Rotated image written to: Model/Augmented/1/122-16-Im018_1.jpg
# Rotated image written to: Model/Augmented/1/63-17-Im018_1.jpg
# Rotated image written to: Model/Augmented/1/-57-18-Im018_1.jpg
# Rotated image written to: Model/Augmented/1/-37-19-Im018_1.jpg
# Total augmented files created so far 216
#
# Resized image written to: Model/Augmented/1/Im063_1.jpg
# Grayscaled image written to: Model/Augmented/1/Gray-Im063_1.jpg
# Histogram equalized image written to: Model/Augmented/1/Hist-Im063_1.jpg
# Horizontally reflected image written to: Model/Augmented/1/Hor-Im063_1.jpg
# Vertical reflected image written to: Model/Augmented/1/Ver-Im063_1.jpg
# Gaussian image written to: Model/Augmented/1/Gaus-Im063_1.jpg
# Translated image written to: Model/Augmented/1/Trans-Im063_1.jpg
# Rotated image written to: Model/Augmented/1/-171-0-Im063_1.jpg
# Rotated image written to: Model/Augmented/1/-8-1-Im063_1.jpg
# Rotated image written to: Model/Augmented/1/-99-2-Im063_1.jpg
# Rotated image written to: Model/Augmented/1/-55-3-Im063_1.jpg
# Rotated image written to: Model/Augmented/1/-147-4-Im063_1.jpg
# Rotated image written to: Model/Augmented/1/-22-5-Im063_1.jpg
# Rotated image written to: Model/Augmented/1/-92-6-Im063_1.jpg
# Rotated image written to: Model/Augmented/1/-90-7-Im063_1.jpg
# Rotated image written to: Model/Augmented/1/-173-8-Im063_1.jpg
# Rotated image written to: Model/Augmented/1/138-9-Im063_1.jpg
# Rotated image written to: Model/Augmented/1/-81-10-Im063_1.jpg
# Rotated image written to: Model/Augmented/1/88-11-Im063_1.jpg
# Rotated image written to: Model/Augmented/1/-43-12-Im063_1.jpg
# Rotated image written to: Model/Augmented/1/5-13-Im063_1.jpg
# Rotated image written to: Model/Augmented/1/-59-14-Im063_1.jpg
# Rotated image written to: Model/Augmented/1/-49-15-Im063_1.jpg
# Rotated image written to: Model/Augmented/1/-86-16-Im063_1.jpg
# Rotated image written to: Model/Augmented/1/-71-17-Im063_1.jpg
# Rotated image written to: Model/Augmented/1/-64-18-Im063_1.jpg
# Rotated image written to: Model/Augmented/1/-113-19-Im063_1.jpg
# Total augmented files created so far 243
#
# Resized image written to: Model/Augmented/1/Im003_1.jpg
# Grayscaled image written to: Model/Augmented/1/Gray-Im003_1.jpg
# Histogram equalized image written to: Model/Augmented/1/Hist-Im003_1.jpg
# Horizontally reflected image written to: Model/Augmented/1/Hor-Im003_1.jpg
# Vertical reflected image written to: Model/Augmented/1/Ver-Im003_1.jpg
# Gaussian image written to: Model/Augmented/1/Gaus-Im003_1.jpg
# Translated image written to: Model/Augmented/1/Trans-Im003_1.jpg
# Rotated image written to: Model/Augmented/1/-15-0-Im003_1.jpg
# Rotated image written to: Model/Augmented/1/1-1-Im003_1.jpg
# Rotated image written to: Model/Augmented/1/-4-2-Im003_1.jpg
# Rotated image written to: Model/Augmented/1/-130-3-Im003_1.jpg
# Rotated image written to: Model/Augmented/1/30-4-Im003_1.jpg
# Rotated image written to: Model/Augmented/1/48-5-Im003_1.jpg
# Rotated image written to: Model/Augmented/1/-44-6-Im003_1.jpg
# Rotated image written to: Model/Augmented/1/68-7-Im003_1.jpg
# Rotated image written to: Model/Augmented/1/0-8-Im003_1.jpg
# Rotated image written to: Model/Augmented/1/-105-9-Im003_1.jpg
# Rotated image written to: Model/Augmented/1/19-10-Im003_1.jpg
# Rotated image written to: Model/Augmented/1/7-11-Im003_1.jpg
# Rotated image written to: Model/Augmented/1/153-12-Im003_1.jpg
# Rotated image written to: Model/Augmented/1/-3-13-Im003_1.jpg
# Rotated image written to: Model/Augmented/1/-156-14-Im003_1.jpg
# Rotated image written to: Model/Augmented/1/-151-15-Im003_1.jpg
# Rotated image written to: Model/Augmented/1/-37-16-Im003_1.jpg
# Rotated image written to: Model/Augmented/1/16-17-Im003_1.jpg
# Rotated image written to: Model/Augmented/1/-74-18-Im003_1.jpg
# Rotated image written to: Model/Augmented/1/-114-19-Im003_1.jpg
# Total augmented files created so far 270
#
# Resized image written to: Model/Augmented/1/Im050_1.jpg
# Grayscaled image written to: Model/Augmented/1/Gray-Im050_1.jpg
# Histogram equalized image written to: Model/Augmented/1/Hist-Im050_1.jpg
# Horizontally reflected image written to: Model/Augmented/1/Hor-Im050_1.jpg
# Vertical reflected image written to: Model/Augmented/1/Ver-Im050_1.jpg
# Gaussian image written to: Model/Augmented/1/Gaus-Im050_1.jpg
# Translated image written to: Model/Augmented/1/Trans-Im050_1.jpg
# Rotated image written to: Model/Augmented/1/91-0-Im050_1.jpg
# Rotated image written to: Model/Augmented/1/-71-1-Im050_1.jpg
# Rotated image written to: Model/Augmented/1/2-2-Im050_1.jpg
# Rotated image written to: Model/Augmented/1/141-3-Im050_1.jpg
# Rotated image written to: Model/Augmented/1/156-4-Im050_1.jpg
# Rotated image written to: Model/Augmented/1/79-5-Im050_1.jpg
# Rotated image written to: Model/Augmented/1/124-6-Im050_1.jpg
# Rotated image written to: Model/Augmented/1/123-7-Im050_1.jpg
# Rotated image written to: Model/Augmented/1/-143-8-Im050_1.jpg
# Rotated image written to: Model/Augmented/1/104-9-Im050_1.jpg
# Rotated image written to: Model/Augmented/1/-48-10-Im050_1.jpg
# Rotated image written to: Model/Augmented/1/-123-11-Im050_1.jpg
# Rotated image written to: Model/Augmented/1/-1-12-Im050_1.jpg
# Rotated image written to: Model/Augmented/1/-159-13-Im050_1.jpg
# Rotated image written to: Model/Augmented/1/20-14-Im050_1.jpg
# Rotated image written to: Model/Augmented/1/97-15-Im050_1.jpg
# Rotated image written to: Model/Augmented/1/4-16-Im050_1.jpg
# Rotated image written to: Model/Augmented/1/-169-17-Im050_1.jpg
# Rotated image written to: Model/Augmented/1/-107-18-Im050_1.jpg
# Rotated image written to: Model/Augmented/1/-20-19-Im050_1.jpg
# Total augmented files created so far 297
#
# Resized image written to: Model/Augmented/1/Im002_1.jpg
# Grayscaled image written to: Model/Augmented/1/Gray-Im002_1.jpg
# Histogram equalized image written to: Model/Augmented/1/Hist-Im002_1.jpg
# Horizontally reflected image written to: Model/Augmented/1/Hor-Im002_1.jpg
# Vertical reflected image written to: Model/Augmented/1/Ver-Im002_1.jpg
# Gaussian image written to: Model/Augmented/1/Gaus-Im002_1.jpg
# Translated image written to: Model/Augmented/1/Trans-Im002_1.jpg
# Rotated image written to: Model/Augmented/1/29-0-Im002_1.jpg
# Rotated image written to: Model/Augmented/1/-123-1-Im002_1.jpg
# Rotated image written to: Model/Augmented/1/-165-2-Im002_1.jpg
# Rotated image written to: Model/Augmented/1/-9-3-Im002_1.jpg
# Rotated image written to: Model/Augmented/1/-116-4-Im002_1.jpg
# Rotated image written to: Model/Augmented/1/22-5-Im002_1.jpg
# Rotated image written to: Model/Augmented/1/49-6-Im002_1.jpg
# Rotated image written to: Model/Augmented/1/-35-7-Im002_1.jpg
# Rotated image written to: Model/Augmented/1/-118-8-Im002_1.jpg
# Rotated image written to: Model/Augmented/1/60-9-Im002_1.jpg
# Rotated image written to: Model/Augmented/1/33-10-Im002_1.jpg
# Rotated image written to: Model/Augmented/1/-22-11-Im002_1.jpg
# Rotated image written to: Model/Augmented/1/18-12-Im002_1.jpg
# Rotated image written to: Model/Augmented/1/-97-13-Im002_1.jpg
# Rotated image written to: Model/Augmented/1/-12-14-Im002_1.jpg
# Rotated image written to: Model/Augmented/1/63-15-Im002_1.jpg
# Rotated image written to: Model/Augmented/1/105-16-Im002_1.jpg
# Rotated image written to: Model/Augmented/1/61-17-Im002_1.jpg
# Rotated image written to: Model/Augmented/1/-41-18-Im002_1.jpg
# Rotated image written to: Model/Augmented/1/-137-19-Im002_1.jpg
# Total augmented files created so far 324
#
# Resized image written to: Model/Augmented/1/Im009_1.jpg
# Grayscaled image written to: Model/Augmented/1/Gray-Im009_1.jpg
# Histogram equalized image written to: Model/Augmented/1/Hist-Im009_1.jpg
# Horizontally reflected image written to: Model/Augmented/1/Hor-Im009_1.jpg
# Vertical reflected image written to: Model/Augmented/1/Ver-Im009_1.jpg
# Gaussian image written to: Model/Augmented/1/Gaus-Im009_1.jpg
# Translated image written to: Model/Augmented/1/Trans-Im009_1.jpg
# Rotated image written to: Model/Augmented/1/21-0-Im009_1.jpg
# Rotated image written to: Model/Augmented/1/77-1-Im009_1.jpg
# Rotated image written to: Model/Augmented/1/177-2-Im009_1.jpg
# Rotated image written to: Model/Augmented/1/-58-3-Im009_1.jpg
# Rotated image written to: Model/Augmented/1/94-4-Im009_1.jpg
# Rotated image written to: Model/Augmented/1/-161-5-Im009_1.jpg
# Rotated image written to: Model/Augmented/1/-88-6-Im009_1.jpg
# Rotated image written to: Model/Augmented/1/6-7-Im009_1.jpg
# Rotated image written to: Model/Augmented/1/180-8-Im009_1.jpg
# Rotated image written to: Model/Augmented/1/156-9-Im009_1.jpg
# Rotated image written to: Model/Augmented/1/88-10-Im009_1.jpg
# Rotated image written to: Model/Augmented/1/-19-11-Im009_1.jpg
# Rotated image written to: Model/Augmented/1/-93-12-Im009_1.jpg
# Rotated image written to: Model/Augmented/1/-8-13-Im009_1.jpg
# Rotated image written to: Model/Augmented/1/23-14-Im009_1.jpg
# Rotated image written to: Model/Augmented/1/-46-15-Im009_1.jpg
# Rotated image written to: Model/Augmented/1/-42-16-Im009_1.jpg
# Rotated image written to: Model/Augmented/1/-83-17-Im009_1.jpg
# Rotated image written to: Model/Augmented/1/23-18-Im009_1.jpg
# Rotated image written to: Model/Augmented/1/131-19-Im009_1.jpg
# Total augmented files created so far 351
#
# Resized image written to: Model/Augmented/1/Im004_1.jpg
# Grayscaled image written to: Model/Augmented/1/Gray-Im004_1.jpg
# Histogram equalized image written to: Model/Augmented/1/Hist-Im004_1.jpg
# Horizontally reflected image written to: Model/Augmented/1/Hor-Im004_1.jpg
# Vertical reflected image written to: Model/Augmented/1/Ver-Im004_1.jpg
# Gaussian image written to: Model/Augmented/1/Gaus-Im004_1.jpg
# Translated image written to: Model/Augmented/1/Trans-Im004_1.jpg
# Rotated image written to: Model/Augmented/1/-157-0-Im004_1.jpg
# Rotated image written to: Model/Augmented/1/29-1-Im004_1.jpg
# Rotated image written to: Model/Augmented/1/-108-2-Im004_1.jpg
# Rotated image written to: Model/Augmented/1/-75-3-Im004_1.jpg
# Rotated image written to: Model/Augmented/1/-45-4-Im004_1.jpg
# Rotated image written to: Model/Augmented/1/176-5-Im004_1.jpg
# Rotated image written to: Model/Augmented/1/92-6-Im004_1.jpg
# Rotated image written to: Model/Augmented/1/-8-7-Im004_1.jpg
# Rotated image written to: Model/Augmented/1/-122-8-Im004_1.jpg
# Rotated image written to: Model/Augmented/1/45-9-Im004_1.jpg
# Rotated image written to: Model/Augmented/1/-64-10-Im004_1.jpg
# Rotated image written to: Model/Augmented/1/-63-11-Im004_1.jpg
# Rotated image written to: Model/Augmented/1/44-12-Im004_1.jpg
# Rotated image written to: Model/Augmented/1/-83-13-Im004_1.jpg
# Rotated image written to: Model/Augmented/1/-69-14-Im004_1.jpg
# Rotated image written to: Model/Augmented/1/67-15-Im004_1.jpg
# Rotated image written to: Model/Augmented/1/14-16-Im004_1.jpg
# Rotated image written to: Model/Augmented/1/-14-17-Im004_1.jpg
# Rotated image written to: Model/Augmented/1/93-18-Im004_1.jpg
# Rotated image written to: Model/Augmented/1/141-19-Im004_1.jpg
# Total augmented files created so far 378
#
# Resized image written to: Model/Augmented/1/Im048_1.jpg
# Grayscaled image written to: Model/Augmented/1/Gray-Im048_1.jpg
# Histogram equalized image written to: Model/Augmented/1/Hist-Im048_1.jpg
# Horizontally reflected image written to: Model/Augmented/1/Hor-Im048_1.jpg
# Vertical reflected image written to: Model/Augmented/1/Ver-Im048_1.jpg
# Gaussian image written to: Model/Augmented/1/Gaus-Im048_1.jpg
# Translated image written to: Model/Augmented/1/Trans-Im048_1.jpg
# Rotated image written to: Model/Augmented/1/-97-0-Im048_1.jpg
# Rotated image written to: Model/Augmented/1/-41-1-Im048_1.jpg
# Rotated image written to: Model/Augmented/1/145-2-Im048_1.jpg
# Rotated image written to: Model/Augmented/1/-141-3-Im048_1.jpg
# Rotated image written to: Model/Augmented/1/108-4-Im048_1.jpg
# Rotated image written to: Model/Augmented/1/-7-5-Im048_1.jpg
# Rotated image written to: Model/Augmented/1/141-6-Im048_1.jpg
# Rotated image written to: Model/Augmented/1/-17-7-Im048_1.jpg
# Rotated image written to: Model/Augmented/1/-110-8-Im048_1.jpg
# Rotated image written to: Model/Augmented/1/7-9-Im048_1.jpg
# Rotated image written to: Model/Augmented/1/-5-10-Im048_1.jpg
# Rotated image written to: Model/Augmented/1/164-11-Im048_1.jpg
# Rotated image written to: Model/Augmented/1/168-12-Im048_1.jpg
# Rotated image written to: Model/Augmented/1/-83-13-Im048_1.jpg
# Rotated image written to: Model/Augmented/1/-126-14-Im048_1.jpg
# Rotated image written to: Model/Augmented/1/-96-15-Im048_1.jpg
# Rotated image written to: Model/Augmented/1/174-16-Im048_1.jpg
# Rotated image written to: Model/Augmented/1/75-17-Im048_1.jpg
# Rotated image written to: Model/Augmented/1/26-18-Im048_1.jpg
# Rotated image written to: Model/Augmented/1/-171-19-Im048_1.jpg
# Total augmented files created so far 405
#
# Resized image written to: Model/Augmented/1/Im060_1.jpg
# Grayscaled image written to: Model/Augmented/1/Gray-Im060_1.jpg
# Histogram equalized image written to: Model/Augmented/1/Hist-Im060_1.jpg
# Horizontally reflected image written to: Model/Augmented/1/Hor-Im060_1.jpg
# Vertical reflected image written to: Model/Augmented/1/Ver-Im060_1.jpg
# Gaussian image written to: Model/Augmented/1/Gaus-Im060_1.jpg
# Translated image written to: Model/Augmented/1/Trans-Im060_1.jpg
# Rotated image written to: Model/Augmented/1/-115-0-Im060_1.jpg
# Rotated image written to: Model/Augmented/1/-18-1-Im060_1.jpg
# Rotated image written to: Model/Augmented/1/77-2-Im060_1.jpg
# Rotated image written to: Model/Augmented/1/-170-3-Im060_1.jpg
# Rotated image written to: Model/Augmented/1/-72-4-Im060_1.jpg
# Rotated image written to: Model/Augmented/1/-46-5-Im060_1.jpg
# Rotated image written to: Model/Augmented/1/113-6-Im060_1.jpg
# Rotated image written to: Model/Augmented/1/150-7-Im060_1.jpg
# Rotated image written to: Model/Augmented/1/84-8-Im060_1.jpg
# Rotated image written to: Model/Augmented/1/-172-9-Im060_1.jpg
# Rotated image written to: Model/Augmented/1/-99-10-Im060_1.jpg
# Rotated image written to: Model/Augmented/1/9-11-Im060_1.jpg
# Rotated image written to: Model/Augmented/1/27-12-Im060_1.jpg
# Rotated image written to: Model/Augmented/1/136-13-Im060_1.jpg
# Rotated image written to: Model/Augmented/1/108-14-Im060_1.jpg
# Rotated image written to: Model/Augmented/1/81-15-Im060_1.jpg
# Rotated image written to: Model/Augmented/1/-134-16-Im060_1.jpg
# Rotated image written to: Model/Augmented/1/-33-17-Im060_1.jpg
# Rotated image written to: Model/Augmented/1/72-18-Im060_1.jpg
# Rotated image written to: Model/Augmented/1/44-19-Im060_1.jpg
# Total augmented files created so far 432
#
# Resized image written to: Model/Augmented/1/Im020_1.jpg
# Grayscaled image written to: Model/Augmented/1/Gray-Im020_1.jpg
# Histogram equalized image written to: Model/Augmented/1/Hist-Im020_1.jpg
# Horizontally reflected image written to: Model/Augmented/1/Hor-Im020_1.jpg
# Vertical reflected image written to: Model/Augmented/1/Ver-Im020_1.jpg
# Gaussian image written to: Model/Augmented/1/Gaus-Im020_1.jpg
# Translated image written to: Model/Augmented/1/Trans-Im020_1.jpg
# Rotated image written to: Model/Augmented/1/1-0-Im020_1.jpg
# Rotated image written to: Model/Augmented/1/3-1-Im020_1.jpg
# Rotated image written to: Model/Augmented/1/121-2-Im020_1.jpg
# Rotated image written to: Model/Augmented/1/82-3-Im020_1.jpg
# Rotated image written to: Model/Augmented/1/-51-4-Im020_1.jpg
# Rotated image written to: Model/Augmented/1/33-5-Im020_1.jpg
# Rotated image written to: Model/Augmented/1/28-6-Im020_1.jpg
# Rotated image written to: Model/Augmented/1/70-7-Im020_1.jpg
# Rotated image written to: Model/Augmented/1/-153-8-Im020_1.jpg
# Rotated image written to: Model/Augmented/1/-166-9-Im020_1.jpg
# Rotated image written to: Model/Augmented/1/-180-10-Im020_1.jpg
# Rotated image written to: Model/Augmented/1/126-11-Im020_1.jpg
# Rotated image written to: Model/Augmented/1/-80-12-Im020_1.jpg
# Rotated image written to: Model/Augmented/1/32-13-Im020_1.jpg
# Rotated image written to: Model/Augmented/1/122-14-Im020_1.jpg
# Rotated image written to: Model/Augmented/1/-138-15-Im020_1.jpg
# Rotated image written to: Model/Augmented/1/77-16-Im020_1.jpg
# Rotated image written to: Model/Augmented/1/110-17-Im020_1.jpg
# Rotated image written to: Model/Augmented/1/-147-18-Im020_1.jpg
# Rotated image written to: Model/Augmented/1/124-19-Im020_1.jpg
# Total augmented files created so far 459
#
# Resized image written to: Model/Augmented/1/Im011_1.jpg
# Grayscaled image written to: Model/Augmented/1/Gray-Im011_1.jpg
# Histogram equalized image written to: Model/Augmented/1/Hist-Im011_1.jpg
# Horizontally reflected image written to: Model/Augmented/1/Hor-Im011_1.jpg
# Vertical reflected image written to: Model/Augmented/1/Ver-Im011_1.jpg
# Gaussian image written to: Model/Augmented/1/Gaus-Im011_1.jpg
# Translated image written to: Model/Augmented/1/Trans-Im011_1.jpg
# Rotated image written to: Model/Augmented/1/170-0-Im011_1.jpg
# Rotated image written to: Model/Augmented/1/109-1-Im011_1.jpg
# Rotated image written to: Model/Augmented/1/76-2-Im011_1.jpg
# Rotated image written to: Model/Augmented/1/3-3-Im011_1.jpg
# Rotated image written to: Model/Augmented/1/15-4-Im011_1.jpg
# Rotated image written to: Model/Augmented/1/34-5-Im011_1.jpg
# Rotated image written to: Model/Augmented/1/-160-6-Im011_1.jpg
# Rotated image written to: Model/Augmented/1/54-7-Im011_1.jpg
# Rotated image written to: Model/Augmented/1/16-8-Im011_1.jpg
# Rotated image written to: Model/Augmented/1/31-9-Im011_1.jpg
# Rotated image written to: Model/Augmented/1/-112-10-Im011_1.jpg
# Rotated image written to: Model/Augmented/1/21-11-Im011_1.jpg
# Rotated image written to: Model/Augmented/1/-64-12-Im011_1.jpg
# Rotated image written to: Model/Augmented/1/-131-13-Im011_1.jpg
# Rotated image written to: Model/Augmented/1/-145-14-Im011_1.jpg
# Rotated image written to: Model/Augmented/1/-83-15-Im011_1.jpg
# Rotated image written to: Model/Augmented/1/-153-16-Im011_1.jpg
# Rotated image written to: Model/Augmented/1/-34-17-Im011_1.jpg
# Rotated image written to: Model/Augmented/1/-85-18-Im011_1.jpg
# Rotated image written to: Model/Augmented/1/-89-19-Im011_1.jpg
# Total augmented files created so far 486
#
# Resized image written to: Model/Augmented/1/Im008_1.jpg
# Grayscaled image written to: Model/Augmented/1/Gray-Im008_1.jpg
# Histogram equalized image written to: Model/Augmented/1/Hist-Im008_1.jpg
# Horizontally reflected image written to: Model/Augmented/1/Hor-Im008_1.jpg
# Vertical reflected image written to: Model/Augmented/1/Ver-Im008_1.jpg
# Gaussian image written to: Model/Augmented/1/Gaus-Im008_1.jpg
# Translated image written to: Model/Augmented/1/Trans-Im008_1.jpg
# Rotated image written to: Model/Augmented/1/37-0-Im008_1.jpg
# Rotated image written to: Model/Augmented/1/-40-1-Im008_1.jpg
# Rotated image written to: Model/Augmented/1/118-2-Im008_1.jpg
# Rotated image written to: Model/Augmented/1/38-3-Im008_1.jpg
# Rotated image written to: Model/Augmented/1/-3-4-Im008_1.jpg
# Rotated image written to: Model/Augmented/1/-97-5-Im008_1.jpg
# Rotated image written to: Model/Augmented/1/-44-6-Im008_1.jpg
# Rotated image written to: Model/Augmented/1/12-7-Im008_1.jpg
# Rotated image written to: Model/Augmented/1/34-8-Im008_1.jpg
# Rotated image written to: Model/Augmented/1/-87-9-Im008_1.jpg
# Rotated image written to: Model/Augmented/1/-72-10-Im008_1.jpg
# Rotated image written to: Model/Augmented/1/62-11-Im008_1.jpg
# Rotated image written to: Model/Augmented/1/-129-12-Im008_1.jpg
# Rotated image written to: Model/Augmented/1/-22-13-Im008_1.jpg
# Rotated image written to: Model/Augmented/1/-103-14-Im008_1.jpg
# Rotated image written to: Model/Augmented/1/161-15-Im008_1.jpg
# Rotated image written to: Model/Augmented/1/45-16-Im008_1.jpg
# Rotated image written to: Model/Augmented/1/-62-17-Im008_1.jpg
# Rotated image written to: Model/Augmented/1/155-18-Im008_1.jpg
# Rotated image written to: Model/Augmented/1/153-19-Im008_1.jpg
# Total augmented files created so far 513
#
# Resized image written to: Model/Augmented/1/Im051_1.jpg
# Grayscaled image written to: Model/Augmented/1/Gray-Im051_1.jpg
# Histogram equalized image written to: Model/Augmented/1/Hist-Im051_1.jpg
# Horizontally reflected image written to: Model/Augmented/1/Hor-Im051_1.jpg
# Vertical reflected image written to: Model/Augmented/1/Ver-Im051_1.jpg
# Gaussian image written to: Model/Augmented/1/Gaus-Im051_1.jpg
# Translated image written to: Model/Augmented/1/Trans-Im051_1.jpg
# Rotated image written to: Model/Augmented/1/57-0-Im051_1.jpg
# Rotated image written to: Model/Augmented/1/-54-1-Im051_1.jpg
# Rotated image written to: Model/Augmented/1/-166-2-Im051_1.jpg
# Rotated image written to: Model/Augmented/1/128-3-Im051_1.jpg
# Rotated image written to: Model/Augmented/1/5-4-Im051_1.jpg
# Rotated image written to: Model/Augmented/1/44-5-Im051_1.jpg
# Rotated image written to: Model/Augmented/1/-112-6-Im051_1.jpg
# Rotated image written to: Model/Augmented/1/-58-7-Im051_1.jpg
# Rotated image written to: Model/Augmented/1/-163-8-Im051_1.jpg
# Rotated image written to: Model/Augmented/1/122-9-Im051_1.jpg
# Rotated image written to: Model/Augmented/1/-139-10-Im051_1.jpg
# Rotated image written to: Model/Augmented/1/6-11-Im051_1.jpg
# Rotated image written to: Model/Augmented/1/130-12-Im051_1.jpg
# Rotated image written to: Model/Augmented/1/-163-13-Im051_1.jpg
# Rotated image written to: Model/Augmented/1/-128-14-Im051_1.jpg
# Rotated image written to: Model/Augmented/1/-172-15-Im051_1.jpg
# Rotated image written to: Model/Augmented/1/172-16-Im051_1.jpg
# Rotated image written to: Model/Augmented/1/-142-17-Im051_1.jpg
# Rotated image written to: Model/Augmented/1/-65-18-Im051_1.jpg
# Rotated image written to: Model/Augmented/1/90-19-Im051_1.jpg
# Total augmented files created so far 540
#
# Resized image written to: Model/Augmented/1/Im028_1.jpg
# Grayscaled image written to: Model/Augmented/1/Gray-Im028_1.jpg
# Histogram equalized image written to: Model/Augmented/1/Hist-Im028_1.jpg
# Horizontally reflected image written to: Model/Augmented/1/Hor-Im028_1.jpg
# Vertical reflected image written to: Model/Augmented/1/Ver-Im028_1.jpg
# Gaussian image written to: Model/Augmented/1/Gaus-Im028_1.jpg
# Translated image written to: Model/Augmented/1/Trans-Im028_1.jpg
# Rotated image written to: Model/Augmented/1/-107-0-Im028_1.jpg
# Rotated image written to: Model/Augmented/1/173-1-Im028_1.jpg
# Rotated image written to: Model/Augmented/1/146-2-Im028_1.jpg
# Rotated image written to: Model/Augmented/1/14-3-Im028_1.jpg
# Rotated image written to: Model/Augmented/1/-31-4-Im028_1.jpg
# Rotated image written to: Model/Augmented/1/100-5-Im028_1.jpg
# Rotated image written to: Model/Augmented/1/-37-6-Im028_1.jpg
# Rotated image written to: Model/Augmented/1/89-7-Im028_1.jpg
# Rotated image written to: Model/Augmented/1/-15-8-Im028_1.jpg
# Rotated image written to: Model/Augmented/1/-141-9-Im028_1.jpg
# Rotated image written to: Model/Augmented/1/-16-10-Im028_1.jpg
# Rotated image written to: Model/Augmented/1/-62-11-Im028_1.jpg
# Rotated image written to: Model/Augmented/1/-90-12-Im028_1.jpg
# Rotated image written to: Model/Augmented/1/107-13-Im028_1.jpg
# Rotated image written to: Model/Augmented/1/-160-14-Im028_1.jpg
# Rotated image written to: Model/Augmented/1/-132-15-Im028_1.jpg
# Rotated image written to: Model/Augmented/1/23-16-Im028_1.jpg
# Rotated image written to: Model/Augmented/1/60-17-Im028_1.jpg
# Rotated image written to: Model/Augmented/1/152-18-Im028_1.jpg
# Rotated image written to: Model/Augmented/1/122-19-Im028_1.jpg
# Total augmented files created so far 567
#
# Resized image written to: Model/Augmented/1/Im053_1.jpg
# Grayscaled image written to: Model/Augmented/1/Gray-Im053_1.jpg
# Histogram equalized image written to: Model/Augmented/1/Hist-Im053_1.jpg
# Horizontally reflected image written to: Model/Augmented/1/Hor-Im053_1.jpg
# Vertical reflected image written to: Model/Augmented/1/Ver-Im053_1.jpg
# Gaussian image written to: Model/Augmented/1/Gaus-Im053_1.jpg
# Translated image written to: Model/Augmented/1/Trans-Im053_1.jpg
# Rotated image written to: Model/Augmented/1/178-0-Im053_1.jpg
# Rotated image written to: Model/Augmented/1/-180-1-Im053_1.jpg
# Rotated image written to: Model/Augmented/1/-47-2-Im053_1.jpg
# Rotated image written to: Model/Augmented/1/-13-3-Im053_1.jpg
# Rotated image written to: Model/Augmented/1/-130-4-Im053_1.jpg
# Rotated image written to: Model/Augmented/1/-29-5-Im053_1.jpg
# Rotated image written to: Model/Augmented/1/-136-6-Im053_1.jpg
# Rotated image written to: Model/Augmented/1/-76-7-Im053_1.jpg
# Rotated image written to: Model/Augmented/1/-54-8-Im053_1.jpg
# Rotated image written to: Model/Augmented/1/69-9-Im053_1.jpg
# Rotated image written to: Model/Augmented/1/26-10-Im053_1.jpg
# Rotated image written to: Model/Augmented/1/147-11-Im053_1.jpg
# Rotated image written to: Model/Augmented/1/110-12-Im053_1.jpg
# Rotated image written to: Model/Augmented/1/-31-13-Im053_1.jpg
# Rotated image written to: Model/Augmented/1/40-14-Im053_1.jpg
# Rotated image written to: Model/Augmented/1/158-15-Im053_1.jpg
# Rotated image written to: Model/Augmented/1/128-16-Im053_1.jpg
# Rotated image written to: Model/Augmented/1/-168-17-Im053_1.jpg
# Rotated image written to: Model/Augmented/1/177-18-Im053_1.jpg
# Rotated image written to: Model/Augmented/1/-46-19-Im053_1.jpg
# Total augmented files created so far 594
#
# Resized image written to: Model/Augmented/1/Im024_1.jpg
# Grayscaled image written to: Model/Augmented/1/Gray-Im024_1.jpg
# Histogram equalized image written to: Model/Augmented/1/Hist-Im024_1.jpg
# Horizontally reflected image written to: Model/Augmented/1/Hor-Im024_1.jpg
# Vertical reflected image written to: Model/Augmented/1/Ver-Im024_1.jpg
# Gaussian image written to: Model/Augmented/1/Gaus-Im024_1.jpg
# Translated image written to: Model/Augmented/1/Trans-Im024_1.jpg
# Rotated image written to: Model/Augmented/1/-49-0-Im024_1.jpg
# Rotated image written to: Model/Augmented/1/136-1-Im024_1.jpg
# Rotated image written to: Model/Augmented/1/97-2-Im024_1.jpg
# Rotated image written to: Model/Augmented/1/53-3-Im024_1.jpg
# Rotated image written to: Model/Augmented/1/-47-4-Im024_1.jpg
# Rotated image written to: Model/Augmented/1/-149-5-Im024_1.jpg
# Rotated image written to: Model/Augmented/1/-67-6-Im024_1.jpg
# Rotated image written to: Model/Augmented/1/-63-7-Im024_1.jpg
# Rotated image written to: Model/Augmented/1/168-8-Im024_1.jpg
# Rotated image written to: Model/Augmented/1/-15-9-Im024_1.jpg
# Rotated image written to: Model/Augmented/1/-147-10-Im024_1.jpg
# Rotated image written to: Model/Augmented/1/95-11-Im024_1.jpg
# Rotated image written to: Model/Augmented/1/164-12-Im024_1.jpg
# Rotated image written to: Model/Augmented/1/-160-13-Im024_1.jpg
# Rotated image written to: Model/Augmented/1/160-14-Im024_1.jpg
# Rotated image written to: Model/Augmented/1/90-15-Im024_1.jpg
# Rotated image written to: Model/Augmented/1/156-16-Im024_1.jpg
# Rotated image written to: Model/Augmented/1/-128-17-Im024_1.jpg
# Rotated image written to: Model/Augmented/1/-29-18-Im024_1.jpg
# Rotated image written to: Model/Augmented/1/-178-19-Im024_1.jpg
# Total augmented files created so far 621
#
# Resized image written to: Model/Augmented/1/Im059_1.jpg
# Grayscaled image written to: Model/Augmented/1/Gray-Im059_1.jpg
# Histogram equalized image written to: Model/Augmented/1/Hist-Im059_1.jpg
# Horizontally reflected image written to: Model/Augmented/1/Hor-Im059_1.jpg
# Vertical reflected image written to: Model/Augmented/1/Ver-Im059_1.jpg
# Gaussian image written to: Model/Augmented/1/Gaus-Im059_1.jpg
# Translated image written to: Model/Augmented/1/Trans-Im059_1.jpg
# Rotated image written to: Model/Augmented/1/-38-0-Im059_1.jpg
# Rotated image written to: Model/Augmented/1/-128-1-Im059_1.jpg
# Rotated image written to: Model/Augmented/1/21-2-Im059_1.jpg
# Rotated image written to: Model/Augmented/1/55-3-Im059_1.jpg
# Rotated image written to: Model/Augmented/1/70-4-Im059_1.jpg
# Rotated image written to: Model/Augmented/1/150-5-Im059_1.jpg
# Rotated image written to: Model/Augmented/1/-115-6-Im059_1.jpg
# Rotated image written to: Model/Augmented/1/3-7-Im059_1.jpg
# Rotated image written to: Model/Augmented/1/42-8-Im059_1.jpg
# Rotated image written to: Model/Augmented/1/-107-9-Im059_1.jpg
# Rotated image written to: Model/Augmented/1/73-10-Im059_1.jpg
# Rotated image written to: Model/Augmented/1/124-11-Im059_1.jpg
# Rotated image written to: Model/Augmented/1/-57-12-Im059_1.jpg
# Rotated image written to: Model/Augmented/1/172-13-Im059_1.jpg
# Rotated image written to: Model/Augmented/1/141-14-Im059_1.jpg
# Rotated image written to: Model/Augmented/1/-104-15-Im059_1.jpg
# Rotated image written to: Model/Augmented/1/-135-16-Im059_1.jpg
# Rotated image written to: Model/Augmented/1/159-17-Im059_1.jpg
# Rotated image written to: Model/Augmented/1/35-18-Im059_1.jpg
# Rotated image written to: Model/Augmented/1/-172-19-Im059_1.jpg
# Total augmented files created so far 648
#
# Resized image written to: Model/Augmented/1/Im016_1.jpg
# Grayscaled image written to: Model/Augmented/1/Gray-Im016_1.jpg
# Histogram equalized image written to: Model/Augmented/1/Hist-Im016_1.jpg
# Horizontally reflected image written to: Model/Augmented/1/Hor-Im016_1.jpg
# Vertical reflected image written to: Model/Augmented/1/Ver-Im016_1.jpg
# Gaussian image written to: Model/Augmented/1/Gaus-Im016_1.jpg
# Translated image written to: Model/Augmented/1/Trans-Im016_1.jpg
# Rotated image written to: Model/Augmented/1/121-0-Im016_1.jpg
# Rotated image written to: Model/Augmented/1/63-1-Im016_1.jpg
# Rotated image written to: Model/Augmented/1/172-2-Im016_1.jpg
# Rotated image written to: Model/Augmented/1/-16-3-Im016_1.jpg
# Rotated image written to: Model/Augmented/1/-88-4-Im016_1.jpg
# Rotated image written to: Model/Augmented/1/-84-5-Im016_1.jpg
# Rotated image written to: Model/Augmented/1/176-6-Im016_1.jpg
# Rotated image written to: Model/Augmented/1/-154-7-Im016_1.jpg
# Rotated image written to: Model/Augmented/1/124-8-Im016_1.jpg
# Rotated image written to: Model/Augmented/1/36-9-Im016_1.jpg
# Rotated image written to: Model/Augmented/1/93-10-Im016_1.jpg
# Rotated image written to: Model/Augmented/1/-41-11-Im016_1.jpg
# Rotated image written to: Model/Augmented/1/-28-12-Im016_1.jpg
# Rotated image written to: Model/Augmented/1/-129-13-Im016_1.jpg
# Rotated image written to: Model/Augmented/1/121-14-Im016_1.jpg
# Rotated image written to: Model/Augmented/1/-180-15-Im016_1.jpg
# Rotated image written to: Model/Augmented/1/8-16-Im016_1.jpg
# Rotated image written to: Model/Augmented/1/7-17-Im016_1.jpg
# Rotated image written to: Model/Augmented/1/160-18-Im016_1.jpg
# Rotated image written to: Model/Augmented/1/-7-19-Im016_1.jpg
# Total augmented files created so far 675
#
# Resized image written to: Model/Augmented/1/Im007_1.jpg
# Grayscaled image written to: Model/Augmented/1/Gray-Im007_1.jpg
# Histogram equalized image written to: Model/Augmented/1/Hist-Im007_1.jpg
# Horizontally reflected image written to: Model/Augmented/1/Hor-Im007_1.jpg
# Vertical reflected image written to: Model/Augmented/1/Ver-Im007_1.jpg
# Gaussian image written to: Model/Augmented/1/Gaus-Im007_1.jpg
# Translated image written to: Model/Augmented/1/Trans-Im007_1.jpg
# Rotated image written to: Model/Augmented/1/-64-0-Im007_1.jpg
# Rotated image written to: Model/Augmented/1/89-1-Im007_1.jpg
# Rotated image written to: Model/Augmented/1/14-2-Im007_1.jpg
# Rotated image written to: Model/Augmented/1/-150-3-Im007_1.jpg
# Rotated image written to: Model/Augmented/1/-140-4-Im007_1.jpg
# Rotated image written to: Model/Augmented/1/-159-5-Im007_1.jpg
# Rotated image written to: Model/Augmented/1/-100-6-Im007_1.jpg
# Rotated image written to: Model/Augmented/1/-143-7-Im007_1.jpg
# Rotated image written to: Model/Augmented/1/-43-8-Im007_1.jpg
# Rotated image written to: Model/Augmented/1/-142-9-Im007_1.jpg
# Rotated image written to: Model/Augmented/1/-67-10-Im007_1.jpg
# Rotated image written to: Model/Augmented/1/-137-11-Im007_1.jpg
# Rotated image written to: Model/Augmented/1/-177-12-Im007_1.jpg
# Rotated image written to: Model/Augmented/1/43-13-Im007_1.jpg
# Rotated image written to: Model/Augmented/1/173-14-Im007_1.jpg
# Rotated image written to: Model/Augmented/1/-72-15-Im007_1.jpg
# Rotated image written to: Model/Augmented/1/-171-16-Im007_1.jpg
# Rotated image written to: Model/Augmented/1/-110-17-Im007_1.jpg
# Rotated image written to: Model/Augmented/1/68-18-Im007_1.jpg
# Rotated image written to: Model/Augmented/1/-40-19-Im007_1.jpg
# Total augmented files created so far 702
#
# Resized image written to: Model/Augmented/1/Im054_1.jpg
# Grayscaled image written to: Model/Augmented/1/Gray-Im054_1.jpg
# Histogram equalized image written to: Model/Augmented/1/Hist-Im054_1.jpg
# Horizontally reflected image written to: Model/Augmented/1/Hor-Im054_1.jpg
# Vertical reflected image written to: Model/Augmented/1/Ver-Im054_1.jpg
# Gaussian image written to: Model/Augmented/1/Gaus-Im054_1.jpg
# Translated image written to: Model/Augmented/1/Trans-Im054_1.jpg
# Rotated image written to: Model/Augmented/1/-26-0-Im054_1.jpg
# Rotated image written to: Model/Augmented/1/-69-1-Im054_1.jpg
# Rotated image written to: Model/Augmented/1/-164-2-Im054_1.jpg
# Rotated image written to: Model/Augmented/1/-146-3-Im054_1.jpg
# Rotated image written to: Model/Augmented/1/91-4-Im054_1.jpg
# Rotated image written to: Model/Augmented/1/-69-5-Im054_1.jpg
# Rotated image written to: Model/Augmented/1/-35-6-Im054_1.jpg
# Rotated image written to: Model/Augmented/1/-118-7-Im054_1.jpg
# Rotated image written to: Model/Augmented/1/-58-8-Im054_1.jpg
# Rotated image written to: Model/Augmented/1/-138-9-Im054_1.jpg
# Rotated image written to: Model/Augmented/1/173-10-Im054_1.jpg
# Rotated image written to: Model/Augmented/1/-157-11-Im054_1.jpg
# Rotated image written to: Model/Augmented/1/-161-12-Im054_1.jpg
# Rotated image written to: Model/Augmented/1/-110-13-Im054_1.jpg
# Rotated image written to: Model/Augmented/1/-106-14-Im054_1.jpg
# Rotated image written to: Model/Augmented/1/-31-15-Im054_1.jpg
# Rotated image written to: Model/Augmented/1/-37-16-Im054_1.jpg
# Rotated image written to: Model/Augmented/1/95-17-Im054_1.jpg
# Rotated image written to: Model/Augmented/1/-64-18-Im054_1.jpg
# Rotated image written to: Model/Augmented/1/-22-19-Im054_1.jpg
# Total augmented files created so far 729
#
# Resized image written to: Model/Augmented/1/Im012_1.jpg
# Grayscaled image written to: Model/Augmented/1/Gray-Im012_1.jpg
# Histogram equalized image written to: Model/Augmented/1/Hist-Im012_1.jpg
# Horizontally reflected image written to: Model/Augmented/1/Hor-Im012_1.jpg
# Vertical reflected image written to: Model/Augmented/1/Ver-Im012_1.jpg
# Gaussian image written to: Model/Augmented/1/Gaus-Im012_1.jpg
# Translated image written to: Model/Augmented/1/Trans-Im012_1.jpg
# Rotated image written to: Model/Augmented/1/166-0-Im012_1.jpg
# Rotated image written to: Model/Augmented/1/170-1-Im012_1.jpg
# ...
# Total augmented files created so far 810
#
# Resized image written to: Model/Augmented/0/Im079_0.jpg
# Grayscaled image written to: Model/Augmented/0/Gray-Im079_0.jpg
# Histogram equalized image written to: Model/Augmented/0/Hist-Im079_0.jpg
# Horizontally reflected image written to: Model/Augmented/0/Hor-Im079_0.jpg
# Vertical reflected image written to: Model/Augmented/0/Ver-Im079_0.jpg
# Gaussian image written to: Model/Augmented/0/Gaus-Im079_0.jpg
# Translated image written to: Model/Augmented/0/Trans-Im079_0.jpg
# Rotated image written to: Model/Augmented/0/-47-0-Im079_0.jpg
# Rotated image written to: Model/Augmented/0/-87-1-Im079_0.jpg
# Rotated image written to: Model/Augmented/0/-87-2-Im079_0.jpg
# Rotated image written to: Model/Augmented/0/177-3-Im079_0.jpg
# Rotated image written to: Model/Augmented/0/-120-4-Im079_0.jpg
# Rotated image written to: Model/Augmented/0/78-5-Im079_0.jpg
# Rotated image written to: Model/Augmented/0/-82-6-Im079_0.jpg
# Rotated image written to: Model/Augmented/0/162-7-Im079_0.jpg
# Rotated image written to: Model/Augmented/0/-7-8-Im079_0.jpg
# Rotated image written to: Model/Augmented/0/116-9-Im079_0.jpg
# Rotated image written to: Model/Augmented/0/47-10-Im079_0.jpg
# Rotated image written to: Model/Augmented/0/-79-11-Im079_0.jpg
# Rotated image written to: Model/Augmented/0/-40-12-Im079_0.jpg
# Rotated image written to: Model/Augmented/0/167-13-Im079_0.jpg
# Rotated image written to: Model/Augmented/0/115-14-Im079_0.jpg
# Rotated image written to: Model/Augmented/0/-10-15-Im079_0.jpg
# Rotated image written to: Model/Augmented/0/-34-16-Im079_0.jpg
# Rotated image written to: Model/Augmented/0/137-17-Im079_0.jpg
# Rotated image written to: Model/Augmented/0/172-18-Im079_0.jpg
# Rotated image written to: Model/Augmented/0/-132-19-Im079_0.jpg
# Total augmented files created so far 837
#
# Resized image written to: Model/Augmented/0/Im075_0.jpg
# Grayscaled image written to: Model/Augmented/0/Gray-Im075_0.jpg
# Histogram equalized image written to: Model/Augmented/0/Hist-Im075_0.jpg
# Horizontally reflected image written to: Model/Augmented/0/Hor-Im075_0.jpg
# Vertical reflected image written to: Model/Augmented/0/Ver-Im075_0.jpg
# Gaussian image written to: Model/Augmented/0/Gaus-Im075_0.jpg
# Translated image written to: Model/Augmented/0/Trans-Im075_0.jpg
# Rotated image written to: Model/Augmented/0/-105-0-Im075_0.jpg
# Rotated image written to: Model/Augmented/0/93-1-Im075_0.jpg
# Rotated image written to: Model/Augmented/0/-130-2-Im075_0.jpg
# Rotated image written to: Model/Augmented/0/-96-3-Im075_0.jpg
# Rotated image written to: Model/Augmented/0/99-4-Im075_0.jpg
# Rotated image written to: Model/Augmented/0/-155-5-Im075_0.jpg
# Rotated image written to: Model/Augmented/0/-8-6-Im075_0.jpg
# Rotated image written to: Model/Augmented/0/-94-7-Im075_0.jpg
# Rotated image written to: Model/Augmented/0/76-8-Im075_0.jpg
# Rotated image written to: Model/Augmented/0/-63-9-Im075_0.jpg
# Rotated image written to: Model/Augmented/0/29-10-Im075_0.jpg
# Rotated image written to: Model/Augmented/0/-153-11-Im075_0.jpg
# Rotated image written to: Model/Augmented/0/62-12-Im075_0.jpg
# Rotated image written to: Model/Augmented/0/133-13-Im075_0.jpg
# Rotated image written to: Model/Augmented/0/55-14-Im075_0.jpg
# Rotated image written to: Model/Augmented/0/153-15-Im075_0.jpg
# Rotated image written to: Model/Augmented/0/26-16-Im075_0.jpg
# Rotated image written to: Model/Augmented/0/41-17-Im075_0.jpg
# Rotated image written to: Model/Augmented/0/9-18-Im075_0.jpg
# Rotated image written to: Model/Augmented/0/-91-19-Im075_0.jpg
# Total augmented files created so far 864
#
# Resized image written to: Model/Augmented/0/Im043_0.jpg
# Grayscaled image written to: Model/Augmented/0/Gray-Im043_0.jpg
# Histogram equalized image written to: Model/Augmented/0/Hist-Im043_0.jpg
# Horizontally reflected image written to: Model/Augmented/0/Hor-Im043_0.jpg
# Vertical reflected image written to: Model/Augmented/0/Ver-Im043_0.jpg
# Gaussian image written to: Model/Augmented/0/Gaus-Im043_0.jpg
# Translated image written to: Model/Augmented/0/Trans-Im043_0.jpg
# Rotated image written to: Model/Augmented/0/-28-0-Im043_0.jpg
# Rotated image written to: Model/Augmented/0/6-1-Im043_0.jpg
# Rotated image written to: Model/Augmented/0/-62-2-Im043_0.jpg
# Rotated image written to: Model/Augmented/0/-52-3-Im043_0.jpg
# Rotated image written to: Model/Augmented/0/127-4-Im043_0.jpg
# Rotated image written to: Model/Augmented/0/-142-5-Im043_0.jpg
# Rotated image written to: Model/Augmented/0/-124-6-Im043_0.jpg
# Rotated image written to: Model/Augmented/0/-50-7-Im043_0.jpg
# Rotated image written to: Model/Augmented/0/54-8-Im043_0.jpg
# Rotated image written to: Model/Augmented/0/166-9-Im043_0.jpg
# Rotated image written to: Model/Augmented/0/86-10-Im043_0.jpg
# Rotated image written to: Model/Augmented/0/111-11-Im043_0.jpg
# Rotated image written to: Model/Augmented/0/-107-12-Im043_0.jpg
# Rotated image written to: Model/Augmented/0/-5-13-Im043_0.jpg
# Rotated image written to: Model/Augmented/0/-9-14-Im043_0.jpg
# Rotated image written to: Model/Augmented/0/51-15-Im043_0.jpg
# Rotated image written to: Model/Augmented/0/-80-16-Im043_0.jpg
# Rotated image written to: Model/Augmented/0/-68-17-Im043_0.jpg
# Rotated image written to: Model/Augmented/0/108-18-Im043_0.jpg
# Rotated image written to: Model/Augmented/0/-147-19-Im043_0.jpg
# Total augmented files created so far 891
#
# Resized image written to: Model/Augmented/0/Im078_0.jpg
# Grayscaled image written to: Model/Augmented/0/Gray-Im078_0.jpg
# Histogram equalized image written to: Model/Augmented/0/Hist-Im078_0.jpg
# Horizontally reflected image written to: Model/Augmented/0/Hor-Im078_0.jpg
# Vertical reflected image written to: Model/Augmented/0/Ver-Im078_0.jpg
# Gaussian image written to: Model/Augmented/0/Gaus-Im078_0.jpg
# Translated image written to: Model/Augmented/0/Trans-Im078_0.jpg
# Rotated image written to: Model/Augmented/0/-104-0-Im078_0.jpg
# Rotated image written to: Model/Augmented/0/-5-1-Im078_0.jpg
# Rotated image written to: Model/Augmented/0/-135-2-Im078_0.jpg
# Rotated image written to: Model/Augmented/0/-54-3-Im078_0.jpg
# Rotated image written to: Model/Augmented/0/61-4-Im078_0.jpg
# Rotated image written to: Model/Augmented/0/139-5-Im078_0.jpg
# Rotated image written to: Model/Augmented/0/-59-6-Im078_0.jpg
# Rotated image written to: Model/Augmented/0/10-7-Im078_0.jpg
# Rotated image written to: Model/Augmented/0/150-8-Im078_0.jpg
# Rotated image written to: Model/Augmented/0/36-9-Im078_0.jpg
# Rotated image written to: Model/Augmented/0/-15-10-Im078_0.jpg
# Rotated image written to: Model/Augmented/0/87-11-Im078_0.jpg
# Rotated image written to: Model/Augmented/0/169-12-Im078_0.jpg
# Rotated image written to: Model/Augmented/0/171-13-Im078_0.jpg
# Rotated image written to: Model/Augmented/0/-66-14-Im078_0.jpg
# Rotated image written to: Model/Augmented/0/67-15-Im078_0.jpg
# Rotated image written to: Model/Augmented/0/11-16-Im078_0.jpg
# Rotated image written to: Model/Augmented/0/-103-17-Im078_0.jpg
# Rotated image written to: Model/Augmented/0/26-18-Im078_0.jpg
# Rotated image written to: Model/Augmented/0/113-19-Im078_0.jpg
# Total augmented files created so far 918
#
# Resized image written to: Model/Augmented/0/Im069_0.jpg
# Grayscaled image written to: Model/Augmented/0/Gray-Im069_0.jpg
# Histogram equalized image written to: Model/Augmented/0/Hist-Im069_0.jpg
# Horizontally reflected image written to: Model/Augmented/0/Hor-Im069_0.jpg
# Vertical reflected image written to: Model/Augmented/0/Ver-Im069_0.jpg
# Gaussian image written to: Model/Augmented/0/Gaus-Im069_0.jpg
# Translated image written to: Model/Augmented/0/Trans-Im069_0.jpg
# Rotated image written to: Model/Augmented/0/68-0-Im069_0.jpg
# Rotated image written to: Model/Augmented/0/-56-1-Im069_0.jpg
# Rotated image written to: Model/Augmented/0/-16-2-Im069_0.jpg
# Rotated image written to: Model/Augmented/0/10-3-Im069_0.jpg
# Rotated image written to: Model/Augmented/0/-78-4-Im069_0.jpg
# Rotated image written to: Model/Augmented/0/113-5-Im069_0.jpg
# Rotated image written to: Model/Augmented/0/-65-6-Im069_0.jpg
# Rotated image written to: Model/Augmented/0/-40-7-Im069_0.jpg
# Rotated image written to: Model/Augmented/0/-52-8-Im069_0.jpg
# Rotated image written to: Model/Augmented/0/59-9-Im069_0.jpg
# Rotated image written to: Model/Augmented/0/-171-10-Im069_0.jpg
# Rotated image written to: Model/Augmented/0/-54-11-Im069_0.jpg
# Rotated image written to: Model/Augmented/0/55-12-Im069_0.jpg
# Rotated image written to: Model/Augmented/0/-146-13-Im069_0.jpg
# Rotated image written to: Model/Augmented/0/89-14-Im069_0.jpg
# Rotated image written to: Model/Augmented/0/-39-15-Im069_0.jpg
# Rotated image written to: Model/Augmented/0/-17-16-Im069_0.jpg
# Rotated image written to: Model/Augmented/0/-111-17-Im069_0.jpg
# Rotated image written to: Model/Augmented/0/-135-18-Im069_0.jpg
# Rotated image written to: Model/Augmented/0/108-19-Im069_0.jpg
# Total augmented files created so far 945
#
# Resized image written to: Model/Augmented/0/Im077_0.jpg
# Grayscaled image written to: Model/Augmented/0/Gray-Im077_0.jpg
# Histogram equalized image written to: Model/Augmented/0/Hist-Im077_0.jpg
# Horizontally reflected image written to: Model/Augmented/0/Hor-Im077_0.jpg
# Vertical reflected image written to: Model/Augmented/0/Ver-Im077_0.jpg
# Gaussian image written to: Model/Augmented/0/Gaus-Im077_0.jpg
# Translated image written to: Model/Augmented/0/Trans-Im077_0.jpg
# Rotated image written to: Model/Augmented/0/42-0-Im077_0.jpg
# Rotated image written to: Model/Augmented/0/-138-1-Im077_0.jpg
# Rotated image written to: Model/Augmented/0/106-2-Im077_0.jpg
# Rotated image written to: Model/Augmented/0/137-3-Im077_0.jpg
# Rotated image written to: Model/Augmented/0/6-4-Im077_0.jpg
# Rotated image written to: Model/Augmented/0/42-5-Im077_0.jpg
# Rotated image written to: Model/Augmented/0/-174-6-Im077_0.jpg
# Rotated image written to: Model/Augmented/0/84-7-Im077_0.jpg
# Rotated image written to: Model/Augmented/0/-131-8-Im077_0.jpg
# Rotated image written to: Model/Augmented/0/-165-9-Im077_0.jpg
# Rotated image written to: Model/Augmented/0/104-10-Im077_0.jpg
# Rotated image written to: Model/Augmented/0/-72-11-Im077_0.jpg
# Rotated image written to: Model/Augmented/0/-47-12-Im077_0.jpg
# Rotated image written to: Model/Augmented/0/155-13-Im077_0.jpg
# Rotated image written to: Model/Augmented/0/131-14-Im077_0.jpg
# Rotated image written to: Model/Augmented/0/62-15-Im077_0.jpg
# Rotated image written to: Model/Augmented/0/64-16-Im077_0.jpg
# Rotated image written to: Model/Augmented/0/99-17-Im077_0.jpg
# Rotated image written to: Model/Augmented/0/-48-18-Im077_0.jpg
# Rotated image written to: Model/Augmented/0/17-19-Im077_0.jpg
# Total augmented files created so far 972
#
# Resized image written to: Model/Augmented/0/Im089_0.jpg
# Grayscaled image written to: Model/Augmented/0/Gray-Im089_0.jpg
# Histogram equalized image written to: Model/Augmented/0/Hist-Im089_0.jpg
# Horizontally reflected image written to: Model/Augmented/0/Hor-Im089_0.jpg
# Vertical reflected image written to: Model/Augmented/0/Ver-Im089_0.jpg
# Gaussian image written to: Model/Augmented/0/Gaus-Im089_0.jpg
# Translated image written to: Model/Augmented/0/Trans-Im089_0.jpg
# Rotated image written to: Model/Augmented/0/89-0-Im089_0.jpg
# Rotated image written to: Model/Augmented/0/137-1-Im089_0.jpg
# Rotated image written to: Model/Augmented/0/34-2-Im089_0.jpg
# Rotated image written to: Model/Augmented/0/10-3-Im089_0.jpg
# Rotated image written to: Model/Augmented/0/50-4-Im089_0.jpg
# Rotated image written to: Model/Augmented/0/82-5-Im089_0.jpg
# Rotated image written to: Model/Augmented/0/61-6-Im089_0.jpg
# Rotated image written to: Model/Augmented/0/135-7-Im089_0.jpg
# Rotated image written to: Model/Augmented/0/-150-8-Im089_0.jpg
# Rotated image written to: Model/Augmented/0/-39-9-Im089_0.jpg
# Rotated image written to: Model/Augmented/0/-114-10-Im089_0.jpg
# Rotated image written to: Model/Augmented/0/-29-11-Im089_0.jpg
# Rotated image written to: Model/Augmented/0/-63-12-Im089_0.jpg
# Rotated image written to: Model/Augmented/0/1-13-Im089_0.jpg
# Rotated image written to: Model/Augmented/0/-136-14-Im089_0.jpg
# Rotated image written to: Model/Augmented/0/-87-15-Im089_0.jpg
# Rotated image written to: Model/Augmented/0/128-16-Im089_0.jpg
# Rotated image written to: Model/Augmented/0/-3-17-Im089_0.jpg
# Rotated image written to: Model/Augmented/0/-38-18-Im089_0.jpg
# Rotated image written to: Model/Augmented/0/53-19-Im089_0.jpg
# Total augmented files created so far 999
#
# Resized image written to: Model/Augmented/0/Im045_0.jpg
# Grayscaled image written to: Model/Augmented/0/Gray-Im045_0.jpg
# Histogram equalized image written to: Model/Augmented/0/Hist-Im045_0.jpg
# Horizontally reflected image written to: Model/Augmented/0/Hor-Im045_0.jpg
# Vertical reflected image written to: Model/Augmented/0/Ver-Im045_0.jpg
# Gaussian image written to: Model/Augmented/0/Gaus-Im045_0.jpg
# Translated image written to: Model/Augmented/0/Trans-Im045_0.jpg
# Rotated image written to: Model/Augmented/0/25-0-Im045_0.jpg
# Rotated image written to: Model/Augmented/0/-19-1-Im045_0.jpg
# Rotated image written to: Model/Augmented/0/123-2-Im045_0.jpg
# Rotated image written to: Model/Augmented/0/-13-3-Im045_0.jpg
# Rotated image written to: Model/Augmented/0/173-4-Im045_0.jpg
# Rotated image written to: Model/Augmented/0/63-5-Im045_0.jpg
# Rotated image written to: Model/Augmented/0/36-6-Im045_0.jpg
# Rotated image written to: Model/Augmented/0/-163-7-Im045_0.jpg
# Rotated image written to: Model/Augmented/0/76-8-Im045_0.jpg
# Rotated image written to: Model/Augmented/0/-180-9-Im045_0.jpg
# Rotated image written to: Model/Augmented/0/65-10-Im045_0.jpg
# Rotated image written to: Model/Augmented/0/29-11-Im045_0.jpg
# Rotated image written to: Model/Augmented/0/-66-12-Im045_0.jpg
# Rotated image written to: Model/Augmented/0/105-13-Im045_0.jpg
# Rotated image written to: Model/Augmented/0/-3-14-Im045_0.jpg
# Rotated image written to: Model/Augmented/0/-74-15-Im045_0.jpg
# Rotated image written to: Model/Augmented/0/108-16-Im045_0.jpg
# Rotated image written to: Model/Augmented/0/-151-17-Im045_0.jpg
# Rotated image written to: Model/Augmented/0/-47-18-Im045_0.jpg
# Rotated image written to: Model/Augmented/0/-144-19-Im045_0.jpg
# Total augmented files created so far 1026
#
# Resized image written to: Model/Augmented/0/Im096_0.jpg
# Grayscaled image written to: Model/Augmented/0/Gray-Im096_0.jpg
# Histogram equalized image written to: Model/Augmented/0/Hist-Im096_0.jpg
# Horizontally reflected image written to: Model/Augmented/0/Hor-Im096_0.jpg
# Vertical reflected image written to: Model/Augmented/0/Ver-Im096_0.jpg
# Gaussian image written to: Model/Augmented/0/Gaus-Im096_0.jpg
# Translated image written to: Model/Augmented/0/Trans-Im096_0.jpg
# Rotated image written to: Model/Augmented/0/63-0-Im096_0.jpg
# Rotated image written to: Model/Augmented/0/-127-1-Im096_0.jpg
# Rotated image written to: Model/Augmented/0/62-2-Im096_0.jpg
# Rotated image written to: Model/Augmented/0/5-3-Im096_0.jpg
# Rotated image written to: Model/Augmented/0/61-4-Im096_0.jpg
# Rotated image written to: Model/Augmented/0/-109-5-Im096_0.jpg
# Rotated image written to: Model/Augmented/0/-167-6-Im096_0.jpg
# Rotated image written to: Model/Augmented/0/180-7-Im096_0.jpg
# Rotated image written to: Model/Augmented/0/25-8-Im096_0.jpg
# Rotated image written to: Model/Augmented/0/146-9-Im096_0.jpg
# Rotated image written to: Model/Augmented/0/-118-10-Im096_0.jpg
# Rotated image written to: Model/Augmented/0/-164-11-Im096_0.jpg
# Rotated image written to: Model/Augmented/0/50-12-Im096_0.jpg
# Rotated image written to: Model/Augmented/0/124-13-Im096_0.jpg
# Rotated image written to: Model/Augmented/0/-2-14-Im096_0.jpg
# Rotated image written to: Model/Augmented/0/171-15-Im096_0.jpg
# Rotated image written to: Model/Augmented/0/61-16-Im096_0.jpg
# Rotated image written to: Model/Augmented/0/-101-17-Im096_0.jpg
# Rotated image written to: Model/Augmented/0/69-18-Im096_0.jpg
# Rotated image written to: Model/Augmented/0/46-19-Im096_0.jpg
# Total augmented files created so far 1053
#
# AML/ALL Augmentation: 2019-03-31 11:55:52
# Added filters to 39 files in the 0 directory
# Total of 1053 augmented files created.

# %% [markdown]
# &nbsp;
#
#
# # Your augmented dataset
# If you head to your __Model/Data/__ directory you will notice the augmented directory. Inside the augmented directory you will find 0 (negative) and 1 (postive) directories including resized copies of the original along with Grayscaled, Histogram Equalized, Reflected, Gaussian Blurred and rotated copies.
#
# Using data augmentation I was able to increase the dataset from 39 images per class to 1053 per class.
#
# &nbsp;
#
# # Contributing
# The Peter Moss Acute Myeloid/Lymphoblastic Leukemia AI Research project encourages and welcomes code contributions, bug fixes and enhancements from the community to the Github repositories. Please read the [CONTRIBUTING](https://github.com/AMLResearchProject/AML-ALL-Classifiers/blob/master/CONTRIBUTING.md "CONTRIBUTING") document for a full guide to forking our repositories and submitting your pull request. You will also find information about our code of conduct on this page.
#
# ## Acute Lymphoblastic Leukemia Convolutional Neural Network Contributors
#
# - [Adam Milton-Barker](https://github.com/AdamMiltonBarker "Adam Milton-Barker") - Bigfinite IoT Network Engineer & Intel Software Innovator, Barcelona, Spain
#
# &nbsp;
#
# # Versioning
# We use SemVer for versioning. For the versions available, see [Releases](https://github.com/AMLResearchProject/AML-ALL-Classifiers/releases "Releases").
#
# # License
# This project is licensed under the **MIT License** - see the [LICENSE](https://github.com/AMLResearchProject/AML-ALL-Classifiers/blob/master/LICENSE "LICENSE") file for details.
#
# # Bugs/Issues
# We use the [repo issues](https://github.com/AMLResearchProject/AML-ALL-Classifiers/issues "repo issues") to track bugs and general requests related to using this project.
#
# &nbsp;
#
# # Project Author
# Adam is a [BigFinite](https://www.bigfinite.com "BigFinite") IoT Network Engineer, part of the team that works on the core IoT software. In his spare time he is an [Intel Software Innovator](https://software.intel.com/en-us/intel-software-innovators/overview "Intel Software Innovator") in the fields of Internet of Things, Artificial Intelligence and Virtual Reality.
#
# [![Adam Milton-Barker: BigFinte IoT Network Engineer & Intel® Software Innovator](../../Media/Images/Adam-Milton-Barker.jpg)](https://github.com/AdamMiltonBarker)
